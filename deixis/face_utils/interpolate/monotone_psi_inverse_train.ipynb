# %%
# Unbounded-scale monotone mapping with learned (mu, sigma) around logit
# - Bootstrapped per-item ratings via your loader
# - Heteroscedastic per-item variances
# - Strict per-bin Δψ floor (no flat collapses)
# - Adaptive prior against overconfident tails
# - (mu, sigma) learned via EMA each iteration to make the logit “comfortable”
# - Optional TensorBoard logging

import numpy as np
import pandas as pd
import torch
import pickle
from pathlib import Path
import matplotlib.pyplot as plt
from typing import Dict, Tuple, Any

# ---------------------------- bootstrap + loader ----------------------------
def bootstrap_tensor(y: torch.Tensor) -> torch.Tensor:
    """
    Vectorized bootstrap with replacement along the last dimension.
    NaNs are ignored; sampling is only from valid entries.
    If a row has <1 valid value, returns NaNs for that row.
    """
    if y.ndim == 1:
        y = y.unsqueeze(0)
    B, R = y.shape
    y_np = y.detach().cpu().numpy()
    out = np.full_like(y_np, np.nan, dtype=np.float32)
    rng = np.random.default_rng(12345)
    for i in range(B):
        row = y_np[i]
        valid_idx = np.where(np.isfinite(row))[0]
        if valid_idx.size == 0:
            continue
        # sample exactly R indices with replacement
        draw = rng.choice(valid_idx, size=R, replace=True)
        out[i] = row[draw]
    return torch.from_numpy(out).to(y.dtype)

def pad_list(l, max_len):
    return l[:max_len] + [np.nan] * (max_len - len(l[:max_len]))

def load_interp_data(base_dir = "/Users/adamsobieszek/PycharmProjects/PsychGAN/", scale=1) -> Tuple[
    Dict[str, torch.Tensor],
    Dict[str, Dict[str, torch.Tensor]]
]:
    """
    Load latent coordinates and ratings, and build bootstrapped rating vectors per item.
    Returns: (photo_to_coords, dim_to_photo_to_ratings)
             where dim_to_photo_to_ratings[dimension][photo] -> 1D torch tensor (bootstrapped ints)
    """
    base_dir = Path(base_dir)
    p2c_path = base_dir / "newer_photo_to_coords.pt"
    d2p2r_path = base_dir / "dim_to_photo_to_ratings2.pkl"
    with open(d2p2r_path, "rb") as f:
        dim_to_photo_to_ratings = pickle.load(f)
    photo_to_coords = torch.load(p2c_path, map_location="cpu")
    photo_to_coords = {k: torch.tensor(v).cpu().flatten()[:512] for k, v in photo_to_coords.items()}

    out = {}
    for dim_name, p2r in dim_to_photo_to_ratings.items():
        # choose an oversample length per dimension (2.5x longest)
        max_len = int(max(len(p2r[kk]) for kk in p2r) * 2.5)
        inner = {}
        for kk, ratings in p2r.items():
            base = torch.tensor(pad_list(ratings, max_len), dtype=torch.float32).reshape(1, -1)
            # Optional global scaling (your code had a small shift when scale!=1)
            base = ((-0.005 if scale != 1 else 0.0) + base) * scale
            boot = bootstrap_tensor(base).reshape(-1)     # 1D vector, ints or floats
            inner[kk] = boot.to(dtype=torch.float32)      # keep as float32 for safety
        out[dim_name] = inner

    return photo_to_coords, out

# ---------------------------- helpers ----------------------------
def diffuse(vec, eps):
    if eps <= 0: return vec
    left = np.zeros_like(vec); right = np.zeros_like(vec)
    left[1:]  = vec[:-1]
    right[:-1]= vec[1:]
    return np.maximum(0.0, (1-2*eps)*vec + eps*(left + right))

def weighted_isotonic(y_vals, w_vals):
    """
    Weighted PAV on an already-ordered 1D grid.
    Returns fitted nondecreasing values (NaNs remain if all weights zero; caller fills).
    """
    mask = w_vals > 0
    y = y_vals[mask]
    w = w_vals[mask]
    if y.size == 0:
        return np.full_like(y_vals, np.nan, dtype=float)

    block_y = y.astype(float).tolist()
    block_w = w.astype(float).tolist()
    block_idx = list(range(len(y)))

    i = 0
    while i < len(block_y) - 1:
        if block_y[i] > block_y[i+1]:
            wy = block_w[i]*block_y[i] + block_w[i+1]*block_y[i+1]
            ww = block_w[i] + block_w[i+1]
            block_y[i] = wy / (ww + 1e-12)
            block_w[i] = ww
            del block_y[i+1]; del block_w[i+1]; del block_idx[i+1]
            if i > 0: i -= 1
        else:
            i += 1

    y_fit_masked = np.empty_like(y)
    for b in range(len(block_y)):
        s = block_idx[b]
        e = block_idx[b+1] if b+1 < len(block_y) else len(y_fit_masked)
        y_fit_masked[s:e] = block_y[b]

    y_fit_full = np.full_like(y_vals, np.nan, dtype=float)
    y_fit_full[mask] = y_fit_masked
    return y_fit_full

def fill_nearest(y_fit, low=None, high=None):
    y = y_fit.copy()
    idx = np.where(~np.isnan(y))[0]
    if idx.size == 0:
        y = np.linspace(0.0, 1.0, len(y))
    else:
        first, last = idx[0], idx[-1]
        for i in range(first-1, -1, -1): y[i] = y[i+1]
        for i in range(last+1, len(y)):  y[i] = y[i-1]
    if low is not None or high is not None:
        low  = -np.inf if low  is None else low
        high =  np.inf if high is None else high
        y = np.clip(y, low, high)
    return y

def logit(p):
    p = np.clip(p, 1e-12, 1 - 1e-12)
    return np.log(p) - np.log(1 - p)

# ---------------------------- Trainer ----------------------------
class MonotoneMappingTrainer:
    def __init__(self, config: Dict[str, Any]):
        self.cfg = config
        self.writer = None
        if self.cfg.get("logging", {}).get("tensorboard", False):
            try:
                from torch.utils.tensorboard import SummaryWriter
                log_dir = self.cfg["logging"].get("log_dir", "./runs/monotone_mapping")
                self.writer = SummaryWriter(log_dir=log_dir)
            except Exception as e:
                print(f"(TensorBoard disabled) {e}")
                self.writer = None

    def _log_scalar(self, name, value, step):
        if self.writer is not None:
            self.writer.add_scalar(name, value, step)

    def fit(self, dim_to_photo_to_ratings: Dict[str, Dict[str, torch.Tensor]], dimension_name_hint="age"):
        # ------------- Pull config -------------
        min_ratings       = self.cfg["data"].get("min_ratings", 10)
        max_iters         = self.cfg["training"].get("max_iters", 200)
        tol               = self.cfg["training"].get("tol", 1e-6)
        sigma_floor       = self.cfg["model"].get("sigma_floor", 1e-4)
        neighbor_diff     = self.cfg["model"].get("neighbor_diffusion", 0.15)
        # Prior
        prior_strength    = self.cfg["model"].get("prior_strength", 3.0)
        prior_power       = self.cfg["model"].get("prior_power", 1.0)
        prior_center      = self.cfg["model"].get("prior_center", "linear_u")  # or "previous"
        # Strict floor
        min_delta_per_bin = self.cfg["model"].get("min_delta_per_bin", 6e-4)
        adaptive_floor_mass = self.cfg["model"].get("adaptive_floor_mass", 0.02)
        baseline_from     = self.cfg["model"].get("baseline_from", "counts")
        # Logit/EMA
        eps               = self.cfg["model"].get("eps", 1.0/202.0)
        ema_rate          = self.cfg["model"].get("ema_rate", 0.25)
        sigma_min_logit   = self.cfg["model"].get("sigma_min_logit", 0.35)

        # ------------- Select dimension & collect data -------------
        dims = list(dim_to_photo_to_ratings.keys())
        dim = next((d for d in dims if dimension_name_hint.lower() in d.lower()), dims[0])
        p2r = dim_to_photo_to_ratings[dim]

        # Filter photos
        def looks_like_target(p):
            try:
                base = Path(p).stem
                n = int(base)
                return 1 <= n <= 1004
            except Exception:
                return False
        photos = sorted([p for p,t in p2r.items() if len(t) >= min_ratings and looks_like_target(p)])
        if not photos:
            photos = sorted([p for p,t in p2r.items() if len(t) >= min_ratings])
        I = len(photos)
        if I == 0:
            raise RuntimeError("No photos with sufficient ratings.")

        photo_idx = {p:i for i,p in enumerate(photos)}
        R_all, idx_i = [], []
        for p in photos:
            # NOTE: these are bootstrapped vectors already (ints/float)
            r = p2r[p].detach().cpu().numpy()
            R_all.append(r)
            idx_i.extend([photo_idx[p]]*len(r))
        R_all = np.concatenate(R_all, axis=0)
        idx_i = np.asarray(idx_i, dtype=np.int32)
        n_i = np.bincount(idx_i, minlength=I).astype(np.int32)

        # rating grid
        grid_r = np.arange(0, 101, dtype=np.int32)
        y_grid = (grid_r + 0.5) / 101.0

        # initialize μ, σ from the raw y distribution
        # clamp away from edges to keep logit sane
        y_all = np.clip((R_all + 0.5) / 101.0, eps, 1 - eps)
        mu = float(y_all.mean())
        sig = float(y_all.std(ddof=0))
        sig = max(sig, sigma_min_logit)

        # Initialize ψ on bins (unbounded scale), start roughly as standardized logit
        u_grid = logit(np.clip(0.5 + (y_grid - mu)/max(sig, 1e-12), eps, 1 - eps))
        u_grid = (u_grid - u_grid.mean()) / (u_grid.std(ddof=0) + 1e-12)
        psi_bins = u_grid.copy()

        Theta = np.zeros(I, dtype=np.float64)
        sigma2 = np.ones(I, dtype=np.float64) * max(sigma_floor**2, 1e-6)

        # Supports per bin (for priors & adaptive floors)
        C_r_raw = np.bincount(R_all.astype(np.int32), minlength=101).astype(np.float64)
        C_r_smooth = diffuse(C_r_raw, neighbor_diff)

        # Per-interval floor b_inc (length 100) and cumulative baseline
        Ninc = 100
        floor_uniform = np.full(Ninc, min_delta_per_bin, dtype=float)
        if adaptive_floor_mass > 0:
            if baseline_from == "counts":
                density = C_r_smooth[:-1] + 1.0
            else:
                density = np.ones(Ninc, dtype=float)
            density = density / (density.sum() + 1e-12)
            floor_adapt = adaptive_floor_mass * density
        else:
            floor_adapt = 0.0
        b_inc = floor_uniform + floor_adapt
        total_floor = float(b_inc.sum())
        if total_floor >= 0.98:  # feasibility
            b_inc *= 0.98 / total_floor
        B_cum = np.concatenate([[0.0], np.cumsum(b_inc)])  # length 101

        prev_obj = None
        for it in range(max_iters):
            # --- current standardized logit grid (depends on μ,σ)
            u_grid = logit(np.clip(0.5 + (y_grid - mu)/max(sig, 1e-12), eps, 1 - eps))
            u_grid_std = (u_grid - u_grid.mean()) / (u_grid.std(ddof=0) + 1e-12)

            # ---- A-step: Θ (item locations on ψ-scale)
            z_all = psi_bins[R_all.astype(np.int32)]
            sum_z = np.bincount(idx_i, weights=z_all, minlength=I).astype(np.float64)
            Theta = sum_z / np.maximum(n_i, 1)
            Theta = (Theta - Theta.mean()) / (Theta.std(ddof=0) + 1e-12)

            # ---- S-step: σ²_i (heteroscedastic per item)
            res = z_all - Theta[idx_i]
            sum_res2 = np.bincount(idx_i, weights=res*res, minlength=I).astype(np.float64)
            sigma2_mle = sum_res2 / np.maximum(n_i, 1)
            sigma2 = np.maximum(sigma2_mle, sigma_floor**2)

            # ---- B-step on φ = ψ - B to enforce Δψ >= b_inc
            w_i = 1.0 / (sigma2 + 1e-12)
            wi_obs = w_i[idx_i]
            # Aggregate to rating bins
            T_r = np.bincount(R_all.astype(np.int32), weights=wi_obs*Theta[idx_i], minlength=101).astype(np.float64)
            W_r = np.bincount(R_all.astype(np.int32), weights=wi_obs,               minlength=101).astype(np.float64)
            # mild diffusion
            T_r = diffuse(T_r, neighbor_diff)
            W_r = diffuse(W_r, neighbor_diff)

            # Prior center for ψ on bins
            if prior_center == "previous":
                prior_mu_psi = psi_bins.copy()
            else:  # "linear_u": shrink toward standardized u_grid
                prior_mu_psi = u_grid_std.copy()

            # Convert to φ prior: μ_φ = μ_ψ - B
            prior_mu_phi = prior_mu_psi - B_cum

            # Prior weights α_r: stronger when support is low
            C_med = np.median(C_r_raw[C_r_raw > 0]) if np.any(C_r_raw > 0) else 1.0
            W_nonzero = W_r[W_r > 0]
            W_med = np.median(W_nonzero) if W_nonzero.size > 0 else 1.0
            alpha_r = prior_strength * W_med * (C_med / (C_r_raw + 1.0))**prior_power
            alpha_r = np.clip(alpha_r, 0.0, 10.0 * W_med)

            # Targets for φ: (m_r - B) with prior
            m_r_phi_num = T_r - W_r * B_cum + alpha_r * prior_mu_phi
            W_r_phi      = W_r + alpha_r
            with np.errstate(divide='ignore', invalid='ignore'):
                m_r_phi = m_r_phi_num / np.maximum(W_r_phi, 1e-12)

            # Weighted isotonic for φ (nondecreasing)
            phi_fit = weighted_isotonic(m_r_phi, W_r_phi)
            phi_fit = fill_nearest(phi_fit)
            phi_fit = np.maximum.accumulate(phi_fit)

            # Recover ψ and guarantee Δψ >= b_inc
            psi_bins = B_cum + phi_fit

            # ---- objective (profile likelihood + prior penalty on φ)
            z_all = psi_bins[R_all.astype(np.int32)]
            res = z_all - Theta[idx_i]
            sum_res2 = np.bincount(idx_i, weights=res*res, minlength=I).astype(np.float64)
            sigma2 = np.maximum(sum_res2 / np.maximum(n_i, 1), sigma_floor**2)
            like = 0.5 * np.sum((sum_res2 / np.maximum(sigma2, 1e-12)) + n_i * np.log(np.maximum(sigma2, 1e-12)))
            prior_pen = 0.5 * np.sum(alpha_r * ((psi_bins - B_cum) - prior_mu_phi)**2)
            obj = like + prior_pen

            # ---- EMA update for (mu, sig) based on weighted y distribution
            W_tot = np.sum(W_r)
            if W_tot > 0:
                mu_hat = float(np.sum(W_r * y_grid) / W_tot)
                var_hat = float(np.sum(W_r * (y_grid - mu_hat)**2) / W_tot)
                sig_hat = float(np.sqrt(max(var_hat, 1e-12)))
            else:
                mu_hat, sig_hat = mu, sig
            mu_prev, sig_prev = mu, sig
            mu = (1 - ema_rate) * mu + ema_rate * mu_hat
            sig = (1 - ema_rate) * sig + ema_rate * max(sig_hat, sigma_min_logit)

            # ---- logging
            dpsi = np.diff(psi_bins)
            self._log_scalar("loss/obj", obj, it)
            self._log_scalar("loss/like", like, it)
            self._log_scalar("loss/prior_pen", prior_pen, it)
            self._log_scalar("geom/min_delta", dpsi.min(), it)
            self._log_scalar("scale/mu", mu, it)
            self._log_scalar("scale/sigma", sig, it)

            # convergence
            if prev_obj is not None and abs(prev_obj - obj) / (abs(prev_obj) + 1e-12) < tol:
                break
            prev_obj = obj

        # ---- outputs ----
        dpsi = np.diff(psi_bins)
        psi_table = pd.DataFrame({
            "rating_int": grid_r,
            "y_unit": y_grid,
            "psi": psi_bins,
            "bin_count": C_r_raw,
            "alpha_prior": alpha_r,
            "baseline_cum": B_cum
        })
        baseline_inc = b_inc.copy()  # length 100

        Theta_df = pd.DataFrame({
            "photo": photos,
            "Theta": Theta,
            "sigma": np.sqrt(sigma2),
            "n": n_i
        })

        diagnostics = dict(
            iterations = it+1,
            obj = float(obj),
            mu = float(mu),
            sigma = float(sig),
            min_delta = float(dpsi.min()),
            floor_min = float(b_inc.min()),
            violates_floor = bool((dpsi < b_inc - 1e-12).any()),
            dimension = dim
        )

        return dict(
            dimension=dim,
            psi_table=psi_table,
            Theta=Theta_df,
            diagnostics=diagnostics,
            baseline_inc=baseline_inc
        )

# ---------------------------- Config ----------------------------
CONFIG = {
    "data": {
        "min_ratings": 10,
        "base_dir": "/Users/adamsobieszek/PycharmProjects/PsychGAN/",
        "bootstrap_scale": 101.0,
    },
    "training": {
        "max_iters": 2000,
        "tol": 1e-6,
    },
    "model": {
        "sigma_floor": 1e-7,
        "neighbor_diffusion": 0.01,
        "prior_strength": 3.0,
        "prior_power": 1.0,
        "prior_center": "linear_u",   # or "previous"
        "min_delta_per_bin": 6e-4,
        "adaptive_floor_mass": 0.01,
        "baseline_from": "counts",
        "eps": 1.0/202.0,
        "ema_rate": 0.2,
        "sigma_min_logit": 0.25,
    },
    "logging": {
        "tensorboard": True,
        "log_dir": "./runs/monotone_mapping_unbounded"
    }
}

# ---------------------------- Run ----------------------------
# Load bootstrapped data using your loader
photo_to_coords, dim_to_photo_to_ratings = load_interp_data(CONFIG["data"]["base_dir"], scale=CONFIG["data"]["bootstrap_scale"])

# Train
trainer = MonotoneMappingTrainer(CONFIG)
results = trainer.fit(dim_to_photo_to_ratings, dimension_name_hint="age")

psi_table = results["psi_table"]
Theta_df  = results["Theta"]
diagn     = results["diagnostics"]
b_inc     = results["baseline_inc"]
dim_name  = results["dimension"]

print("Diagnostics:", diagn)

# ---------------------------- Visualize ----------------------------
x = psi_table["y_unit"].values
y = psi_table["psi"].values
B = psi_table["baseline_cum"].values
dpsi = np.diff(y)
mid  = (x[:-1] + x[1:]) / 2.0

fig, ax = plt.subplots(1,1, figsize=(6.6,4.4))
ax.plot(x, y, lw=2, label="ψ (unbounded)")
ax.plot(x, B, lw=1.2, alpha=0.6, label="baseline (cum)")
ax.set_xlabel("raw scale y"); ax.set_ylabel("ψ(y)")
ax.set_title(f"Unbounded monotone mapping ψ — {dim_name}")
ax.legend(); plt.tight_layout(); plt.show()

fig, ax = plt.subplots(2,1, figsize=(7.4,6.0), sharex=True)
ax[0].plot(mid, dpsi, lw=1.6, label="Δψ per bin")
ax[0].plot(mid, b_inc, lw=1.2, alpha=0.85, label="floor b_r")
ax[0].set_ylabel("Δψ"); ax[0].legend()
ax[1].bar(x, psi_table["bin_count"].values, width=1/101, alpha=0.55, label="bin count")
ax[1].plot(x, psi_table["alpha_prior"].values, lw=1.2, label="prior weight α_r")
ax[1].set_xlabel("raw scale y"); ax[1].set_ylabel("support / prior"); ax[1].legend()
plt.tight_layout(); plt.show()

# Save artifacts
out_dir = Path("./scale_learning_age_unbounded")
out_dir.mkdir(parents=True, exist_ok=True)
psi_csv   = out_dir / f"psi_lookup_{dim_name}_unbounded.csv"
theta_csv = out_dir / f"Theta_sigma_{dim_name}_unbounded.csv"
psi_table.to_csv(psi_csv, index=False)
Theta_df.to_csv(theta_csv, index=False)
print("Saved CSVs:", psi_csv, "and", theta_csv)
# Out:
# /var/folders/nc/zbqbbkkx08z7v1g3mlf8bdn00000gn/T/ipykernel_73841/1637880195.py:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   photo_to_coords = {k: torch.tensor(v).cpu().flatten()[:512] for k, v in photo_to_coords.items()}
# Diagnostics: {'iterations': 164, 'obj': -18722.966260296933, 'mu': 0.363016145763665, 'sigma': 0.25, 'min_delta': 0.0006000585604482023, 'floor_min': 0.00060005856044832, 'violates_floor': False, 'dimension': 'age'}
# Saved CSVs: scale_learning_age_unbounded/psi_lookup_age_unbounded.csv and scale_learning_age_unbounded/Theta_sigma_age_unbounded.csv

# %%
# ============================================================
# Inverse mapping training: ψ:(0,1)->R learned from per-face
# rating distributions (quantile transport + robust NLL)
# ============================================================

import os, logging, pickle
from pathlib import Path
from typing import Dict, Tuple, List, Optional

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# ------------------ Utilities: bootstrap & I/O ------------------

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
DTYPE  = torch.float32

def bootstrap_tensor(data: torch.Tensor) -> torch.Tensor:
    """
    Bootstraps along dim=1 (ratings), preserving NaNs, used by load_interp_data.
    Expects shape (1, N) or (B, N); returns same shape.
    """
    if data.dim() == 1:
        data = data.unsqueeze(0)
    B, N = data.shape
    mask = ~torch.isnan(data)
    out = torch.full_like(data, float('nan'))
    for b in range(B):
        valid = data[b, mask[b]]
        if valid.numel() == 0:
            out[b] = torch.full((N,), 0.5, device=data.device, dtype=data.dtype)
            continue
        idx = torch.randint(0, valid.numel(), (N,), device=data.device)
        out[b] = valid[idx]
    return out

def pad_list(l, max_len):
    return l[:max_len] + [np.nan] * (max_len - len(l[:max_len]))

def load_interp_data(base_dir = "/Users/adamsobieszek/PycharmProjects/PsychGAN/", scale=1) -> Tuple[
    Dict[str, torch.Tensor],
    Dict[str, Dict[str, torch.Tensor]]
]:
    """
    Load latent coordinates (unused here), and ratings with bootstrap per image.
    Returns: (photo_to_coords, dim_to_photo_to_ratings)
    """
    base_dir = Path(base_dir)
    p2c_path = base_dir / "newer_photo_to_coords.pt"
    d2p2r_path = base_dir / "dim_to_photo_to_ratings2.pkl"
    with open(d2p2r_path, "rb") as f:
        dim_to_photo_to_ratings = pickle.load(f)
    photo_to_coords = torch.load(p2c_path, map_location="cpu")
    photo_to_coords = {k: torch.tensor(photo_to_coords[k]).cpu().flatten()[:512] for k in photo_to_coords}
    for k in dim_to_photo_to_ratings:
        max_len = int(max(len(dim_to_photo_to_ratings[k][kk]) for kk in dim_to_photo_to_ratings[k]) * 2.5)
        dim_to_photo_to_ratings[k] = {
            kk: bootstrap_tensor(
                    (((-0.005 if scale!=1 else 0.0) + torch.tensor(pad_list(dim_to_photo_to_ratings[k][kk], max_len))).reshape(1, -1)) * scale
                ).reshape(-1)
            for kk in dim_to_photo_to_ratings[k]
        }
    return photo_to_coords, dim_to_photo_to_ratings

# %%
# ------------------ Live Visualizer (Plotly, async) v2 ------------------
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from IPython.display import display
from concurrent.futures import ThreadPoolExecutor
from queue import Queue, Empty, Full
import numpy as np
import torch

class LiveInverseMappingVisualizer:
    """
    Column 1 (spans rows): mapping ψ(y) vs best linear baseline.
    Column 2 (rows 1..3): three example items stacked, hist of z=ψ(y) and current N(Θ,σ²) pdf.
    Column 3 (spans rows): scatter of Beta(α,β) fitted on re-scaled transformed ratings
                           z -> y_tilde in [0.005, 0.995] via global min/max.
    """
    def __init__(self, dataset, example_item_ids=None, grid_points=401, hist_bins=30,
                 beta_clip=(0.005, 0.995), kappa_min=1e-3):
        self.ds = dataset
        self.grid_points = int(grid_points)
        self.hist_bins = int(hist_bins)
        self.beta_clip = beta_clip
        self.kappa_min = float(kappa_min)

        # Choose 3 examples: low/median/high mean on raw unit scale
        if example_item_ids is None:
            means = []
            for r in self.ds.ratings:
                y_int = r.clone().float()
                y = torch.where(torch.isnan(y_int), y_int,
                                torch.clamp((y_int + 0.5)/101.0, 1e-6, 1-1e-6))
                y = y[~torch.isnan(y)]
                means.append(0.5 if y.numel()==0 else float(y.mean()))
            order = np.argsort(means)
            lo = int(order[max(0, int(0.1 * len(order)) - 1)])
            md = int(order[int(0.5 * len(order))])
            hi = int(order[min(len(order)-1, int(0.9 * len(order)))])
            example_item_ids = [lo, md, hi]
        self.example_item_ids = example_item_ids

        # Figure: rows=3, cols=3; col1 spans all rows; col3 spans all rows; col2 has 3 stacked plots
        specs = [
            [{"type":"xy", "rowspan":3}, {"type":"xy"}, {"type":"xy", "rowspan":3}],
            [None,                    {"type":"xy"}, None],
            [None,                    {"type":"xy"}, None],
        ]
        titles = (
            "Mapping ψ(y) (red) & Best Linear Baseline (gray)",
            f"Example #{self.example_item_ids[0]}",
            f"Example #{self.example_item_ids[1]}",
            "Beta(α, β) over items",
            f"Example #{self.example_item_ids[2]}",
        )
        self.fig = go.FigureWidget(make_subplots(
            rows=3, cols=3, specs=specs, column_widths=[0.55, 0.25, 0.20],
            subplot_titles=(titles[0], titles[1], titles[2], titles[3], titles[4])
        ))

        # Column 1 (row 1 span): baseline + ψ
        self.fig.add_trace(go.Scatter(mode="lines", line=dict(color="gray", width=2, dash="dash"),
                                      name="baseline", showlegend=False), row=1, col=1)
        self.fig.add_trace(go.Scatter(mode="lines", line=dict(color="red", width=3),
                                      name="psi", showlegend=False), row=1, col=1)

        # Column 2: three example panels (each bar + pdf)
        colors = ["#729ECE", "#8EBA42", "#FF9DA7"]
        for r in (1,2,3):
            cidx = r-1
            self.fig.add_trace(go.Bar(name=f"hist{r}", marker=dict(color=colors[cidx], opacity=0.45),
                                      showlegend=False), row=r, col=2)
            self.fig.add_trace(go.Scatter(mode="lines", line=dict(color=colors[cidx], width=2),
                                          name=f"pdf{r}", showlegend=False), row=r, col=2)

        # Column 3 (row 1 span): alpha-beta scatter
        self.fig.add_trace(go.Scatter(mode="markers",
                                      marker=dict(size=6, color="#444", opacity=0.6),
                                      name="Beta αβ", showlegend=False), row=1, col=3)

        # Axes labels
        self.fig.update_xaxes(title_text="y (slider in [0,1])", row=1, col=1)
        self.fig.update_yaxes(title_text="ψ(y)", row=1, col=1)
        for r in (1,2,3):
            self.fig.update_xaxes(title_text="z = ψ(y)", row=r, col=2)
            self.fig.update_yaxes(title_text="density", row=r, col=2)
        self.fig.update_xaxes(title_text="α (Beta)", row=1, col=3)
        self.fig.update_yaxes(title_text="β (Beta)", row=1, col=3)

        self.fig.update_layout(width=1800, height=760, title_text="Live Inverse Mapping Training",
                               margin=dict(l=50,r=20,t=60,b=40))

        display(self.fig)

        # Async infra
        self.executor = ThreadPoolExecutor(max_workers=1)
        self.plot_data_queue = Queue(maxsize=1)

        # Cache all items' unit ratings (list of np arrays)
        self._all_unit_ratings = []
        for r in self.ds.ratings:
            y_int = r.clone().float()
            y = torch.where(torch.isnan(y_int), y_int,
                            torch.clamp((y_int + 0.5)/101.0, 1e-6, 1-1e-6))
            y = y[~torch.isnan(y)]
            self._all_unit_ratings.append(y.cpu().numpy())
        # Cache 3 examples
        self._cached_unit_examples = {iid: self._all_unit_ratings[iid] for iid in self.example_item_ids}

    @torch.no_grad()
    def _prepare_and_queue_data(self, psi_model, emb_module):
        device = next(psi_model.parameters()).device

        # --- Mapping curve ---
        ygrid = torch.linspace(1e-6, 1-1e-6, self.grid_points, device=device)
        zgrid_t = psi_model(ygrid)
        zgrid = zgrid_t.detach().cpu().numpy()
        y_np = ygrid.detach().cpu().numpy()
        # Best linear baseline a + b*y
        X = np.stack([np.ones_like(y_np), y_np], axis=1)
        a_b, *_ = np.linalg.lstsq(X, zgrid, rcond=None)
        z_lin = X @ a_b

        # --- Three example items (z hist + current Gaussian pdf) ---
        hist_data = []
        for iid in self.example_item_ids:
            y_unit = self._cached_unit_examples[iid]
            if y_unit.size == 0:
                hist_data.append({"x": np.array([]), "h": np.array([]), "pdf_x": np.array([]), "pdf_y": np.array([])})
                continue
            yt = torch.tensor(y_unit, device=device, dtype=torch.float32)
            z = psi_model(yt).detach().cpu().numpy()
            zmin, zmax = np.quantile(z, [0.01, 0.99]) if z.size>1 else (float(z.min()), float(z.max()+1e-6))
            edges = np.linspace(zmin, zmax, self.hist_bins+1)
            centers = 0.5*(edges[:-1] + edges[1:])
            counts, _ = np.histogram(z, bins=edges, density=True)

            theta_i, sigma_i = emb_module(torch.tensor([iid], device=device))
            mu = float(theta_i.squeeze().detach().cpu().numpy())
            sd = max(1e-6, float(sigma_i.squeeze().detach().cpu().numpy()))
            pdf_x = np.linspace(zmin, zmax, 200)
            pdf_y = (1.0/(np.sqrt(2*np.pi)*sd)) * np.exp(-(pdf_x-mu)**2/(2*sd**2))

            hist_data.append({"x": centers, "h": counts, "pdf_x": pdf_x, "pdf_y": pdf_y})

        # --- Alpha-Beta scatter from Beta fits on re-scaled transformed ratings ---
        # 1) compute global z_min/z_max across all items
        z_global_min = np.inf
        z_global_max = -np.inf
        for arr in self._all_unit_ratings:
            if arr.size == 0: continue
            yt = torch.tensor(arr, device=device, dtype=torch.float32)
            z  = psi_model(yt).detach().cpu().numpy()
            if z.size == 0: continue
            z_global_min = min(z_global_min, float(np.min(z)))
            z_global_max = max(z_global_max, float(np.max(z)))
        if not np.isfinite(z_global_min) or not np.isfinite(z_global_max) or z_global_max <= z_global_min:
            z_global_min, z_global_max = -1.0, 1.0  # safe default

        lo, hi = self.beta_clip
        alpha_list, beta_list = [], []
        for arr in self._all_unit_ratings:
            if arr.size < 2:
                alpha_list.append(np.nan); beta_list.append(np.nan); continue
            yt = torch.tensor(arr, device=device, dtype=torch.float32)
            z  = psi_model(yt).detach().cpu().numpy()
            if z.size < 2:
                alpha_list.append(np.nan); beta_list.append(np.nan); continue
            # affine map to [lo,hi]
            ztil = (z - z_global_min) / max(1e-12, (z_global_max - z_global_min))
            ytil = np.clip(lo + (hi - lo) * ztil, lo, hi)
            m = float(np.mean(ytil))
            v = float(np.var(ytil, ddof=1)) if ytil.size>1 else 1e-6
            m = np.clip(m, lo, hi)
            v = max(v, 1e-8)
            denom = m*(1-m)
            if denom <= 1e-8:
                kappa = 1e6
            else:
                kappa = max(self.kappa_min, denom / v - 1.0)
            alpha = m * kappa
            beta  = (1.0 - m) * kappa
            alpha_list.append(alpha)
            beta_list.append(beta)

        alpha_arr = np.array(alpha_list, dtype=np.float64)
        beta_arr  = np.array(beta_list,  dtype=np.float64)
        valid = np.isfinite(alpha_arr) & np.isfinite(beta_arr) & (alpha_arr>0) & (beta_arr>0)
        alpha_arr = alpha_arr[valid]
        beta_arr  = beta_arr[valid]

        # Push latest frame
        payload = (y_np, zgrid, z_lin, hist_data, alpha_arr, beta_arr)
        try:
            self.plot_data_queue.get_nowait()
        except Empty:
            pass
        try:
            self.plot_data_queue.put_nowait(payload)
        except Full:
            pass

    def update_async(self, psi_model, emb_module):
        self.executor.submit(self._prepare_and_queue_data, psi_model, emb_module)

    def check_and_update_plot(self):
        try:
            y_np, zgrid, z_lin, hist_data, alpha_arr, beta_arr = self.plot_data_queue.get_nowait()
        except Empty:
            return
        with self.fig.batch_update():
            # Column 1 (mapping: traces 0,1)
            self.fig.data[0].x = y_np
            self.fig.data[0].y = z_lin
            self.fig.data[1].x = y_np
            self.fig.data[1].y = zgrid

            # Column 2 (examples): traces 2..7 (bar,pdf)x3
            for r in range(3):
                base = 2 + 2*r
                h = hist_data[r]
                self.fig.data[base + 0].x = h["x"]
                self.fig.data[base + 0].y = h["h"]
                self.fig.data[base + 1].x = h["pdf_x"]
                self.fig.data[base + 1].y = h["pdf_y"]

            # Column 3 (scatter): trace 8
            self.fig.data[8].x = alpha_arr
            self.fig.data[8].y = beta_arr
# ============================================================
# Inverse mapping training: ψ:(0,1)->R learned from per-face
# rating distributions (quantile transport + robust NLL)
# ============================================================

import os, logging, pickle
from pathlib import Path
from typing import Dict, Tuple, List, Optional

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# ------------------ Utilities: bootstrap & I/O ------------------

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DTYPE  = torch.float32

def bootstrap_tensor(data: torch.Tensor) -> torch.Tensor:
    """
    Bootstraps along dim=1 (ratings), preserving NaNs, used by load_interp_data.
    Expects shape (1, N) or (B, N); returns same shape.
    """
    if data.dim() == 1:
        data = data.unsqueeze(0)
    B, N = data.shape
    mask = ~torch.isnan(data)
    out = torch.full_like(data, float('nan'))
    for b in range(B):
        valid = data[b, mask[b]]
        if valid.numel() == 0:
            out[b] = torch.full((N,), 0.5, device=data.device, dtype=data.dtype)
            continue
        idx = torch.randint(0, valid.numel(), (N,), device=data.device)
        out[b] = valid[idx]
    return out

def pad_list(l, max_len):
    return l[:max_len] + [np.nan] * (max_len - len(l[:max_len]))

def load_interp_data(base_dir = "/Users/adamsobieszek/PycharmProjects/PsychGAN/", scale=1) -> Tuple[
    Dict[str, torch.Tensor],
    Dict[str, Dict[str, torch.Tensor]]
]:
    """
    Load latent coordinates (unused here), and ratings with bootstrap per image.
    Returns: (photo_to_coords, dim_to_photo_to_ratings)
    """
    base_dir = Path(base_dir)
    p2c_path = base_dir / "newer_photo_to_coords.pt"
    d2p2r_path = base_dir / "dim_to_photo_to_ratings2.pkl"
    with open(d2p2r_path, "rb") as f:
        dim_to_photo_to_ratings = pickle.load(f)
    photo_to_coords = torch.load(p2c_path, map_location="cpu")
    photo_to_coords = {k: torch.tensor(photo_to_coords[k]).cpu().flatten()[:512] for k in photo_to_coords}
    for k in dim_to_photo_to_ratings:
        max_len = int(max(len(dim_to_photo_to_ratings[k][kk]) for kk in dim_to_photo_to_ratings[k]) * 2.5)
        dim_to_photo_to_ratings[k] = {
            kk: bootstrap_tensor(
                    (((-0.005 if scale!=1 else 0.0) + torch.tensor(pad_list(dim_to_photo_to_ratings[k][kk], max_len))).reshape(1, -1)) * scale
                ).reshape(-1)
            for kk in dim_to_photo_to_ratings[k]
        }
    return photo_to_coords, dim_to_photo_to_ratings

# ------------------ Dataset & Collate ------------------

class ItemRatingsDataset(Dataset):
    """
    One sample = one face (item).
    y_raw: raw ratings as integers [0..100] with NaNs padded (bootstrapped in loader).
    We convert to unit scale (0,1) inside collate.
    """
    def __init__(self,
                 dim_to_photo_to_ratings: Dict[str, Dict[str, torch.Tensor]],
                 target_dim: str = "age",
                 min_ratings: int = 10):
        dims = list(dim_to_photo_to_ratings.keys())
        dim = next((d for d in dims if target_dim.lower() in d.lower()), dims[0])
        self.dim_name = dim
        p2r = dim_to_photo_to_ratings[dim]
        items, ratings = [], []
        for photo, r in p2r.items():
            r = torch.as_tensor(r, dtype=torch.float32)
            n_valid = (~torch.isnan(r)).sum().item()
            if n_valid >= min_ratings:
                items.append(photo)
                ratings.append(r)
        self.items = items
        self.ratings = ratings  # list of 1D tensors with NaNs padded

    def __len__(self): return len(self.items)

    def __getitem__(self, idx):
        return {
            "item_id": idx,
            "photo": self.items[idx],
            "ratings_raw": self.ratings[idx]  # 0..100 with NaNs
        }

def to_unit(y_int: torch.Tensor) -> torch.Tensor:
    # y_int can contain NaNs; keep them
    return torch.where(
        torch.isnan(y_int),
        y_int,
        torch.clamp((y_int + 0.5)/101.0, 1e-6, 1-1e-6)
    )

def collate_items_quantiles(batch: List[dict],
                            quantiles: torch.Tensor,
                            subsample_raw: Optional[int]=None):
    """
    Build a batch:
    - Qy: per-item empirical quantiles (unit scale)
    - y_all: stacked raw unit ratings for optional likelihood (with NaNs removed; possibly subsampled)
    - n_i: counts per item
    """
    item_ids = torch.tensor([b["item_id"] for b in batch], dtype=torch.long)
    # Prepare quantiles and raw ratings (unit)
    Qy_list, y_raw_list, n_list = [], [], []
    for b in batch:
        y_int = b["ratings_raw"].clone().detach()
        y = to_unit(y_int)  # unit in (0,1)
        y_valid = y[~torch.isnan(y)]
        n = y_valid.numel()
        if n == 0:
            # fall back: uniform
            Qy = quantiles.clone()
            yv = torch.tensor([], dtype=torch.float32)
        else:
            Qy = torch.quantile(y_valid, quantiles.to(y_valid.device))
            if (subsample_raw is not None) and (n > subsample_raw):
                idx = torch.randint(0, n, (subsample_raw,), device=y_valid.device)
                yv = y_valid[idx]
            else:
                yv = y_valid
        Qy_list.append(Qy)
        y_raw_list.append(yv)
        n_list.append(n)

    # Pad y_raw_list into a ragged batch (list) – trainer will loop
    batch_data = {
        "item_ids": item_ids,
        "Qy_list": Qy_list,          # list of tensors (K,)
        "y_raw_list": y_raw_list,    # list of tensors (n_i_subsample,)
        "n_list": torch.tensor(n_list, dtype=torch.float32),
    }
    return batch_data

# %%
# --- NEW: compute item location statistic over [0,1] ---
def compute_item_locations_unit(dataset, stat="mean"):
    ms = []
    for r in dataset.ratings:
        y_int = r.clone().float()
        y = torch.where(torch.isnan(y_int), y_int, torch.clamp((y_int + 0.5)/101.0, 1e-6, 1-1e-6))
        y = y[~torch.isnan(y)]
        if y.numel() == 0:
            ms.append(0.5)
        else:
            ms.append(float(y.mean() if stat == "mean" else y.median()))
    return np.array(ms, dtype=np.float64)

# --- NEW: simple, stable density-reweighting over m in [0,1] via histogram ---
def make_density_weights_from_m(ms, bins=20, target="uniform",
                                clip_min=0.33, clip_max=3.0, gamma=0.75, eps=1e-6) -> torch.Tensor:
    ms = np.clip(ms, 1e-6, 1-1e-6)
    hist, edges = np.histogram(ms, bins=bins, range=(0,1), density=False)
    N = ms.shape[0]
    binwidth = (edges[1] - edges[0])
    # empirical density per unit x
    dens = (hist + eps) / (N * binwidth + eps * bins)
    # map each m to its bin density
    idx = np.minimum(bins-1, (ms * bins).astype(int))
    p_emp = dens[idx]
    # target density: uniform on [0,1] => 1.0 per unit x
    if target == "uniform":
        p_tgt = np.ones_like(p_emp)
    else:
        # placeholder for custom target; default to uniform
        p_tgt = np.ones_like(p_emp)

    w = p_tgt / (p_emp + eps)
    w = np.clip(w, clip_min, clip_max) ** gamma
    w = w / w.mean()  # normalize to mean 1
    return torch.tensor(w, dtype=DTYPE)

# %%
def to_unit(y_int: torch.Tensor) -> torch.Tensor:
    # y_int can contain NaNs; keep them
    return torch.where(
        torch.isnan(y_int),
        y_int,
        torch.clamp((y_int + 0.5)/101.0, 1e-6, 1-1e-6)
    )
# --- NEW: draw uniform-in-logit within each integer bin (fast, vectorized) ---
def sample_unit_from_integer_logit_bins(y_int: torch.Tensor, eps: float = 1e-4) -> torch.Tensor:
    """
    y_int: 1D tensor of integers in [0..100] with possible NaNs.
    returns: 1D tensor of sampled y in (0,1), NaNs removed.
    """
    r = y_int.clone().to(torch.float32)
    mask = ~torch.isnan(r)
    if not mask.any():
        return torch.tensor([], dtype=torch.float32, device=y_int.device)

    r = r[mask]                                  # valid ints
    lo = (r - 0.5) / 101.0
    hi = (r + 0.5) / 101.0
    lo = torch.clamp(lo, eps, 1.0 - eps)        # ends: [eps, 1-eps]
    hi = torch.clamp(hi, eps, 1.0 - eps)

    l0 = torch.logit(lo)
    l1 = torch.logit(hi)
    u  = torch.rand_like(l0)
    l  = l0 + u * (l1 - l0)                      # uniform in logit
    y  = torch.sigmoid(l)
    return torch.clamp(y, 1e-6, 1-1e-6)
# --- EDIT: collate now does the logit-bin jitter; no external sampler needed ---
def collate_items_quantiles(batch: List[dict],
                            quantiles: torch.Tensor,
                            subsample_raw: Optional[int] = None,
                            logit_bin_jitter: bool = True,
                            eps: float = 1e-4):
    item_ids = torch.tensor([b["item_id"] for b in batch], dtype=torch.long)
    Qy_list, y_raw_list, n_list = [], [], []

    for b in batch:
        y_int = b["ratings_raw"].clone().detach()
        if logit_bin_jitter:
            y = sample_unit_from_integer_logit_bins(y_int, eps=eps)
        else:
            y = to_unit(y_int)
            y = y[~torch.isnan(y)]

        n = y.numel()
        if n == 0:
            Qy = quantiles.clone()
            yv = torch.tensor([], dtype=torch.float32, device=y_int.device)
        else:
            if (subsample_raw is not None) and (n > subsample_raw):
                idx = torch.randint(0, n, (subsample_raw,), device=y.device)
                yv = y[idx]
            else:
                yv = y
            Qy = torch.quantile(y, quantiles.to(y.device))

        Qy_list.append(Qy)
        y_raw_list.append(yv)
        n_list.append(n)

    return {
        "item_ids": item_ids,
        "Qy_list": Qy_list,
        "y_raw_list": y_raw_list,
        "n_list": torch.tensor(n_list, dtype=torch.float32),
    }

# %%
# ============================================
# Monotone inverse-scale training WITHOUT item embeddings
# Per-item μ,σ are estimated a posteriori in transformed space
# and tracked with an EMA used for the OT target.
# ============================================

import os, sys, logging
from typing import List, Optional, Tuple, Dict

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

# Assumes the following are already defined in the notebook/session:
# - LiveInverseMappingVisualizer
# - DEVICE, DTYPE
# - load_interp_data, ItemRatingsDataset, to_unit, collate_items_quantiles

# ------------------ Monotone ψ model ------------------

class MonoPsiGrid(nn.Module):
    """
    Global monotone map ψ on y∈(0,1) via positive derivative on a uniform grid.
    ψ(0)=0 (reference). Strictly increasing via softplus on derivative.
    """
    def __init__(self, M:int=200, eps_floor:float=1e-4):
        super().__init__()
        self.M = int(M)
        self.register_buffer("y_grid", torch.linspace(0., 1., self.M, dtype=DTYPE))
        self.rho = nn.Parameter(torch.zeros(self.M, dtype=DTYPE))   # unconstrained per-grid derivative params
        self.eps_floor = float(eps_floor)
        # Optional global affine (helps gauge/identification)
        self.shift = nn.Parameter(torch.tensor(0., dtype=DTYPE))
        self.scale = nn.Parameter(torch.tensor(1., dtype=DTYPE))

    def deriv_at_grid(self) -> torch.Tensor:
        # ψ'(y_m) = eps + softplus(rho_m)
        return self.eps_floor + torch.nn.functional.softplus(self.rho)

    def psi_grid_values(self) -> torch.Tensor:
        # Integrate derivative over grid (trapezoid). Baseline ψ(0)=0, then apply affine.
        d = self.deriv_at_grid()
        y = self.y_grid
        h = y[1]-y[0]
        d_left  = d[:-1]
        d_right = d[1:]
        inc = 0.5*h*(d_left + d_right)              # area per interval
        psi0 = torch.zeros(1, dtype=DTYPE, device=d.device)
        psi_vals = torch.cat([psi0, torch.cumsum(inc, dim=0)], dim=0)  # length M
        return self.shift + self.scale * psi_vals

    def forward(self, y_query: torch.Tensor) -> torch.Tensor:
        """
        y_query: (...,) in (0,1); returns ψ(y_query).
        Linear interpolation on ψ grid; differentiable w.r.t. parameters.
        """
        y = torch.clamp(y_query, 1e-6, 1-1e-6)
        psi_vals = self.psi_grid_values()
        idx_right = torch.searchsorted(self.y_grid, y)
        idx_right = torch.clamp(idx_right, 1, self.M-1)
        idx_left = idx_right - 1
        y0 = self.y_grid[idx_left]
        y1 = self.y_grid[idx_right]
        psi0 = psi_vals[idx_left]
        psi1 = psi_vals[idx_right]
        t = (y - y0) / torch.clamp(y1 - y0, 1e-12)
        return psi0 + t*(psi1 - psi0)

    # Regularizers
    def curvature_penalty(self) -> torch.Tensor:
        psi = self.psi_grid_values()
        d2 = psi[:-2] - 2*psi[1:-1] + psi[2:]
        return torch.mean(d2**2)

    def floor_barrier(self) -> torch.Tensor:
        d = self.deriv_at_grid()
        target = 2.0*self.eps_floor
        return torch.mean(torch.nn.functional.softplus(target - d)**2)

# ------------------ EMA over per-item μ,σ in transformed space ------------------

class PerItemEMA:
    """
    Track EMA of per-item μ,σ of z=ψ(y), updated from a posteriori batch estimates.
    """
    def __init__(self, num_items:int, alpha:float=0.1, sigma_floor:float=1e-6, device=None, dtype=torch.float32):
        self.num_items   = int(num_items)
        self.alpha       = float(alpha)
        self.sigma_floor = float(sigma_floor)
        self.mu    = torch.zeros(self.num_items, dtype=dtype, device=device)
        self.sigma = torch.ones (self.num_items, dtype=dtype, device=device)

    @torch.no_grad()
    def init_from_loader(self, loader: DataLoader, psi: MonoPsiGrid, device):
        """
        One quick pass to initialize EMA from current ψ.
        Uses all available ratings from the loader.
        """
        psi.eval()
        counts = torch.zeros(self.num_items, dtype=self.mu.dtype, device=device)
        tmp_mu = torch.zeros_like(self.mu)
        tmp_sd = torch.ones_like(self.sigma)  # start from 1

        for batch in loader:
            ids = batch["item_ids"].to(device)
            for i, y_unit in enumerate(batch["y_raw_list"]):
                if y_unit.numel() == 0:
                    continue
                z = psi(to_unit(y_unit.to(device)))
                m = z.mean()
                s = torch.clamp(z.std(unbiased=False), self.sigma_floor)
                tmp_mu[ids[i]] = m
                tmp_sd[ids[i]] = s
                counts[ids[i]] = 1

        mask = counts > 0
        self.mu[mask]    = tmp_mu[mask]
        self.sigma[mask] = tmp_sd[mask]

    @torch.no_grad()
    def update_batch(self, item_ids: torch.Tensor, mu_hat: torch.Tensor, sigma_hat: torch.Tensor):
        a = self.alpha
        self.mu[item_ids]    = (1 - a) * self.mu[item_ids]    + a * mu_hat
        self.sigma[item_ids] = (1 - a) * self.sigma[item_ids] + a * torch.clamp(sigma_hat, self.sigma_floor)

class EMAShim(nn.Module):
    """
    Lightweight shim so the LiveInverseMappingVisualizer can query μ,σ
    like an embedding module: forward(item_ids) -> (mu[:,1], sigma[:,1]).
    """
    def __init__(self, ema: PerItemEMA):
        super().__init__()
        self.ema = ema
    def forward(self, item_ids: torch.Tensor):
        mu = self.ema.mu[item_ids].unsqueeze(-1)
        sigma = self.ema.sigma[item_ids].unsqueeze(-1)
        return mu, sigma

# ------------------ Loss helpers ------------------

def normal_quantiles(tau: torch.Tensor, device=None, dtype=None) -> torch.Tensor:
    dist = torch.distributions.Normal(
        loc=torch.tensor(0., device=device, dtype=dtype),
        scale=torch.tensor(1., device=device, dtype=dtype)
    )
    return dist.icdf(torch.clamp(tau, 1e-6, 1-1e-6))

def estimate_mu_sigma_from_transformed(z: torch.Tensor, sigma_floor: float = 1e-6) -> Tuple[torch.Tensor, torch.Tensor]:
    if z.numel() == 0:
        return torch.tensor(0., dtype=z.dtype, device=z.device), torch.tensor(1., dtype=z.dtype, device=z.device)
    mu = torch.mean(z)
    sd = torch.clamp(z.std(unbiased=False), sigma_floor)
    return mu, sd

def ot_quantile_loss_with_ema(
    psi: MonoPsiGrid,
    item_ids: torch.Tensor,
    Qy_list: List[torch.Tensor],
    ema: PerItemEMA,
    tau: torch.Tensor,
    weights_per_item: Optional[torch.Tensor]=None
) -> torch.Tensor:
    device = item_ids.device
    q_norm = normal_quantiles(tau.to(device), device=device, dtype=DTYPE)
    losses = []
    for b, Qy in enumerate(Qy_list):
        if Qy.numel() == 0:
            continue
        z_q = psi(Qy.to(device))  # ψ(Q_y(τ))
        mu_tgt    = ema.mu[item_ids[b]]
        sigma_tgt = torch.clamp(ema.sigma[item_ids[b]], 1e-6)
        target = mu_tgt + sigma_tgt * q_norm
        e = z_q - target
        l = torch.mean(e**2)
        if weights_per_item is not None:
            l = l * weights_per_item[b]
        losses.append(l)
    if not losses:
        return torch.tensor(0., device=device)
    return torch.mean(torch.stack(losses))

def student_t_nll_aposteriori(
    psi: MonoPsiGrid,
    item_ids: torch.Tensor,
    y_raw_list: List[torch.Tensor],
    nu: float = 6.0,
    sigma_floor: float = 1e-6,
    weights_per_item: Optional[torch.Tensor] = None,
    weight_gamma: float = 1.0
) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
    """
    Robust NLL with per-item μ̂,σ̂ estimated from current transformed ratings.
    Returns: (mean_nll, mu_hat_vec[B], sigma_hat_vec[B])
    """
    device = item_ids.device
    nu_t = torch.tensor(nu, device=device, dtype=DTYPE)
    losses, mu_hats, sigma_hats = [], [], []
    for b, y_unit in enumerate(y_raw_list):
        if y_unit.numel() == 0:
            mu_hat = torch.tensor(0., device=device, dtype=DTYPE)
            sigma_hat = torch.tensor(1., device=device, dtype=DTYPE)
            mu_hats.append(mu_hat); sigma_hats.append(sigma_hat)
            continue
        z = psi(to_unit(y_unit.to(device)))
        mu_hat, sigma_hat = estimate_mu_sigma_from_transformed(z, sigma_floor=sigma_floor)
        mu_hats.append(mu_hat); sigma_hats.append(sigma_hat)
        r = (z - mu_hat) / sigma_hat
        term = ((nu_t + 1.)/2.) * torch.log1p((r**2)/nu_t)
        nll = torch.mean(term) + torch.log(sigma_hat)
        if weights_per_item is not None:
            w = torch.clamp(weights_per_item[b], 1e-6)
            nll = nll * (w ** weight_gamma)
        losses.append(nll)
    if not losses:
        return torch.tensor(0., device=device), torch.stack(mu_hats), torch.stack(sigma_hats)
    return torch.mean(torch.stack(losses)), torch.stack(mu_hats), torch.stack(sigma_hats)

def identification_penalty_on_batch(mu_batch: torch.Tensor, lambda_mean: float = 1.0, lambda_var: float = 1.0) -> torch.Tensor:
    """
    Softly set the gauge via batch EMA μ statistics: mean ≈ 0, var ≈ 1.
    """
    if mu_batch.numel() == 0:
        return torch.tensor(0., device=mu_batch.device, dtype=mu_batch.dtype)
    m  = mu_batch.mean()
    v  = mu_batch.pow(2).mean()   # since target mean is 0, var = E[mu^2]
    return lambda_mean * (m**2) + lambda_var * (v - 1.)**2

# ------------------ Optional: item-density reweighting helpers ------------------

@torch.no_grad()
def compute_item_locations_unit(dataset, stat:str="mean") -> torch.Tensor:
    """
    Compute per-item location on unit scale using raw ratings in dataset.ratings.
    """
    locs = []
    for r in dataset.ratings:
        y_int = r.clone().float()
        y = torch.where(torch.isnan(y_int), y_int,
                        torch.clamp((y_int + 0.5)/101.0, 1e-6, 1-1e-6))
        y = y[~torch.isnan(y)]
        if y.numel() == 0:
            locs.append(0.5)
        else:
            if stat == "median":
                locs.append(float(y.median()))
            else:
                locs.append(float(y.mean()))
    return torch.tensor(locs, dtype=DTYPE)

def make_density_weights_from_m(
    m_all: torch.Tensor,
    bins: int = 30,
    target: str = "uniform",
    clip_min: float = 0.2,
    clip_max: float = 5.0,
    gamma: float = 1.0
) -> torch.Tensor:
    """
    Compute inverse-frequency weights over item locations m_all in [0,1].
    """
    m_np = m_all.detach().cpu().numpy()
    hist, edges = np.histogram(m_np, bins=bins, range=(0.0, 1.0), density=False)
    hist = hist.astype(np.float64) + 1e-8
    p_emp = hist / hist.sum()
    if target == "uniform":
        p_tgt = np.ones_like(p_emp) / len(p_emp)
    else:
        p_tgt = np.ones_like(p_emp) / len(p_emp)
    w_bin = p_tgt / p_emp
    # Map each item to its bin
    bin_idx = np.clip(np.digitize(m_np, edges[:-1], right=False) - 1, 0, len(p_emp)-1)
    w_items = w_bin[bin_idx]
    w_items = np.clip(w_items, clip_min, clip_max) ** gamma
    w = torch.tensor(w_items, dtype=DTYPE, device=DEVICE)
    # Normalize to mean 1
    return w / (w.mean() + 1e-8)

# ------------------ Trainer (no embeddings; with EMA) ------------------

class InverseScaleTrainer:

    def __init__(self,
                 psi_model: MonoPsiGrid,
                 num_items: int,
                 config: dict,
                 visualizer=None,
                 item_density_weights: Optional[torch.Tensor] = None):
        self.psi = psi_model.to(DEVICE)
        self.cfg = config
        self.visualizer = visualizer

        # EMA over transformed μ,σ
        ema_alpha = self.cfg.get("ema", {}).get("alpha", 0.1)
        self.ema = PerItemEMA(num_items=num_items,
                              alpha=ema_alpha,
                              sigma_floor=self.cfg["model"].get("sigma_min", 1e-5),
                              device=DEVICE, dtype=DTYPE)
        self.ema_shim = EMAShim(self.ema).to(DEVICE)

        self.item_density_weights = item_density_weights
        self.quantiles = torch.tensor(config["model"]["quantiles"], dtype=DTYPE)

        params = list(self.psi.parameters())
        try:
            sys.path.append('/Users/adamsobieszek/PycharmProjects/_manipy/deixis/pixel2style2pixel/training')
            from ranger import Ranger  # optional optimizer
            self.opt = Ranger(params, lr=config["training"]["learning_rate"])
        except Exception:
            self.opt = optim.AdamW(params,
                                   lr=config["training"]["learning_rate"],
                                   weight_decay=config["training"]["weight_decay"])
        self.scheduler = optim.lr_scheduler.CosineAnnealingLR(
            self.opt,
            T_max=config["training"]["epochs"] * config["training"]["steps_per_epoch_estimate"]
        )

    def train_epoch(self, loader: DataLoader, epoch: int = 0, phase: str = "train") -> dict:
        train = (phase == "train")
        self.psi.train(train)

        logs = {"ot": 0., "nll": 0., "curv": 0., "floor": 0., "id": 0.}
        tot = 0.0

        for step, batch in enumerate(loader):
            item_ids   = batch["item_ids"].to(DEVICE)
            Qy_list    = batch["Qy_list"]
            y_raw_list = batch["y_raw_list"]
            n_list     = batch["n_list"].to(DEVICE)

            # ---- item weights ----
            if getattr(self, "item_density_weights", None) is not None and self.cfg["reweighting"]["enabled"]:
                w_density = self.item_density_weights[item_ids]
            else:
                w_density = torch.ones_like(n_list)

            scheme = self.cfg["training"].get("item_weighting", "none")
            if scheme == "n":
                w_n = n_list
            elif scheme == "sqrt_n":
                w_n = torch.sqrt(torch.clamp(n_list, 1))
            else:
                w_n = torch.ones_like(n_list)

            pow_n = float(self.cfg["reweighting"].get("n_weight_power", 0.0))
            if pow_n != 0.0:
                n_scaled = (n_list / (n_list.mean() + 1e-8)).clamp(1e-3)
                w_n = w_n * (n_scaled ** pow_n)

            w_items = (w_density * w_n)
            w_items = w_items / (w_items.mean() + 1e-8)

            # ---- Loss weights ----
            ot_w     = self.cfg["loss_weights"]["ot"]
            nll_w    = self.cfg["loss_weights"]["nll"]
            curv_w   = self.cfg["loss_weights"]["curv"]
            floor_w  = self.cfg["loss_weights"]["floor"]
            id_w     = self.cfg["loss_weights"]["id"]

            # ---- NLL a posteriori; also gather μ̂,σ̂ for EMA ----
            loss_nll, mu_hat_vec, sigma_hat_vec = student_t_nll_aposteriori(
                self.psi, item_ids, y_raw_list,
                nu=self.cfg["model"]["student_t_nu"],
                sigma_floor=self.cfg["model"]["sigma_min"],
                weights_per_item=w_items if self.cfg["reweighting"].get("apply_to_nll", True) else None,
                weight_gamma=float(self.cfg["reweighting"].get("nll_gamma", 0.5))
            )

            # ---- EMA update (training only) ----
            if train:
                self.ema.update_batch(item_ids, mu_hat_vec.detach(), sigma_hat_vec.detach())

            # ---- OT quantile loss vs EMA μ̄,σ̄ ----
            loss_ot = ot_quantile_loss_with_ema(
                self.psi, item_ids, Qy_list, self.ema,
                tau=self.quantiles, weights_per_item=w_items
            )

            # ---- Regularizers & identification ----
            loss_curv  = self.psi.curvature_penalty()
            loss_floor = self.psi.floor_barrier()
            mu_ema_batch = self.ema.mu[item_ids]
            loss_id = identification_penalty_on_batch(mu_ema_batch, lambda_mean=1.0, lambda_var=1.0)

            # ---- Total ----
            loss = (ot_w * loss_ot
                    + nll_w * loss_nll
                    + curv_w * loss_curv
                    + floor_w * loss_floor
                    + id_w * loss_id)

            if train:
                self.opt.zero_grad(set_to_none=True)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(list(self.psi.parameters()), max_norm=self.cfg["training"]["grad_clip_norm"])
                self.opt.step()
                self.scheduler.step()

            tot += float(loss.item())
            logs["ot"]   += float(loss_ot.item())
            logs["nll"]  += float(loss_nll.item())
            logs["curv"] += float(loss_curv.item())
            logs["floor"]+= float(loss_floor.item())
            logs["id"]   += float(loss_id.item())

            # Live visualizer (uses EMA shim)
            if self.visualizer and (phase == "train"):
                try:
                    self.visualizer.update_async(self.psi, self.ema_shim)
                    self.visualizer.check_and_update_plot()
                except Exception:
                    pass

            if (step + 1) % self.cfg["logging"]["print_every"] == 0:
                avg = {k: v / (step + 1) for k, v in logs.items()}
                logging.info(
                    f"[{phase}] epoch {epoch} step {step+1}/{len(loader)} "
                    + " ".join(f"{k}:{avg[k]:.4f}" for k in avg)
                )

        N = max(1, len(loader))
        return {k: v / N for k, v in logs.items()} | {"total": tot / N}

# ------------------ Config ------------------

CONFIG = {
    "data": {
        "dimension": "age",
        "min_ratings": 10,
        "val_split": 0.1,
        "subsample_raw_for_nll": 256,  # None or int
        "base_dir": "/Users/adamsobieszek/PycharmProjects/PsychGAN/"
    },
    "model": {
        "grid_M": 200,
        "eps_floor": 1/400,
        "student_t_nu": 6.0,
        "quantiles": [*np.arange(0.01, 0.991, 0.01)],
        "sigma_min": 1e-5
    },
    "loss_weights": {
        "ot":   1.0,
        "nll":  1.0,
        "curv": 0.0,
        "floor":1e-2,
        "id":   10.0
    },
    "training": {
        "epochs": 2000,
        "batch_size": 64,
        "learning_rate": 8e-4,Not a work day on Oct 31, 2025 at 12:00 midnight - 11:59 PM

        "weight_decay": 1e-3,
        "grad_clip_norm": 1.0,
        "item_weighting": "n",           # {"n","sqrt_n","none"}
        "steps_per_epoch_estimate": 200
    },
    "logging": {
        "level": "INFO",
        "print_every": 10,
        "plot_every_steps": 30
    },
    "reweighting": {
        "enabled": False,
        "stat": "mean",
        "bins": 30,
        "target": "uniform",
        "clip_min": 0.2,
        "clip_max": 5.0,
        "gamma": 1.0,
        "apply_to_nll": True,
        "nll_gamma": 0.50,
        "n_weight_power": 0.0
    },
    "ema": {
        "alpha": 0.1
    }
}

logging.basicConfig(level=CONFIG["logging"]["level"])

# ------------------ Main (training script) ------------------

if __name__ == "__main__":
    # Load data
    _, dim_to_photo_to_ratings = load_interp_data(
        base_dir=CONFIG["data"]["base_dir"], scale=101
    )

    # Optional filtering (example from your previous script)
    dim_to_photo_to_ratings = {
        k: {kk: vv for kk, vv in v.items() if torch.mean(vv) > 10}
        for k, v in dim_to_photo_to_ratings.items()
    }

    # Dataset & split
    ds = ItemRatingsDataset(dim_to_photo_to_ratings,
                            target_dim=CONFIG["data"]["dimension"],
                            min_ratings=CONFIG["data"]["min_ratings"])
    N = len(ds)
    idx = np.arange(N); np.random.shuffle(idx)
    n_val = max(1, int(CONFIG["data"]["val_split"] * N))
    val_idx = idx[:n_val]; train_idx = idx[n_val:]

    ds_train = torch.utils.data.Subset(ds, train_idx.tolist())
    ds_val   = torch.utils.data.Subset(ds, val_idx.tolist())

    def _collate(batch):
        return collate_items_quantiles(
            batch,
            quantiles=torch.tensor(CONFIG["model"]["quantiles"], dtype=DTYPE),
            subsample_raw=CONFIG["data"]["subsample_raw_for_nll"]
        )

    train_loader = DataLoader(ds_train, batch_size=CONFIG["training"]["batch_size"],
                              shuffle=True, num_workers=0, collate_fn=_collate)
    val_loader   = DataLoader(ds_val, batch_size=CONFIG["training"]["batch_size"],
                              shuffle=False, num_workers=0, collate_fn=_collate)

    # Model
    psi = MonoPsiGrid(M=CONFIG["model"]["grid_M"], eps_floor=CONFIG["model"]["eps_floor"]).to(DEVICE)

    # (Optional) quick gauge calibration: shift/scale ψ so initial EMA μ ~ N(0,1)
    with torch.no_grad():
        tmp_ema = PerItemEMA(num_items=N, alpha=1.0, sigma_floor=CONFIG["model"]["sigma_min"], device=DEVICE, dtype=DTYPE)
        tmp_loader = DataLoader(ds_train, batch_size=CONFIG["training"]["batch_size"],
                                shuffle=False, num_workers=0, collate_fn=_collate)
        tmp_ema.init_from_loader(tmp_loader, psi, DEVICE)
        mu_mean = tmp_ema.mu.mean()
        mu_std  = tmp_ema.mu.std(unbiased=False).clamp(1e-6)
        psi.shift.data = psi.shift.data - mu_mean
        psi.scale.data = psi.scale.data / mu_std

    # Visualizer
    try:
        live_vis = LiveInverseMappingVisualizer(dataset=ds, example_item_ids=None)
    except Exception:
        live_vis = None

    # Optional item-density weights
    if CONFIG["reweighting"]["enabled"]:
        m_all = compute_item_locations_unit(ds, stat=CONFIG["reweighting"]["stat"])
        density_w_all = make_density_weights_from_m(
            m_all,
            bins=CONFIG["reweighting"]["bins"],
            target=CONFIG["reweighting"]["target"],
            clip_min=CONFIG["reweighting"]["clip_min"],
            clip_max=CONFIG["reweighting"]["clip_max"],
            gamma=CONFIG["reweighting"]["gamma"]
        ).to(DEVICE)
    else:
        density_w_all = None

    trainer = InverseScaleTrainer(
        psi_model=psi,
        num_items=N,
        config=CONFIG,
        visualizer=live_vis,
        item_density_weights=density_w_all
    )

    # Initialize EMA from current ψ on the train set
    trainer.ema.init_from_loader(train_loader, trainer.psi, DEVICE)

    best_val = float("inf")
    for epoch in range(1, CONFIG["training"]["epochs"]+1):
        tr = trainer.train_epoch(train_loader, epoch, phase="train")
        vl = trainer.train_epoch(val_loader,   epoch, phase="val")

        # Force a plot refresh at epoch end
        if live_vis:
            try:
                live_vis.update_async(trainer.psi, trainer.ema_shim)
                live_vis.check_and_update_plot()
            except Exception:
                pass

        val_score = vl["ot"] + CONFIG["loss_weights"]["nll"] * vl["nll"]
        logging.info(f"Epoch {epoch:03d} | "
                     f"train total={tr['total']:.4f} "
                     + " ".join([f"{k}:{v:.4f}" for k, v in tr.items() if k!='total'])
                     + " || val "
                     + " ".join([f"{k}:{v:.4f}" for k, v in vl.items()]))

        if val_score < best_val:
            best_val = val_score
            os.makedirs("checkpoints", exist_ok=True)
            torch.save({
                "psi": trainer.psi.state_dict(),
                "ema_mu": trainer.ema.mu.detach().cpu(),
                "ema_sigma": trainer.ema.sigma.detach().cpu(),
                "config": CONFIG
            }, "checkpoints/inverse_mapping_best.pt")
            logging.info(f"Saved best model (val score={best_val:.4f})")

    logging.info("Done.")
# Out:
# /var/folders/nc/zbqbbkkx08z7v1g3mlf8bdn00000gn/T/ipykernel_73841/1230419096.py:284: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   photo_to_coords = {k: torch.tensor(photo_to_coords[k]).cpu().flatten()[:512] for k in photo_to_coords}
# FigureWidget({
#     'data': [{'line': {'color': 'gray', 'dash': 'dash', 'width': 2},
#               'mode': 'lines',
#               'name': 'baseline',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd7d2f25e-aef2-43d6-94da-35f87f12a19c',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'red', 'width': 3},
#               'mode': 'lines',
#               'name': 'psi',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '675052d8-b5b9-4d1e-b662-45704a18425e',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'marker': {'color': '#729ECE', 'opacity': 0.45},
#               'name': 'hist1',
#               'showlegend': False,
#               'type': 'bar',
#               'uid': '1ac3a77f-5dd1-410d-9047-6775dc8e7db2',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': '#729ECE', 'width': 2},
#               'mode': 'lines',
#               'name': 'pdf1',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '695f6bf2-d18d-462d-bcca-95456c4cdb10',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'marker': {'color': '#8EBA42', 'opacity': 0.45},
#               'name': 'hist2',
#               'showlegend': False,
#               'type': 'bar',
#               'uid': '496a6708-d535-4800-be18-3c5a95add4c5',
#               'xaxis': 'x4',
#               'yaxis': 'y4'},
#              {'line': {'color': '#8EBA42', 'width': 2},
#               'mode': 'lines',
#               'name': 'pdf2',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ecbec46d-fdc8-4af0-b5f2-46bb1175c06b',
#               'xaxis': 'x4',
#               'yaxis': 'y4'},
#              {'marker': {'color': '#FF9DA7', 'opacity': 0.45},
#               'name': 'hist3',
#               'showlegend': False,
#               'type': 'bar',
#               'uid': '07226310-3fcc-4069-9c6d-78e056cff5a5',
#               'xaxis': 'x5',
#               'yaxis': 'y5'},
#              {'line': {'color': '#FF9DA7', 'width': 2},
#               'mode': 'lines',
#               'name': 'pdf3',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'c0937d5a-758b-4245-aa06-cd6d7dc53071',
#               'xaxis': 'x5',
#               'yaxis': 'y5'},
#              {'marker': {'color': '#444', 'opacity': 0.6, 'size': 6},
#               'mode': 'markers',
#               'name': 'Beta αβ',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '402852bb-af1b-48bb-bf33-120a37fe2db8',
#               'xaxis': 'x3',
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Mapping ψ(y) (red) & Best Linear Baseline (gray)',
#                                 'x': 0.23833333333333337,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Example #484',
#                                 'x': 0.6516666666666668,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Example #1127',
#                                 'x': 0.9133333333333333,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Beta(α, β) over items',
#                                 'x': 0.6516666666666668,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.6111111111111112,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Example #750',
#                                 'x': 0.6516666666666668,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.22222222222222224,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 760,
#                'margin': {'b': 40, 'l': 50, 'r': 20, 't': 60},
#                'template': '...',
#                'title': {'text': 'Live Inverse Mapping Training'},
#                'width': 1800,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 0.47666666666666674], 'title': {'text': 'y (slider in [0,1])'}},
#                'xaxis2': {'anchor': 'y2',
#                           'domain': [0.5433333333333334, 0.7600000000000001],
#                           'title': {'text': 'z = ψ(y)'}},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.8266666666666667, 1.0], 'title': {'text': 'α (Beta)'}},
#                'xaxis4': {'anchor': 'y4',
#                           'domain': [0.5433333333333334, 0.7600000000000001],
#                           'title': {'text': 'z = ψ(y)'}},
#                'xaxis5': {'anchor': 'y5',
#                           'domain': [0.5433333333333334, 0.7600000000000001],
#                           'title': {'text': 'z = ψ(y)'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'ψ(y)'}},
#                'yaxis2': {'anchor': 'x2', 'domain': [0.7777777777777778, 1.0], 'title': {'text': 'density'}},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 1.0], 'title': {'text': 'β (Beta)'}},
#                'yaxis4': {'anchor': 'x4',
#                           'domain': [0.3888888888888889, 0.6111111111111112],
#                           'title': {'text': 'density'}},
#                'yaxis5': {'anchor': 'x5', 'domain': [0.0, 0.22222222222222224], 'title': {'text': 'density'}}}
# })
# /Users/adamsobieszek/PycharmProjects/_manipy/deixis/pixel2style2pixel/training/ranger.py:123: UserWarning:
#
# This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value = 1) (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/python_arg_parser.cpp:1691.)
#
# INFO:root:[train] epoch 1 step 10/17 ot:18370.3357 nll:-1.0702 curv:0.0000 floor:0.1651 id:84.5013
# INFO:root:Epoch 001 | train total=19126.7160 ot:18285.8828 nll:-1.0659 curv:0.0000 floor:0.1651 id:84.1897 || val ot:18633.0029 nll:-1.0599 curv:0.0000 floor:0.1651 id:1.0000 total:18641.9443
# INFO:root:Saved best model (val score=18631.9430)
# INFO:root:[train] epoch 2 step 10/17 ot:18443.6910 nll:-1.0580 curv:0.0000 floor:0.1651 id:84.8756
# INFO:root:Epoch 002 | train total=19090.5491 ot:18250.7410 nll:-1.0665 curv:0.0000 floor:0.1652 id:84.0873 || val ot:18609.5225 nll:-1.0608 curv:0.0000 floor:0.1652 id:1.0000 total:18618.4639
# INFO:root:Saved best model (val score=18608.4616)
# INFO:root:[train] epoch 3 step 10/17 ot:18211.4066 nll:-1.0621 curv:0.0000 floor:0.1652 id:84.0946
# INFO:root:Epoch 003 | train total=19089.6237 ot:18249.5633 nll:-1.0676 curv:0.0000 floor:0.1652 id:84.1126 || val ot:18588.8760 nll:-1.0612 curv:0.0000 floor:0.1653 id:1.0000 total:18597.8164
# INFO:root:Saved best model (val score=18587.8148)
# INFO:root:[train] epoch 4 step 10/17 ot:18033.7090 nll:-1.0695 curv:0.0000 floor:0.1653 id:83.1134
# INFO:root:Epoch 004 | train total=19053.9145 ot:18215.1420 nll:-1.0674 curv:0.0000 floor:0.1654 id:83.9838 || val ot:18559.7842 nll:-1.0623 curv:0.0000 floor:0.1654 id:1.0000 total:18568.7236
# INFO:root:Saved best model (val score=18558.7219)
# INFO:root:[train] epoch 5 step 10/17 ot:18011.3443 nll:-1.0697 curv:0.0000 floor:0.1655 id:82.9699
# INFO:root:Epoch 005 | train total=19047.7891 ot:18209.0095 nll:-1.0680 curv:0.0000 floor:0.1655 id:83.9846 || val ot:18526.0332 nll:-1.0631 curv:0.0000 floor:0.1656 id:1.0000 total:18534.9727
# INFO:root:Saved best model (val score=18524.9701)
# INFO:root:[train] epoch 6 step 10/17 ot:18291.0337 nll:-1.0706 curv:0.0000 floor:0.1656 id:84.2945
# INFO:root:Epoch 006 | train total=18962.5366 ot:18126.7486 nll:-1.0693 curv:0.0000 floor:0.1656 id:83.6855 || val ot:18491.5527 nll:-1.0641 curv:0.0000 floor:0.1657 id:1.0000 total:18500.4902
# INFO:root:Saved best model (val score=18490.4886)
# INFO:root:[train] epoch 7 step 10/17 ot:17741.4263 nll:-1.0726 curv:0.0000 floor:0.1658 id:82.2568
# INFO:root:Epoch 007 | train total=18959.5432 ot:18124.3776 nll:-1.0708 curv:0.0000 floor:0.1658 id:83.6235 || val ot:18433.7158 nll:-1.0657 curv:0.0000 floor:0.1659 id:1.0000 total:18442.6514
# INFO:root:Saved best model (val score=18432.6501)
# INFO:root:[train] epoch 8 step 10/17 ot:18967.4130 nll:-1.0676 curv:0.0000 floor:0.1659 id:86.9810
# INFO:root:Epoch 008 | train total=18847.8957 ot:18017.0674 nll:-1.0720 curv:0.0000 floor:0.1660 id:83.1899 || val ot:18392.9072 nll:-1.0663 curv:0.0000 floor:0.1661 id:1.0000 total:18401.8428
# INFO:root:Saved best model (val score=18391.8410)
# INFO:root:[train] epoch 9 step 10/17 ot:17888.3162 nll:-1.0615 curv:0.0000 floor:0.1661 id:82.5316
# INFO:root:Epoch 009 | train total=18886.5707 ot:18054.9723 nll:-1.0727 curv:0.0000 floor:0.1662 id:83.2669 || val ot:18346.5098 nll:-1.0676 curv:0.0000 floor:0.1663 id:1.0000 total:18355.4443
# INFO:root:Saved best model (val score=18345.4422)
# INFO:root:[train] epoch 10 step 10/17 ot:18748.7335 nll:-1.0520 curv:0.0000 floor:0.1663 id:86.0548
# INFO:root:Epoch 010 | train total=18735.9408 ot:17911.5226 nll:-1.0751 curv:0.0000 floor:0.1664 id:82.5491 || val ot:18301.7520 nll:-1.0685 curv:0.0000 floor:0.1665 id:1.0000 total:18310.6855
# INFO:root:Saved best model (val score=18300.6835)
# INFO:root:[train] epoch 11 step 10/17 ot:18340.7066 nll:-1.0774 curv:0.0000 floor:0.1665 id:84.0227
# INFO:root:Epoch 011 | train total=18729.0777 ot:17907.4801 nll:-1.0756 curv:0.0000 floor:0.1666 id:82.2671 || val ot:18250.7021 nll:-1.0701 curv:0.0000 floor:0.1667 id:1.0000 total:18259.6338
# INFO:root:Saved best model (val score=18249.6320)
# INFO:root:[train] epoch 12 step 10/17 ot:18217.7086 nll:-1.0749 curv:0.0000 floor:0.1667 id:83.4835
# INFO:root:Epoch 012 | train total=18694.7241 ot:17874.8579 nll:-1.0771 curv:0.0000 floor:0.1668 id:82.0941 || val ot:18199.4482 nll:-1.0723 curv:0.0000 floor:0.1669 id:1.0000 total:18208.3779
# INFO:root:Saved best model (val score=18198.3759)
# INFO:root:[train] epoch 13 step 10/17 ot:17710.1072 nll:-1.0884 curv:0.0000 floor:0.1670 id:80.9227
# INFO:root:Epoch 013 | train total=18637.5779 ot:17822.9852 nll:-1.0787 curv:0.0000 floor:0.1670 id:81.5669 || val ot:18124.0078 nll:-1.0740 curv:0.0000 floor:0.1672 id:1.0000 total:18132.9355
# INFO:root:Saved best model (val score=18122.9338)
# INFO:root:[train] epoch 14 step 10/17 ot:17513.5151 nll:-1.0841 curv:0.0000 floor:0.1672 id:80.0216
# INFO:root:Epoch 014 | train total=18600.4295 ot:17788.6567 nll:-1.0793 curv:0.0000 floor:0.1673 id:81.2850 || val ot:18071.7998 nll:-1.0754 curv:0.0000 floor:0.1674 id:1.0000 total:18080.7266
# INFO:root:Saved best model (val score=18070.7244)
# INFO:root:[train] epoch 15 step 10/17 ot:17737.5264 nll:-1.0820 curv:0.0000 floor:0.1675 id:81.0390
# INFO:root:Epoch 015 | train total=18489.0513 ot:17684.4104 nll:-1.0811 curv:0.0000 floor:0.1675 id:80.5720 || val ot:18013.6270 nll:-1.0778 curv:0.0000 floor:0.1677 id:1.0000 total:18022.5508
# INFO:root:Saved best model (val score=18012.5492)
# INFO:root:[train] epoch 16 step 10/17 ot:17756.0856 nll:-1.0786 curv:0.0000 floor:0.1677 id:80.5371
# INFO:root:Epoch 016 | train total=18446.6480 ot:17646.7798 nll:-1.0846 curv:0.0000 floor:0.1678 id:80.0951 || val ot:17954.6240 nll:-1.0789 curv:0.0000 floor:0.1679 id:1.0000 total:17963.5469
# INFO:root:Saved best model (val score=17953.5451)
# INFO:root:[train] epoch 17 step 10/17 ot:17385.3477 nll:-1.0812 curv:0.0000 floor:0.1680 id:78.5243
# INFO:root:Epoch 017 | train total=18353.7952 ot:17560.3834 nll:-1.0860 curv:0.0000 floor:0.1680 id:79.4496 || val ot:17891.1221 nll:-1.0805 curv:0.0000 floor:0.1682 id:1.0000 total:17900.0439
# INFO:root:Saved best model (val score=17890.0415)
# INFO:root:[train] epoch 18 step 10/17 ot:17349.9135 nll:-1.0904 curv:0.0000 floor:0.1683 id:78.2142
# INFO:root:Epoch 018 | train total=18325.6095 ot:17536.4207 nll:-1.0867 curv:0.0000 floor:0.1683 id:79.0273 || val ot:17828.0371 nll:-1.0815 curv:0.0000 floor:0.1684 id:1.0000 total:17836.9570
# INFO:root:Saved best model (val score=17826.9556)
# INFO:root:[train] epoch 19 step 10/17 ot:17344.8000 nll:-1.0992 curv:0.0000 floor:0.1685 id:77.8425
# INFO:root:Epoch 019 | train total=18244.2071 ot:17461.4625 nll:-1.0893 curv:0.0000 floor:0.1686 id:78.3832 || val ot:17741.1689 nll:-1.0847 curv:0.0000 floor:0.1688 id:1.0000 total:17750.0859
# INFO:root:Saved best model (val score=17740.0843)
# INFO:root:[train] epoch 20 step 10/17 ot:17133.9662 nll:-1.0857 curv:0.0000 floor:0.1688 id:76.9306
# INFO:root:Epoch 020 | train total=18154.5254 ot:17378.7819 nll:-1.0915 curv:0.0000 floor:0.1689 id:77.6833 || val ot:17673.3926 nll:-1.0870 curv:0.0000 floor:0.1691 id:1.0000 total:17682.3076
# INFO:root:Saved best model (val score=17672.3056)
# INFO:root:[train] epoch 21 step 10/17 ot:17437.8563 nll:-1.0903 curv:0.0000 floor:0.1691 id:77.5153
# INFO:root:Epoch 021 | train total=18084.8775 ot:17315.7995 nll:-1.0931 curv:0.0000 floor:0.1692 id:77.0169 || val ot:17607.1348 nll:-1.0883 curv:0.0000 floor:0.1694 id:1.0000 total:17616.0479
# INFO:root:Saved best model (val score=17606.0465)
# INFO:root:[train] epoch 22 step 10/17 ot:17114.8637 nll:-1.0887 curv:0.0000 floor:0.1694 id:75.8277
# INFO:root:Epoch 022 | train total=18028.2981 ot:17264.8236 nll:-1.0951 curv:0.0000 floor:0.1695 id:76.4568 || val ot:17540.7773 nll:-1.0901 curv:0.0000 floor:0.1696 id:1.0000 total:17549.6895
# INFO:root:Saved best model (val score=17539.6873)
# INFO:root:[train] epoch 23 step 10/17 ot:17367.2416 nll:-1.0937 curv:0.0000 floor:0.1697 id:76.2138
# INFO:root:Epoch 023 | train total=17891.7816 ot:17137.3199 nll:-1.0973 curv:0.0000 floor:0.1698 id:75.5557 || val ot:17471.0928 nll:-1.0915 curv:0.0000 floor:0.1699 id:1.0000 total:17480.0029
# INFO:root:Saved best model (val score=17470.0013)
# INFO:root:[train] epoch 24 step 10/17 ot:17433.2875 nll:-1.0947 curv:0.0000 floor:0.1701 id:76.3344
# INFO:root:Epoch 024 | train total=17812.8500 ot:17066.0998 nll:-1.0994 curv:0.0000 floor:0.1701 id:74.7848 || val ot:17398.5352 nll:-1.0949 curv:0.0000 floor:0.1702 id:1.0000 total:17407.4424
# INFO:root:Saved best model (val score=17397.4403)
# INFO:root:[train] epoch 25 step 10/17 ot:17292.2371 nll:-1.1107 curv:0.0000 floor:0.1704 id:75.1163
# INFO:root:Epoch 025 | train total=17760.4903 ot:17020.4037 nll:-1.1012 curv:0.0000 floor:0.1704 id:74.1186 || val ot:17300.8447 nll:-1.0965 curv:0.0000 floor:0.1707 id:1.0000 total:17309.7500
# INFO:root:Saved best model (val score=17299.7482)
# INFO:root:[train] epoch 26 step 10/17 ot:16778.4893 nll:-1.1042 curv:0.0000 floor:0.1707 id:72.8281
# INFO:root:Epoch 026 | train total=17680.2314 ot:16947.7996 nll:-1.1038 curv:0.0000 floor:0.1708 id:73.3534 || val ot:17228.4824 nll:-1.0990 curv:0.0000 floor:0.1710 id:1.0000 total:17237.3848
# INFO:root:Saved best model (val score=17227.3834)
# INFO:root:[train] epoch 27 step 10/17 ot:17343.7969 nll:-1.1029 curv:0.0000 floor:0.1711 id:74.2035
# INFO:root:Epoch 027 | train total=17564.0022 ot:16840.5444 nll:-1.1058 curv:0.0000 floor:0.1711 id:72.4562 || val ot:17153.7549 nll:-1.1011 curv:0.0000 floor:0.1713 id:1.0000 total:17162.6553
# INFO:root:Saved best model (val score=17152.6538)
# INFO:root:[train] epoch 28 step 10/17 ot:16295.2999 nll:-1.1102 curv:0.0000 floor:0.1714 id:69.7055
# INFO:root:Epoch 028 | train total=17503.5704 ot:16786.9989 nll:-1.1083 curv:0.0000 floor:0.1715 id:71.7678 || val ot:17080.3506 nll:-1.1029 curv:0.0000 floor:0.1716 id:1.0000 total:17089.2500
# INFO:root:Saved best model (val score=17079.2477)
# INFO:root:[train] epoch 29 step 10/17 ot:16982.5358 nll:-1.1010 curv:0.0000 floor:0.1718 id:71.9264
# INFO:root:Epoch 029 | train total=17395.8860 ot:16688.5987 nll:-1.1108 curv:0.0000 floor:0.1718 id:70.8396 || val ot:17001.6230 nll:-1.1049 curv:0.0000 floor:0.1720 id:1.0000 total:17010.5195
# INFO:root:Saved best model (val score=17000.5181)
# INFO:root:[train] epoch 30 step 10/17 ot:16445.4373 nll:-1.1170 curv:0.0000 floor:0.1721 id:69.1503
# INFO:root:Epoch 030 | train total=17307.0628 ot:16607.9737 nll:-1.1125 curv:0.0000 floor:0.1722 id:70.0200 || val ot:16929.5547 nll:-1.1072 curv:0.0000 floor:0.1723 id:1.0000 total:16938.4492
# INFO:root:Saved best model (val score=16928.4475)
# INFO:root:[train] epoch 31 step 10/17 ot:16666.2965 nll:-1.1082 curv:0.0000 floor:0.1725 id:69.7921
# INFO:root:Epoch 031 | train total=17231.4610 ot:16540.2872 nll:-1.1147 curv:0.0000 floor:0.1725 id:69.2287 || val ot:16823.3350 nll:-1.1113 curv:0.0000 floor:0.1728 id:1.0000 total:16832.2256
# INFO:root:Saved best model (val score=16822.2237)
# INFO:root:[train] epoch 32 step 10/17 ot:16708.8896 nll:-1.1088 curv:0.0000 floor:0.1728 id:69.4156
# INFO:root:Epoch 032 | train total=17164.3071 ot:16481.0149 nll:-1.1178 curv:0.0000 floor:0.1729 id:68.4408 || val ot:16743.1982 nll:-1.1128 curv:0.0000 floor:0.1731 id:1.0000 total:16752.0879
# INFO:root:Saved best model (val score=16742.0855)
# INFO:root:[train] epoch 33 step 10/17 ot:16568.3915 nll:-1.1144 curv:0.0000 floor:0.1732 id:68.1822
# INFO:root:Epoch 033 | train total=17029.9786 ot:16356.7560 nll:-1.1210 curv:0.0000 floor:0.1733 id:67.4342 || val ot:16664.5117 nll:-1.1153 curv:0.0000 floor:0.1735 id:1.0000 total:16673.3984
# INFO:root:Saved best model (val score=16663.3964)
# INFO:root:[train] epoch 34 step 10/17 ot:15977.7232 nll:-1.1140 curv:0.0000 floor:0.1736 id:65.3978
# INFO:root:Epoch 034 | train total=16975.0636 ot:16309.2807 nll:-1.1230 curv:0.0000 floor:0.1737 id:66.6904 || val ot:16582.7227 nll:-1.1177 curv:0.0000 floor:0.1739 id:1.0000 total:16591.6074
# INFO:root:Saved best model (val score=16581.6050)
# INFO:root:[train] epoch 35 step 10/17 ot:16613.3152 nll:-1.1241 curv:0.0000 floor:0.1740 id:67.2631
# INFO:root:Epoch 035 | train total=16862.5398 ot:16206.4223 nll:-1.1251 curv:0.0000 floor:0.1741 id:65.7241 || val ot:16503.7603 nll:-1.1205 curv:0.0000 floor:0.1742 id:1.0000 total:16512.6421
# INFO:root:Saved best model (val score=16502.6398)
# INFO:root:[train] epoch 36 step 10/17 ot:16163.5445 nll:-1.1172 curv:0.0000 floor:0.1744 id:64.9044
# INFO:root:Epoch 036 | train total=16795.9894 ot:16147.9620 nll:-1.1285 curv:0.0000 floor:0.1745 id:64.9154 || val ot:16427.9014 nll:-1.1228 curv:0.0000 floor:0.1746 id:1.0000 total:16436.7803
# INFO:root:Saved best model (val score=16426.7785)
# INFO:root:[train] epoch 37 step 10/17 ot:16448.6713 nll:-1.1333 curv:0.0000 floor:0.1748 id:65.5999
# INFO:root:Epoch 037 | train total=16683.1427 ot:16044.4942 nll:-1.1306 curv:0.0000 floor:0.1748 id:63.9777 || val ot:16311.1299 nll:-1.1262 curv:0.0000 floor:0.1751 id:1.0000 total:16320.0059
# INFO:root:Saved best model (val score=16310.0036)
# INFO:root:[train] epoch 38 step 10/17 ot:15980.6551 nll:-1.1381 curv:0.0000 floor:0.1752 id:62.9117
# INFO:root:Epoch 038 | train total=16596.7684 ot:15966.8157 nll:-1.1328 curv:0.0000 floor:0.1753 id:63.1083 || val ot:16231.5347 nll:-1.1286 curv:0.0000 floor:0.1755 id:1.0000 total:16240.4077
# INFO:root:Saved best model (val score=16230.4060)
# INFO:root:[train] epoch 39 step 10/17 ot:16256.7201 nll:-1.1246 curv:0.0000 floor:0.1756 id:63.4418
# INFO:root:Epoch 039 | train total=16545.5095 ot:15923.1460 nll:-1.1358 curv:0.0000 floor:0.1757 id:62.3497 || val ot:16144.3833 nll:-1.1313 curv:0.0000 floor:0.1759 id:1.0000 total:16153.2539
# INFO:root:Saved best model (val score=16143.2520)
# INFO:root:[train] epoch 40 step 10/17 ot:15811.3270 nll:-1.1358 curv:0.0000 floor:0.1760 id:61.2966
# INFO:root:Epoch 040 | train total=16409.0302 ot:15797.6268 nll:-1.1386 curv:0.0000 floor:0.1761 id:61.2540 || val ot:16064.0044 nll:-1.1336 curv:0.0000 floor:0.1763 id:1.0000 total:16072.8726
# INFO:root:Saved best model (val score=16062.8708)
# INFO:root:[train] epoch 41 step 10/17 ot:15816.2897 nll:-1.1427 curv:0.0000 floor:0.1764 id:60.5173
# INFO:root:Epoch 041 | train total=16308.5314 ot:15706.5256 nll:-1.1409 curv:0.0000 floor:0.1765 id:60.3145 || val ot:15980.4360 nll:-1.1367 curv:0.0000 floor:0.1767 id:1.0000 total:15989.3013
# INFO:root:Saved best model (val score=15979.2994)
# INFO:root:[train] epoch 42 step 10/17 ot:15824.1442 nll:-1.1337 curv:0.0000 floor:0.1768 id:60.2691
# INFO:root:Epoch 042 | train total=16189.2794 ot:15596.7030 nll:-1.1446 curv:0.0000 floor:0.1769 id:59.3719 || val ot:15895.9214 nll:-1.1389 curv:0.0000 floor:0.1771 id:1.0000 total:15904.7847
# INFO:root:Saved best model (val score=15894.7825)
# INFO:root:[train] epoch 43 step 10/17 ot:15290.2996 nll:-1.1379 curv:0.0000 floor:0.1772 id:57.6044
# INFO:root:Epoch 043 | train total=16134.8261 ot:15550.5755 nll:-1.1468 curv:0.0000 floor:0.1773 id:58.5396 || val ot:15772.8135 nll:-1.1429 curv:0.0000 floor:0.1776 id:1.0000 total:15781.6729
# INFO:root:Saved best model (val score=15771.6705)
# INFO:root:[train] epoch 44 step 10/17 ot:15365.0415 nll:-1.1447 curv:0.0000 floor:0.1777 id:57.1444
# INFO:root:Epoch 044 | train total=16022.5790 ot:15448.2578 nll:-1.1503 curv:0.0000 floor:0.1778 id:57.5470 || val ot:15691.9131 nll:-1.1448 curv:0.0000 floor:0.1780 id:1.0000 total:15700.7705
# INFO:root:Saved best model (val score=15690.7683)
# INFO:root:[train] epoch 45 step 10/17 ot:15559.9873 nll:-1.1489 curv:0.0000 floor:0.1781 id:57.1397
# INFO:root:Epoch 045 | train total=15917.7918 ot:15353.0113 nll:-1.1522 curv:0.0000 floor:0.1782 id:56.5931 || val ot:15606.1714 nll:-1.1480 curv:0.0000 floor:0.1785 id:1.0000 total:15615.0254
# INFO:root:Saved best model (val score=15605.0234)
# INFO:root:[train] epoch 46 step 10/17 ot:14927.8543 nll:-1.1516 curv:0.0000 floor:0.1786 id:54.5574
# INFO:root:Epoch 046 | train total=15826.1134 ot:15270.2438 nll:-1.1554 curv:0.0000 floor:0.1787 id:55.7023 || val ot:15521.0679 nll:-1.1507 curv:0.0000 floor:0.1789 id:1.0000 total:15529.9189
# INFO:root:Saved best model (val score=15519.9172)
# INFO:root:[train] epoch 47 step 10/17 ot:15269.7310 nll:-1.1558 curv:0.0000 floor:0.1790 id:55.0313
# INFO:root:Epoch 047 | train total=15739.1751 ot:15192.2030 nll:-1.1574 curv:0.0000 floor:0.1791 id:54.8128 || val ot:15433.4004 nll:-1.1534 curv:0.0000 floor:0.1793 id:1.0000 total:15442.2490
# INFO:root:Saved best model (val score=15432.2470)
# INFO:root:[train] epoch 48 step 10/17 ot:15119.1420 nll:-1.1627 curv:0.0000 floor:0.1795 id:53.8920
# INFO:root:Epoch 048 | train total=15609.5827 ot:15072.7575 nll:-1.1614 curv:0.0000 floor:0.1796 id:53.7985 || val ot:15347.2432 nll:-1.1560 curv:0.0000 floor:0.1797 id:1.0000 total:15356.0889
# INFO:root:Saved best model (val score=15346.0872)
# INFO:root:[train] epoch 49 step 10/17 ot:15631.8704 nll:-1.1505 curv:0.0000 floor:0.1799 id:55.0364
# INFO:root:Epoch 049 | train total=15514.9267 ot:14986.9161 nll:-1.1645 curv:0.0000 floor:0.1800 id:52.9173 || val ot:15226.8623 nll:-1.1607 curv:0.0000 floor:0.1803 id:1.0000 total:15235.7036
# INFO:root:Saved best model (val score=15225.7017)
# INFO:root:[train] epoch 50 step 10/17 ot:14734.4518 nll:-1.1645 curv:0.0000 floor:0.1804 id:51.3699
# INFO:root:Epoch 050 | train total=15444.9346 ot:14925.3571 nll:-1.1675 curv:0.0000 floor:0.1805 id:52.0743 || val ot:15137.3550 nll:-1.1636 curv:0.0000 floor:0.1808 id:1.0000 total:15146.1934
# INFO:root:Saved best model (val score=15136.1914)
# INFO:root:[train] epoch 51 step 10/17 ot:14694.4660 nll:-1.1666 curv:0.0000 floor:0.1808 id:50.6462
# INFO:root:Epoch 051 | train total=15329.9160 ot:14820.5735 nll:-1.1701 curv:0.0000 floor:0.1809 id:51.0511 || val ot:15048.6919 nll:-1.1661 curv:0.0000 floor:0.1812 id:1.0000 total:15057.5278
# INFO:root:Saved best model (val score=15047.5258)
# INFO:root:[train] epoch 52 step 10/17 ot:14538.9318 nll:-1.1837 curv:0.0000 floor:0.1813 id:49.5468
# INFO:root:Epoch 052 | train total=15209.3805 ot:14709.4497 nll:-1.1731 curv:0.0000 floor:0.1814 id:50.1102 || val ot:14957.9370 nll:-1.1689 curv:0.0000 floor:0.1816 id:1.0000 total:14966.7700
# INFO:root:Saved best model (val score=14956.7681)
# INFO:root:[train] epoch 53 step 10/17 ot:14789.5667 nll:-1.1696 curv:0.0000 floor:0.1818 id:49.6090
# INFO:root:Epoch 053 | train total=15102.4162 ot:14612.0166 nll:-1.1764 curv:0.0000 floor:0.1819 id:49.1574 || val ot:14871.2026 nll:-1.1719 curv:0.0000 floor:0.1821 id:1.0000 total:14880.0327
# INFO:root:Saved best model (val score=14870.0307)
# INFO:root:[train] epoch 54 step 10/17 ot:14347.3690 nll:-1.1820 curv:0.0000 floor:0.1823 id:47.5979
# INFO:root:Epoch 054 | train total=15044.7225 ot:14561.5949 nll:-1.1792 curv:0.0000 floor:0.1824 id:48.4305 || val ot:14782.7759 nll:-1.1746 curv:0.0000 floor:0.1825 id:1.0000 total:14791.6035
# INFO:root:Saved best model (val score=14781.6013)
# INFO:root:[train] epoch 55 step 10/17 ot:14529.6392 nll:-1.1810 curv:0.0000 floor:0.1827 id:47.6793
# INFO:root:Epoch 055 | train total=14920.1380 ot:14447.2733 nll:-1.1830 curv:0.0000 floor:0.1828 id:47.4046 || val ot:14663.4976 nll:-1.1787 curv:0.0000 floor:0.1832 id:1.0000 total:14672.3208
# INFO:root:Saved best model (val score=14662.3188)
# INFO:root:[train] epoch 56 step 10/17 ot:14218.9207 nll:-1.1813 curv:0.0000 floor:0.1832 id:45.8176
# INFO:root:Epoch 056 | train total=14854.0767 ot:14389.0696 nll:-1.1852 curv:0.0000 floor:0.1833 id:46.6190 || val ot:14571.8525 nll:-1.1820 curv:0.0000 floor:0.1836 id:1.0000 total:14580.6729
# INFO:root:Saved best model (val score=14570.6706)
# INFO:root:[train] epoch 57 step 10/17 ot:14554.3166 nll:-1.1824 curv:0.0000 floor:0.1837 id:46.3427
# INFO:root:Epoch 057 | train total=14736.5798 ot:14280.8189 nll:-1.1894 curv:0.0000 floor:0.1838 id:45.6948 || val ot:14484.3086 nll:-1.1856 curv:0.0000 floor:0.1841 id:1.0000 total:14493.1250
# INFO:root:Saved best model (val score=14483.1230)
# INFO:root:[train] epoch 58 step 10/17 ot:14326.4229 nll:-1.1971 curv:0.0000 floor:0.1842 id:45.3112
# INFO:root:Epoch 058 | train total=14644.6714 ot:14197.9066 nll:-1.1924 curv:0.0000 floor:0.1843 id:44.7955 || val ot:14395.8281 nll:-1.1880 curv:0.0000 floor:0.1846 id:1.0000 total:14404.6421
# INFO:root:Saved best model (val score=14394.6401)
# INFO:root:[train] epoch 59 step 10/17 ot:13955.8995 nll:-1.1977 curv:0.0000 floor:0.1847 id:43.4879
# INFO:root:Epoch 059 | train total=14520.1536 ot:14082.5303 nll:-1.1957 curv:0.0000 floor:0.1848 id:43.8817 || val ot:14304.1118 nll:-1.1911 curv:0.0000 floor:0.1850 id:1.0000 total:14312.9224
# INFO:root:Saved best model (val score=14302.9207)
# INFO:root:[train] epoch 60 step 10/17 ot:13759.0755 nll:-1.1966 curv:0.0000 floor:0.1852 id:42.1451
# INFO:root:Epoch 060 | train total=14425.3771 ot:13996.2917 nll:-1.1987 curv:0.0000 floor:0.1853 id:43.0282 || val ot:14216.3037 nll:-1.1942 curv:0.0000 floor:0.1855 id:1.0000 total:14225.1118
# INFO:root:Saved best model (val score=14215.1095)
# INFO:root:[train] epoch 61 step 10/17 ot:14203.6005 nll:-1.1987 curv:0.0000 floor:0.1857 id:43.0101
# INFO:root:Epoch 061 | train total=14330.7212 ot:13910.5271 nll:-1.2024 curv:0.0000 floor:0.1858 id:42.1395 || val ot:14090.2168 nll:-1.1983 curv:0.0000 floor:0.1862 id:1.0000 total:14099.0205
# INFO:root:Saved best model (val score=14089.0185)
# INFO:root:[train] epoch 62 step 10/17 ot:13671.8118 nll:-1.2051 curv:0.0000 floor:0.1862 id:40.8938
# INFO:root:Epoch 062 | train total=14212.4116 ot:13800.8418 nll:-1.2056 curv:0.0000 floor:0.1863 id:41.2774 || val ot:14004.6333 nll:-1.2003 curv:0.0000 floor:0.1866 id:1.0000 total:14013.4351
# INFO:root:Saved best model (val score=14003.4330)
# INFO:root:[train] epoch 63 step 10/17 ot:13544.1820 nll:-1.2079 curv:0.0000 floor:0.1867 id:39.8907
# INFO:root:Epoch 063 | train total=14143.0120 ot:13739.1428 nll:-1.2084 curv:0.0000 floor:0.1868 id:40.5076 || val ot:13916.8477 nll:-1.2046 curv:0.0000 floor:0.1871 id:1.0000 total:13925.6450
# INFO:root:Saved best model (val score=13915.6430)
# INFO:root:[train] epoch 64 step 10/17 ot:13524.9293 nll:-1.2158 curv:0.0000 floor:0.1872 id:39.1981
# INFO:root:Epoch 064 | train total=14030.7872 ot:13636.1539 nll:-1.2118 curv:0.0000 floor:0.1874 id:39.5843 || val ot:13820.9917 nll:-1.2075 curv:0.0000 floor:0.1876 id:1.0000 total:13829.7861
# INFO:root:Saved best model (val score=13819.7842)
# INFO:root:[train] epoch 65 step 10/17 ot:13334.8781 nll:-1.2223 curv:0.0000 floor:0.1878 id:38.1291
# INFO:root:Epoch 065 | train total=13941.3388 ot:13554.8890 nll:-1.2151 curv:0.0000 floor:0.1879 id:38.7663 || val ot:13735.3467 nll:-1.2111 curv:0.0000 floor:0.1881 id:1.0000 total:13744.1372
# INFO:root:Saved best model (val score=13734.1356)
# INFO:root:[train] epoch 66 step 10/17 ot:13449.5071 nll:-1.2113 curv:0.0000 floor:0.1883 id:37.8022
# INFO:root:Epoch 066 | train total=13824.5774 ot:13446.6847 nll:-1.2190 curv:0.0000 floor:0.1884 id:37.9110 || val ot:13640.8438 nll:-1.2145 curv:0.0000 floor:0.1886 id:1.0000 total:13649.6313
# INFO:root:Saved best model (val score=13639.6292)
# INFO:root:[train] epoch 67 step 10/17 ot:13450.2450 nll:-1.2172 curv:0.0000 floor:0.1888 id:37.2703
# INFO:root:Epoch 067 | train total=13730.6049 ot:13360.7981 nll:-1.2225 curv:0.0000 floor:0.1889 id:37.1027 || val ot:13518.5137 nll:-1.2193 curv:0.0000 floor:0.1893 id:1.0000 total:13527.2964
# INFO:root:Saved best model (val score=13517.2944)
# INFO:root:[train] epoch 68 step 10/17 ot:13272.2322 nll:-1.2125 curv:0.0000 floor:0.1893 id:36.2937
# INFO:root:Epoch 068 | train total=13622.8104 ot:13261.4935 nll:-1.2264 curv:0.0000 floor:0.1895 id:36.2541 || val ot:13428.8862 nll:-1.2233 curv:0.0000 floor:0.1898 id:1.0000 total:13437.6650
# INFO:root:Saved best model (val score=13427.6629)
# INFO:root:[train] epoch 69 step 10/17 ot:13066.5287 nll:-1.2305 curv:0.0000 floor:0.1899 id:35.1010
# INFO:root:Epoch 069 | train total=13484.0883 ot:13131.4908 nll:-1.2298 curv:0.0000 floor:0.1900 id:35.3825 || val ot:13341.5259 nll:-1.2251 curv:0.0000 floor:0.1903 id:1.0000 total:13350.3027
# INFO:root:Saved best model (val score=13340.3008)
# INFO:root:[train] epoch 70 step 10/17 ot:13134.6194 nll:-1.2372 curv:0.0000 floor:0.1904 id:34.7818
# INFO:root:Epoch 070 | train total=13424.0120 ot:13078.7598 nll:-1.2333 curv:0.0000 floor:0.1905 id:34.6484 || val ot:13251.8306 nll:-1.2287 curv:0.0000 floor:0.1908 id:1.0000 total:13260.6040
# INFO:root:Saved best model (val score=13250.6019)
# INFO:root:[train] epoch 71 step 10/17 ot:13255.3760 nll:-1.2291 curv:0.0000 floor:0.1910 id:34.6752
# INFO:root:Epoch 071 | train total=13304.9470 ot:12967.2810 nll:-1.2377 curv:0.0000 floor:0.1911 id:33.8902 || val ot:13163.0527 nll:-1.2325 curv:0.0000 floor:0.1913 id:1.0000 total:13171.8223
# INFO:root:Saved best model (val score=13161.8203)
# INFO:root:[train] epoch 72 step 10/17 ot:13265.8156 nll:-1.2294 curv:0.0000 floor:0.1915 id:33.9595
# INFO:root:Epoch 072 | train total=13213.4152 ot:12883.9199 nll:-1.2403 curv:0.0000 floor:0.1916 id:33.0734 || val ot:13068.9922 nll:-1.2358 curv:0.0000 floor:0.1918 id:1.0000 total:13077.7583
# INFO:root:Saved best model (val score=13067.7564)
# INFO:root:[train] epoch 73 step 10/17 ot:12802.1037 nll:-1.2427 curv:0.0000 floor:0.1920 id:32.2674
# INFO:root:Epoch 073 | train total=13125.6137 ot:12803.9124 nll:-1.2442 curv:0.0000 floor:0.1922 id:32.2944 || val ot:12948.0576 nll:-1.2407 curv:0.0000 floor:0.1925 id:1.0000 total:12956.8193
# INFO:root:Saved best model (val score=12946.8169)
# INFO:root:[train] epoch 74 step 10/17 ot:12252.4664 nll:-1.2600 curv:0.0000 floor:0.1926 id:30.3712
# INFO:root:Epoch 074 | train total=13036.8810 ot:12722.0805 nll:-1.2467 curv:0.0000 floor:0.1927 id:31.6045 || val ot:12859.9946 nll:-1.2438 curv:0.0000 floor:0.1930 id:1.0000 total:12868.7524
# INFO:root:Saved best model (val score=12858.7508)
# INFO:root:[train] epoch 75 step 10/17 ot:12586.2609 nll:-1.2552 curv:0.0000 floor:0.1931 id:30.6805
# INFO:root:Epoch 075 | train total=12923.3622 ot:12616.5786 nll:-1.2501 curv:0.0000 floor:0.1933 id:30.8032 || val ot:12771.5630 nll:-1.2470 curv:0.0000 floor:0.1936 id:1.0000 total:12780.3179
# INFO:root:Saved best model (val score=12770.3159)
# INFO:root:[train] epoch 76 step 10/17 ot:12703.7529 nll:-1.2458 curv:0.0000 floor:0.1937 id:30.4680
# INFO:root:Epoch 076 | train total=12809.1864 ot:12510.2226 nll:-1.2547 curv:0.0000 floor:0.1938 id:30.0217 || val ot:12683.1128 nll:-1.2509 curv:0.0000 floor:0.1941 id:1.0000 total:12691.8638
# INFO:root:Saved best model (val score=12681.8619)
# INFO:root:[train] epoch 77 step 10/17 ot:12260.4312 nll:-1.2627 curv:0.0000 floor:0.1943 id:29.0217
# INFO:root:Epoch 077 | train total=12726.8442 ot:12434.4898 nll:-1.2580 curv:0.0000 floor:0.1944 id:29.3610 || val ot:12590.8965 nll:-1.2541 curv:0.0000 floor:0.1946 id:1.0000 total:12599.6445
# INFO:root:Saved best model (val score=12589.6424)
# INFO:root:[train] epoch 78 step 10/17 ot:12299.8027 nll:-1.2705 curv:0.0000 floor:0.1948 id:28.4032
# INFO:root:Epoch 078 | train total=12616.6053 ot:12332.0108 nll:-1.2625 curv:0.0000 floor:0.1949 id:28.5855 || val ot:12503.2622 nll:-1.2582 curv:0.0000 floor:0.1952 id:1.0000 total:12512.0059
# INFO:root:Saved best model (val score=12502.0040)
# INFO:root:[train] epoch 79 step 10/17 ot:12121.7331 nll:-1.2617 curv:0.0000 floor:0.1954 id:27.5529
# INFO:root:Epoch 079 | train total=12533.0742 ot:12255.3452 nll:-1.2663 curv:0.0000 floor:0.1955 id:27.8993 || val ot:12380.5386 nll:-1.2637 curv:0.0000 floor:0.1959 id:1.0000 total:12389.2769
# INFO:root:Saved best model (val score=12379.2748)
# INFO:root:[train] epoch 80 step 10/17 ot:12119.4309 nll:-1.2778 curv:0.0000 floor:0.1959 id:27.0258
# INFO:root:Epoch 080 | train total=12426.0128 ot:12155.3310 nll:-1.2695 curv:0.0000 floor:0.1961 id:27.1949 || val ot:12293.7695 nll:-1.2659 curv:0.0000 floor:0.1964 id:1.0000 total:12302.5054
# INFO:root:Saved best model (val score=12292.5036)
# INFO:root:[train] epoch 81 step 10/17 ot:12503.9751 nll:-1.2730 curv:0.0000 floor:0.1965 id:27.4805
# INFO:root:Epoch 081 | train total=12341.9327 ot:12077.5572 nll:-1.2735 curv:0.0000 floor:0.1966 id:26.5647 || val ot:12204.4902 nll:-1.2698 curv:0.0000 floor:0.1970 id:1.0000 total:12213.2227
# INFO:root:Saved best model (val score=12203.2204)
# INFO:root:[train] epoch 82 step 10/17 ot:12107.1060 nll:-1.2760 curv:0.0000 floor:0.1971 id:26.0897
# INFO:root:Epoch 082 | train total=12221.9103 ot:11965.2884 nll:-1.2776 curv:0.0000 floor:0.1972 id:25.7898 || val ot:12116.2720 nll:-1.2724 curv:0.0000 floor:0.1975 id:1.0000 total:12125.0015
# INFO:root:Saved best model (val score=12114.9995)
# INFO:root:[train] epoch 83 step 10/17 ot:11748.4378 nll:-1.2744 curv:0.0000 floor:0.1977 id:24.8806
# INFO:root:Epoch 083 | train total=12131.0302 ot:11880.8215 nll:-1.2810 curv:0.0000 floor:0.1978 id:25.1488 || val ot:12029.3096 nll:-1.2768 curv:0.0000 floor:0.1981 id:1.0000 total:12038.0347
# INFO:root:Saved best model (val score=12028.0328)
# INFO:root:[train] epoch 84 step 10/17 ot:11868.0280 nll:-1.2877 curv:0.0000 floor:0.1983 id:24.5801
# INFO:root:Epoch 084 | train total=12033.8824 ot:11790.2578 nll:-1.2853 curv:0.0000 floor:0.1984 id:24.4908 || val ot:11938.5942 nll:-1.2799 curv:0.0000 floor:0.1986 id:1.0000 total:11947.3159
# INFO:root:Saved best model (val score=11937.3143)
# INFO:root:[train] epoch 85 step 10/17 ot:11619.0494 nll:-1.2834 curv:0.0000 floor:0.1988 id:23.6806
# INFO:root:Epoch 085 | train total=11954.8038 ot:11717.3202 nll:-1.2879 curv:0.0000 floor:0.1990 id:23.8770 || val ot:11820.8262 nll:-1.2859 curv:0.0000 floor:0.1994 id:1.0000 total:11829.5420
# INFO:root:Saved best model (val score=11819.5403)
# INFO:root:[train] epoch 86 step 10/17 ot:11503.4422 nll:-1.3028 curv:0.0000 floor:0.1994 id:22.9784
# INFO:root:Epoch 086 | train total=11844.3141 ot:11613.1485 nll:-1.2919 curv:0.0000 floor:0.1995 id:23.2456 || val ot:11731.8555 nll:-1.2891 curv:0.0000 floor:0.1999 id:1.0000 total:11740.5684
# INFO:root:Saved best model (val score=11730.5663)
# INFO:root:[train] epoch 87 step 10/17 ot:11330.1930 nll:-1.2948 curv:0.0000 floor:0.2000 id:22.1795
# INFO:root:Epoch 087 | train total=11750.0338 ot:11525.3865 nll:-1.2969 curv:0.0000 floor:0.2001 id:22.5942 || val ot:11646.0781 nll:-1.2924 curv:0.0000 floor:0.2005 id:1.0000 total:11654.7876
# INFO:root:Saved best model (val score=11644.7858)
# INFO:root:[train] epoch 88 step 10/17 ot:11458.9381 nll:-1.2964 curv:0.0000 floor:0.2006 id:21.9651
# INFO:root:Epoch 088 | train total=11657.6226 ot:11439.1911 nll:-1.3003 curv:0.0000 floor:0.2007 id:21.9730 || val ot:11557.8901 nll:-1.2965 curv:0.0000 floor:0.2010 id:1.0000 total:11566.5952
# INFO:root:Saved best model (val score=11556.5936)
# INFO:root:[train] epoch 89 step 10/17 ot:11023.7237 nll:-1.3088 curv:0.0000 floor:0.2012 id:20.7620
# INFO:root:Epoch 089 | train total=11534.0547 ot:11322.0435 nll:-1.3044 curv:0.0000 floor:0.2013 id:21.3314 || val ot:11471.6987 nll:-1.2996 curv:0.0000 floor:0.2016 id:1.0000 total:11480.4014
# INFO:root:Saved best model (val score=11470.3991)
# INFO:root:[train] epoch 90 step 10/17 ot:11538.2111 nll:-1.3146 curv:0.0000 floor:0.2018 id:21.3458
# INFO:root:Epoch 090 | train total=11434.0542 ot:11227.8111 nll:-1.3074 curv:0.0000 floor:0.2019 id:20.7548 || val ot:11384.0742 nll:-1.3045 curv:0.0000 floor:0.2021 id:1.0000 total:11392.7720
# INFO:root:Saved best model (val score=11382.7697)
# INFO:root:[train] epoch 91 step 10/17 ot:11094.1373 nll:-1.3157 curv:0.0000 floor:0.2024 id:19.9996
# INFO:root:Epoch 091 | train total=11363.3780 ot:11162.7490 nll:-1.3118 curv:0.0000 floor:0.2025 id:20.1939 || val ot:11267.7876 nll:-1.3089 curv:0.0000 floor:0.2029 id:1.0000 total:11276.4805
# INFO:root:Saved best model (val score=11266.4787)
# INFO:root:[train] epoch 92 step 10/17 ot:11171.8726 nll:-1.3124 curv:0.0000 floor:0.2030 id:19.8024
# INFO:root:Epoch 092 | train total=11269.4836 ot:11074.7066 nll:-1.3160 curv:0.0000 floor:0.2031 id:19.6091 || val ot:11180.9736 nll:-1.3130 curv:0.0000 floor:0.2035 id:1.0000 total:11189.6626
# INFO:root:Saved best model (val score=11179.6606)
# INFO:root:[train] epoch 93 step 10/17 ot:10901.6226 nll:-1.3174 curv:0.0000 floor:0.2036 id:18.9442
# INFO:root:Epoch 093 | train total=11156.9158 ot:10968.1305 nll:-1.3201 curv:0.0000 floor:0.2037 id:19.0103 || val ot:11091.8540 nll:-1.3172 curv:0.0000 floor:0.2040 id:1.0000 total:11100.5391
# INFO:root:Saved best model (val score=11090.5368)
# INFO:root:[train] epoch 94 step 10/17 ot:10753.2444 nll:-1.3212 curv:0.0000 floor:0.2042 id:18.2458
# INFO:root:Epoch 094 | train total=11090.0009 ot:10906.2015 nll:-1.3242 curv:0.0000 floor:0.2043 id:18.5122 || val ot:11011.2339 nll:-1.3204 curv:0.0000 floor:0.2046 id:1.0000 total:11019.9155
# INFO:root:Saved best model (val score=11009.9135)
# INFO:root:[train] epoch 95 step 10/17 ot:10545.1887 nll:-1.3249 curv:0.0000 floor:0.2048 id:17.5005
# INFO:root:Epoch 095 | train total=10987.3502 ot:10808.9954 nll:-1.3291 curv:0.0000 floor:0.2049 id:17.9682 || val ot:10925.2407 nll:-1.3246 curv:0.0000 floor:0.2052 id:1.0000 total:10933.9180
# INFO:root:Saved best model (val score=10923.9162)
# INFO:root:[train] epoch 96 step 10/17 ot:10781.9775 nll:-1.3383 curv:0.0000 floor:0.2054 id:17.4723
# INFO:root:Epoch 096 | train total=10882.8436 ot:10710.1909 nll:-1.3330 curv:0.0000 floor:0.2055 id:17.3984 || val ot:10840.2905 nll:-1.3271 curv:0.0000 floor:0.2058 id:1.0000 total:10848.9653
# INFO:root:Saved best model (val score=10838.9634)
# INFO:root:[train] epoch 97 step 10/17 ot:10547.0782 nll:-1.3416 curv:0.0000 floor:0.2060 id:16.6815
# INFO:root:Epoch 097 | train total=10827.6107 ot:10659.5267 nll:-1.3363 curv:0.0000 floor:0.2061 id:16.9418 || val ot:10725.2891 nll:-1.3329 curv:0.0000 floor:0.2066 id:1.0000 total:10733.9580
# INFO:root:Saved best model (val score=10723.9561)
# INFO:root:[train] epoch 98 step 10/17 ot:10711.9534 nll:-1.3307 curv:0.0000 floor:0.2066 id:16.6651
# INFO:root:Epoch 098 | train total=10689.0616 ot:10526.9085 nll:-1.3410 curv:0.0000 floor:0.2068 id:16.3492 || val ot:10640.1538 nll:-1.3374 curv:0.0000 floor:0.2071 id:1.0000 total:10648.8184
# INFO:root:Saved best model (val score=10638.8165)
# INFO:root:[train] epoch 99 step 10/17 ot:10608.2234 nll:-1.3377 curv:0.0000 floor:0.2072 id:16.1070
# INFO:root:Epoch 099 | train total=10615.6627 ot:10458.1257 nll:-1.3452 curv:0.0000 floor:0.2074 id:15.8880 || val ot:10557.0728 nll:-1.3414 curv:0.0000 floor:0.2077 id:1.0000 total:10565.7334
# INFO:root:Saved best model (val score=10555.7313)
# INFO:root:[train] epoch 100 step 10/17 ot:10224.7809 nll:-1.3498 curv:0.0000 floor:0.2079 id:15.1095
# INFO:root:Epoch 100 | train total=10539.4421 ot:10386.6836 nll:-1.3483 curv:0.0000 floor:0.2080 id:15.4105 || val ot:10473.2002 nll:-1.3456 curv:0.0000 floor:0.2083 id:1.0000 total:10481.8564
# INFO:root:Saved best model (val score=10471.8546)
# INFO:root:[train] epoch 101 step 10/17 ot:10059.4367 nll:-1.3554 curv:0.0000 floor:0.2085 id:14.6041
# INFO:root:Epoch 101 | train total=10431.1659 ot:10283.1377 nll:-1.3534 curv:0.0000 floor:0.2086 id:14.9380 || val ot:10390.1934 nll:-1.3486 curv:0.0000 floor:0.2089 id:1.0000 total:10398.8467
# INFO:root:Saved best model (val score=10388.8447)
# INFO:root:[train] epoch 102 step 10/17 ot:10113.6956 nll:-1.3580 curv:0.0000 floor:0.2091 id:14.2688
# INFO:root:Epoch 102 | train total=10354.8893 ot:10211.6974 nll:-1.3574 curv:0.0000 floor:0.2092 id:14.4547 || val ot:10307.9497 nll:-1.3527 curv:0.0000 floor:0.2095 id:1.0000 total:10316.5991
# INFO:root:Saved best model (val score=10306.5970)
# INFO:root:[train] epoch 103 step 10/17 ot:10078.3870 nll:-1.3586 curv:0.0000 floor:0.2097 id:13.9476
# INFO:root:Epoch 103 | train total=10261.7220 ot:10123.1048 nll:-1.3612 curv:0.0000 floor:0.2099 id:13.9976 || val ot:10192.8125 nll:-1.3582 curv:0.0000 floor:0.2103 id:1.0000 total:10201.4561
# INFO:root:Saved best model (val score=10191.4543)
# INFO:root:[train] epoch 104 step 10/17 ot:9876.6263 nll:-1.3689 curv:0.0000 floor:0.2104 id:13.3457
# INFO:root:Epoch 104 | train total=10166.1633 ot:10032.0091 nll:-1.3662 curv:0.0000 floor:0.2105 id:13.5519 || val ot:10111.4058 nll:-1.3621 curv:0.0000 floor:0.2109 id:1.0000 total:10120.0459
# INFO:root:Saved best model (val score=10110.0437)
# INFO:root:[train] epoch 105 step 10/17 ot:10057.9628 nll:-1.3653 curv:0.0000 floor:0.2110 id:13.2245
# INFO:root:Epoch 105 | train total=10091.3766 ot:9961.6221 nll:-1.3699 curv:0.0000 floor:0.2111 id:13.1122 || val ot:10031.7251 nll:-1.3665 curv:0.0000 floor:0.2115 id:1.0000 total:10040.3608
# INFO:root:Saved best model (val score=10030.3586)
# INFO:root:[train] epoch 106 step 10/17 ot:9768.1274 nll:-1.3734 curv:0.0000 floor:0.2116 id:12.5456
# INFO:root:Epoch 106 | train total=9975.7434 ot:9850.4420 nll:-1.3740 curv:0.0000 floor:0.2117 id:12.6674 || val ot:9950.7822 nll:-1.3703 curv:0.0000 floor:0.2121 id:1.0000 total:9959.4141
# INFO:root:Saved best model (val score=9949.4120)
# INFO:root:[train] epoch 107 step 10/17 ot:9713.6898 nll:-1.3784 curv:0.0000 floor:0.2123 id:12.1974
# INFO:root:Epoch 107 | train total=9900.0447 ot:9778.8824 nll:-1.3786 curv:0.0000 floor:0.2124 id:12.2539 || val ot:9868.0864 nll:-1.3743 curv:0.0000 floor:0.2127 id:1.0000 total:9876.7139
# INFO:root:Saved best model (val score=9866.7121)
# INFO:root:[train] epoch 108 step 10/17 ot:9467.1565 nll:-1.3908 curv:0.0000 floor:0.2129 id:11.4845
# INFO:root:Epoch 108 | train total=9812.5516 ot:9695.3312 nll:-1.3826 curv:0.0000 floor:0.2130 id:11.8601 || val ot:9786.6226 nll:-1.3780 curv:0.0000 floor:0.2133 id:1.0000 total:9795.2466
# INFO:root:Saved best model (val score=9785.2446)
# INFO:root:[train] epoch 109 step 10/17 ot:9742.2670 nll:-1.3910 curv:0.0000 floor:0.2135 id:11.5844
# INFO:root:Epoch 109 | train total=9734.6110 ot:9621.4828 nll:-1.3869 curv:0.0000 floor:0.2137 id:11.4513 || val ot:9679.3750 nll:-1.3829 curv:0.0000 floor:0.2141 id:1.0000 total:9687.9941
# INFO:root:Saved best model (val score=9677.9921)
# INFO:root:[train] epoch 110 step 10/17 ot:9404.1953 nll:-1.3832 curv:0.0000 floor:0.2142 id:10.9180
# INFO:root:Epoch 110 | train total=9628.3383 ot:9519.2078 nll:-1.3913 curv:0.0000 floor:0.2143 id:11.0520 || val ot:9600.0933 nll:-1.3881 curv:0.0000 floor:0.2147 id:1.0000 total:9608.7070
# INFO:root:Saved best model (val score=9598.7052)
# INFO:root:[train] epoch 111 step 10/17 ot:9636.9145 nll:-1.3846 curv:0.0000 floor:0.2148 id:10.9310
# INFO:root:Epoch 111 | train total=9546.5807 ot:9441.2351 nll:-1.3957 curv:0.0000 floor:0.2149 id:10.6739 || val ot:9517.6890 nll:-1.3927 curv:0.0000 floor:0.2153 id:1.0000 total:9526.2983
# INFO:root:Saved best model (val score=9516.2962)
# INFO:root:[train] epoch 112 step 10/17 ot:9546.3411 nll:-1.3896 curv:0.0000 floor:0.2155 id:10.4891
# INFO:root:Epoch 112 | train total=9459.1805 ot:9357.5547 nll:-1.3998 curv:0.0000 floor:0.2156 id:10.3024 || val ot:9440.2754 nll:-1.3961 curv:0.0000 floor:0.2159 id:1.0000 total:9448.8813
# INFO:root:Saved best model (val score=9438.8793)
# INFO:root:[train] epoch 113 step 10/17 ot:9173.2986 nll:-1.3958 curv:0.0000 floor:0.2161 id:9.8120
# INFO:root:Epoch 113 | train total=9370.6899 ot:9272.6685 nll:-1.4043 curv:0.0000 floor:0.2162 id:9.9424 || val ot:9362.5312 nll:-1.4009 curv:0.0000 floor:0.2165 id:1.0000 total:9371.1323
# INFO:root:Saved best model (val score=9361.1304)
# INFO:root:[train] epoch 114 step 10/17 ot:9254.8845 nll:-1.4021 curv:0.0000 floor:0.2167 id:9.6443
# INFO:root:Epoch 114 | train total=9301.9752 ot:9207.4182 nll:-1.4089 curv:0.0000 floor:0.2169 id:9.5964 || val ot:9279.6650 nll:-1.4046 curv:0.0000 floor:0.2171 id:1.0000 total:9288.2622
# INFO:root:Saved best model (val score=9278.2605)
# INFO:root:[train] epoch 115 step 10/17 ot:9134.5226 nll:-1.4024 curv:0.0000 floor:0.2174 id:9.2589
# INFO:root:Epoch 115 | train total=9217.7930 ot:9126.5921 nll:-1.4138 curv:0.0000 floor:0.2175 id:9.2613 || val ot:9175.0605 nll:-1.4100 curv:0.0000 floor:0.2180 id:1.0000 total:9183.6523
# INFO:root:Saved best model (val score=9173.6506)
# INFO:root:[train] epoch 116 step 10/17 ot:8975.8110 nll:-1.4227 curv:0.0000 floor:0.2180 id:8.8583
# INFO:root:Epoch 116 | train total=9132.0452 ot:9044.2158 nll:-1.4175 curv:0.0000 floor:0.2182 id:8.9245 || val ot:9098.6499 nll:-1.4144 curv:0.0000 floor:0.2186 id:1.0000 total:9107.2373
# INFO:root:Saved best model (val score=9097.2355)
# INFO:root:[train] epoch 117 step 10/17 ot:9046.8621 nll:-1.4158 curv:0.0000 floor:0.2187 id:8.6937
# INFO:root:Epoch 117 | train total=9048.6208 ot:8964.0905 nll:-1.4216 curv:0.0000 floor:0.2188 id:8.5950 || val ot:9022.0933 nll:-1.4189 curv:0.0000 floor:0.2192 id:1.0000 total:9030.6763
# INFO:root:Saved best model (val score=9020.6744)
# INFO:root:[train] epoch 118 step 10/17 ot:9063.0004 nll:-1.4292 curv:0.0000 floor:0.2194 id:8.5147
# INFO:root:Epoch 118 | train total=8958.9831 ot:8877.5854 nll:-1.4272 curv:0.0000 floor:0.2195 id:8.2823 || val ot:8945.7671 nll:-1.4227 curv:0.0000 floor:0.2198 id:1.0000 total:8954.3462
# INFO:root:Saved best model (val score=8944.3444)
# INFO:root:[train] epoch 119 step 10/17 ot:8610.4804 nll:-1.4346 curv:0.0000 floor:0.2200 id:7.8097
# ...
# INFO:root:[train] epoch 1308 step 10/17 ot:0.3934 nll:-6.5969 curv:0.0171 floor:0.4626 id:6994.3341
# INFO:root:Epoch 1308 | train total=69943.2537 ot:0.3846 nll:-6.5908 curv:0.0171 floor:0.4626 id:6994.9455 || val ot:74.8097 nll:-6.5847 curv:0.0171 floor:0.4626 id:1.0000 total:78.2296
# INFO:root:[train] epoch 1309 step 10/17 ot:0.3828 nll:-6.5823 curv:0.0171 floor:0.4626 id:7015.2616
# INFO:root:Epoch 1309 | train total=70150.7918 ot:0.3846 nll:-6.5908 curv:0.0171 floor:0.4626 id:7015.6992 || val ot:74.9785 nll:-6.5863 curv:0.0171 floor:0.4626 id:1.0000 total:78.3968
# INFO:root:[train] epoch 1310 step 10/17 ot:0.3887 nll:-6.5871 curv:0.0171 floor:0.4626 id:7035.9548
# INFO:root:Epoch 1310 | train total=70358.8456 ot:0.3844 nll:-6.5916 curv:0.0172 floor:0.4626 id:7036.5047 || val ot:75.1030 nll:-6.5863 curv:0.0172 floor:0.4626 id:1.0000 total:78.5213
# INFO:root:[train] epoch 1311 step 10/17 ot:0.3926 nll:-6.5990 curv:0.0172 floor:0.4626 id:7056.8860
# INFO:root:Epoch 1311 | train total=70567.9081 ot:0.3821 nll:-6.5923 curv:0.0172 floor:0.4626 id:7057.4114 || val ot:75.2255 nll:-6.5867 curv:0.0172 floor:0.4626 id:1.0000 total:78.6434
# INFO:root:[train] epoch 1312 step 10/17 ot:0.3864 nll:-6.5918 curv:0.0172 floor:0.4626 id:7077.9036
# INFO:root:Epoch 1312 | train total=70777.1806 ot:0.3811 nll:-6.5934 curv:0.0172 floor:0.4626 id:7078.3388 || val ot:75.3504 nll:-6.5879 curv:0.0173 floor:0.4626 id:1.0000 total:78.7671
# INFO:root:[train] epoch 1313 step 10/17 ot:0.3756 nll:-6.6038 curv:0.0173 floor:0.4626 id:7099.1401
# INFO:root:Epoch 1313 | train total=70987.0676 ot:0.3799 nll:-6.5936 curv:0.0173 floor:0.4626 id:7099.3277 || val ot:75.4745 nll:-6.5887 curv:0.0173 floor:0.4627 id:1.0000 total:78.8904
# INFO:root:[train] epoch 1314 step 10/17 ot:0.3927 nll:-6.5886 curv:0.0173 floor:0.4627 id:7119.6824
# INFO:root:Epoch 1314 | train total=71197.5129 ot:0.3790 nll:-6.5949 curv:0.0173 floor:0.4627 id:7120.3725 || val ot:75.5971 nll:-6.5888 curv:0.0174 floor:0.4627 id:1.0000 total:79.0130
# INFO:root:[train] epoch 1315 step 10/17 ot:0.3907 nll:-6.5921 curv:0.0174 floor:0.4627 id:7140.6943
# INFO:root:Epoch 1315 | train total=71408.1457 ot:0.3773 nll:-6.5947 curv:0.0174 floor:0.4627 id:7141.4359 || val ot:75.7680 nll:-6.5896 curv:0.0174 floor:0.4627 id:1.0000 total:79.1830
# INFO:root:[train] epoch 1316 step 10/17 ot:0.3650 nll:-6.5983 curv:0.0174 floor:0.4627 id:7162.3672
# INFO:root:Epoch 1316 | train total=71619.0634 ot:0.3768 nll:-6.5955 curv:0.0175 floor:0.4627 id:7162.5278 || val ot:75.8920 nll:-6.5902 curv:0.0175 floor:0.4627 id:1.0000 total:79.3064
# INFO:root:[train] epoch 1317 step 10/17 ot:0.3734 nll:-6.5876 curv:0.0175 floor:0.4627 id:7183.3772
# INFO:root:Epoch 1317 | train total=71830.4449 ot:0.3761 nll:-6.5951 curv:0.0175 floor:0.4627 id:7183.6661 || val ot:76.0160 nll:-6.5912 curv:0.0175 floor:0.4627 id:1.0000 total:79.4295
# INFO:root:[train] epoch 1318 step 10/17 ot:0.3692 nll:-6.6020 curv:0.0175 floor:0.4627 id:7204.6534
# INFO:root:Epoch 1318 | train total=72042.6310 ot:0.3755 nll:-6.5962 curv:0.0175 floor:0.4627 id:7204.8847 || val ot:76.1384 nll:-6.5911 curv:0.0176 floor:0.4627 id:1.0000 total:79.5519
# INFO:root:[train] epoch 1319 step 10/17 ot:0.3830 nll:-6.5952 curv:0.0176 floor:0.4627 id:7225.6944
# INFO:root:Epoch 1319 | train total=72255.1990 ot:0.3744 nll:-6.5966 curv:0.0176 floor:0.4627 id:7226.1416 || val ot:76.2626 nll:-6.5918 curv:0.0176 floor:0.4627 id:1.0000 total:79.6754
# INFO:root:[train] epoch 1320 step 10/17 ot:0.3764 nll:-6.6006 curv:0.0176 floor:0.4627 id:7246.9694
# INFO:root:Epoch 1320 | train total=72468.6778 ot:0.3718 nll:-6.5979 curv:0.0177 floor:0.4627 id:7247.4901 || val ot:76.3862 nll:-6.5925 curv:0.0177 floor:0.4627 id:1.0000 total:79.7984
# INFO:root:[train] epoch 1321 step 10/17 ot:0.3654 nll:-6.6005 curv:0.0177 floor:0.4627 id:7268.3948
# INFO:root:Epoch 1321 | train total=72681.7914 ot:0.3710 nll:-6.5984 curv:0.0177 floor:0.4627 id:7268.8014 || val ot:76.5567 nll:-6.5930 curv:0.0177 floor:0.4628 id:1.0000 total:79.9683
# INFO:root:[train] epoch 1322 step 10/17 ot:0.3685 nll:-6.6019 curv:0.0177 floor:0.4628 id:7289.8358
# INFO:root:Epoch 1322 | train total=72895.2776 ot:0.3713 nll:-6.5978 curv:0.0178 floor:0.4628 id:7290.1501 || val ot:76.6811 nll:-6.5932 curv:0.0178 floor:0.4628 id:1.0000 total:80.0925
# INFO:root:[train] epoch 1323 step 10/17 ot:0.3766 nll:-6.6025 curv:0.0178 floor:0.4628 id:7311.1208
# INFO:root:Epoch 1323 | train total=73109.6218 ot:0.3702 nll:-6.5994 curv:0.0178 floor:0.4628 id:7311.5847 || val ot:76.8057 nll:-6.5938 curv:0.0178 floor:0.4628 id:1.0000 total:80.2165
# INFO:root:[train] epoch 1324 step 10/17 ot:0.3711 nll:-6.6015 curv:0.0179 floor:0.4628 id:7332.6921
# INFO:root:Epoch 1324 | train total=73324.6365 ot:0.3678 nll:-6.5997 curv:0.0179 floor:0.4628 id:7333.0864 || val ot:76.9293 nll:-6.5941 curv:0.0179 floor:0.4628 id:1.0000 total:80.3399
# INFO:root:[train] epoch 1325 step 10/17 ot:0.3617 nll:-6.5987 curv:0.0179 floor:0.4628 id:7354.3071
# INFO:root:Epoch 1325 | train total=73540.0983 ot:0.3664 nll:-6.6007 curv:0.0179 floor:0.4628 id:7354.6328 || val ot:77.0534 nll:-6.5953 curv:0.0179 floor:0.4628 id:1.0000 total:80.4626
# INFO:root:[train] epoch 1326 step 10/17 ot:0.3773 nll:-6.6040 curv:0.0180 floor:0.4628 id:7375.5158
# INFO:root:Epoch 1326 | train total=73755.9706 ot:0.3657 nll:-6.6004 curv:0.0180 floor:0.4628 id:7376.2202 || val ot:77.1771 nll:-6.5957 curv:0.0180 floor:0.4628 id:1.0000 total:80.5860
# INFO:root:[train] epoch 1327 step 10/17 ot:0.3616 nll:-6.5960 curv:0.0180 floor:0.4628 id:7397.5002
# INFO:root:Epoch 1327 | train total=73971.6926 ot:0.3656 nll:-6.6013 curv:0.0180 floor:0.4628 id:7397.7924 || val ot:77.3465 nll:-6.5962 curv:0.0181 floor:0.4628 id:1.0000 total:80.7549
# INFO:root:[train] epoch 1328 step 10/17 ot:0.3617 nll:-6.6044 curv:0.0181 floor:0.4628 id:7418.9688
# INFO:root:Epoch 1328 | train total=74188.3258 ot:0.3640 nll:-6.6020 curv:0.0181 floor:0.4628 id:7419.4559 || val ot:77.4740 nll:-6.5977 curv:0.0181 floor:0.4628 id:1.0000 total:80.8809
# INFO:root:[train] epoch 1329 step 10/17 ot:0.3641 nll:-6.6114 curv:0.0181 floor:0.4628 id:7440.6890
# INFO:root:Epoch 1329 | train total=74405.3107 ot:0.3633 nll:-6.6022 curv:0.0181 floor:0.4628 id:7441.1546 || val ot:77.5981 nll:-6.5981 curv:0.0181 floor:0.4628 id:1.0000 total:81.0046
# INFO:root:[train] epoch 1330 step 10/17 ot:0.3538 nll:-6.6071 curv:0.0182 floor:0.4628 id:7462.7336
# INFO:root:Epoch 1330 | train total=74622.9214 ot:0.3624 nll:-6.6031 curv:0.0182 floor:0.4628 id:7462.9157 || val ot:77.7222 nll:-6.5976 curv:0.0182 floor:0.4629 id:1.0000 total:81.1292
# INFO:root:[train] epoch 1331 step 10/17 ot:0.3715 nll:-6.6143 curv:0.0182 floor:0.4629 id:7484.1559
# INFO:root:Epoch 1331 | train total=74841.1149 ot:0.3611 nll:-6.6037 curv:0.0182 floor:0.4629 id:7484.7353 || val ot:77.8460 nll:-6.5979 curv:0.0182 floor:0.4629 id:1.0000 total:81.2528
# INFO:root:[train] epoch 1332 step 10/17 ot:0.3617 nll:-6.6010 curv:0.0183 floor:0.4629 id:7506.0834
# INFO:root:Epoch 1332 | train total=75059.7256 ot:0.3603 nll:-6.6043 curv:0.0183 floor:0.4629 id:7506.5965 || val ot:77.9700 nll:-6.5990 curv:0.0183 floor:0.4629 id:1.0000 total:81.3756
# INFO:root:[train] epoch 1333 step 10/17 ot:0.3659 nll:-6.5985 curv:0.0183 floor:0.4629 id:7527.8695
# INFO:root:Epoch 1333 | train total=75278.4297 ot:0.3597 nll:-6.6053 curv:0.0183 floor:0.4629 id:7528.4671 || val ot:78.1413 nll:-6.5997 curv:0.0183 floor:0.4629 id:1.0000 total:81.5463
# INFO:root:[train] epoch 1334 step 10/17 ot:0.3637 nll:-6.5982 curv:0.0184 floor:0.4629 id:7549.8570
# INFO:root:Epoch 1334 | train total=75497.7050 ot:0.3581 nll:-6.6052 curv:0.0184 floor:0.4629 id:7550.3948 || val ot:78.2670 nll:-6.6001 curv:0.0184 floor:0.4629 id:1.0000 total:81.6715
# INFO:root:[train] epoch 1335 step 10/17 ot:0.3463 nll:-6.6251 curv:0.0184 floor:0.4629 id:7572.1429
# INFO:root:Epoch 1335 | train total=75717.5285 ot:0.3573 nll:-6.6057 curv:0.0184 floor:0.4629 id:7572.3772 || val ot:78.3910 nll:-6.6012 curv:0.0184 floor:0.4629 id:1.0000 total:81.7945
# INFO:root:[train] epoch 1336 step 10/17 ot:0.3448 nll:-6.6207 curv:0.0185 floor:0.4629 id:7594.2879
# INFO:root:Epoch 1336 | train total=75937.8157 ot:0.3568 nll:-6.6061 curv:0.0185 floor:0.4629 id:7594.4060 || val ot:78.5145 nll:-6.6018 curv:0.0185 floor:0.4629 id:1.0000 total:81.9173
# INFO:root:[train] epoch 1337 step 10/17 ot:0.3584 nll:-6.5928 curv:0.0185 floor:0.4629 id:7616.0423
# INFO:root:Epoch 1337 | train total=76159.0142 ot:0.3546 nll:-6.6070 curv:0.0185 floor:0.4629 id:7616.5262 || val ot:78.6408 nll:-6.6018 curv:0.0185 floor:0.4629 id:1.0000 total:82.0437
# INFO:root:[train] epoch 1338 step 10/17 ot:0.3543 nll:-6.6095 curv:0.0186 floor:0.4629 id:7638.2939
# INFO:root:Epoch 1338 | train total=76380.3571 ot:0.3541 nll:-6.6084 curv:0.0186 floor:0.4629 id:7638.6608 || val ot:78.7641 nll:-6.6029 curv:0.0186 floor:0.4629 id:1.0000 total:82.1658
# INFO:root:[train] epoch 1339 step 10/17 ot:0.3672 nll:-6.5944 curv:0.0186 floor:0.4629 id:7660.0841
# INFO:root:Epoch 1339 | train total=76601.9903 ot:0.3532 nll:-6.6084 curv:0.0186 floor:0.4629 id:7660.8240 || val ot:78.9367 nll:-6.6027 curv:0.0186 floor:0.4629 id:1.0000 total:82.3386
# INFO:root:[train] epoch 1340 step 10/17 ot:0.3531 nll:-6.6036 curv:0.0186 floor:0.4629 id:7682.5748
# INFO:root:Epoch 1340 | train total=76824.0653 ot:0.3522 nll:-6.6085 curv:0.0187 floor:0.4629 id:7683.0316 || val ot:79.0620 nll:-6.6032 curv:0.0187 floor:0.4630 id:1.0000 total:82.4635
# INFO:root:[train] epoch 1341 step 10/17 ot:0.3526 nll:-6.6004 curv:0.0187 floor:0.4630 id:7704.8777
# INFO:root:Epoch 1341 | train total=77046.6213 ot:0.3519 nll:-6.6089 curv:0.0187 floor:0.4630 id:7705.2873 || val ot:79.1864 nll:-6.6040 curv:0.0187 floor:0.4630 id:1.0000 total:82.5870
# INFO:root:[train] epoch 1342 step 10/17 ot:0.3448 nll:-6.6042 curv:0.0188 floor:0.4630 id:7727.3697
# INFO:root:Epoch 1342 | train total=77270.1291 ot:0.3504 nll:-6.6106 curv:0.0188 floor:0.4630 id:7727.6384 || val ot:79.3113 nll:-6.6045 curv:0.0188 floor:0.4630 id:1.0000 total:82.7115
# INFO:root:[train] epoch 1343 step 10/17 ot:0.3496 nll:-6.6120 curv:0.0188 floor:0.4630 id:7749.6041
# INFO:root:Epoch 1343 | train total=77493.9288 ot:0.3498 nll:-6.6109 curv:0.0188 floor:0.4630 id:7750.0186 || val ot:79.4362 nll:-6.6049 curv:0.0188 floor:0.4630 id:1.0000 total:82.8359
# INFO:root:[train] epoch 1344 step 10/17 ot:0.3449 nll:-6.6076 curv:0.0189 floor:0.4630 id:7772.1149
# INFO:root:Epoch 1344 | train total=77718.0873 ot:0.3501 nll:-6.6101 curv:0.0189 floor:0.4630 id:7772.4343 || val ot:79.5607 nll:-6.6048 curv:0.0189 floor:0.4630 id:1.0000 total:82.9605
# INFO:root:[train] epoch 1345 step 10/17 ot:0.3421 nll:-6.6223 curv:0.0189 floor:0.4630 id:7794.6987
# INFO:root:Epoch 1345 | train total=77942.6415 ot:0.3484 nll:-6.6104 curv:0.0189 floor:0.4630 id:7794.8899 || val ot:79.7325 nll:-6.6060 curv:0.0190 floor:0.4630 id:1.0000 total:83.1311
# INFO:root:[train] epoch 1346 step 10/17 ot:0.3554 nll:-6.6039 curv:0.0190 floor:0.4630 id:7816.7667
# INFO:root:Epoch 1346 | train total=78167.9154 ot:0.3464 nll:-6.6122 curv:0.0190 floor:0.4630 id:7817.4175 || val ot:79.8586 nll:-6.6061 curv:0.0190 floor:0.4630 id:1.0000 total:83.2571
# INFO:root:[train] epoch 1347 step 10/17 ot:0.3447 nll:-6.6175 curv:0.0190 floor:0.4630 id:7839.5910
# INFO:root:Epoch 1347 | train total=78393.4756 ot:0.3456 nll:-6.6128 curv:0.0190 floor:0.4630 id:7839.9737 || val ot:79.9833 nll:-6.6075 curv:0.0191 floor:0.4630 id:1.0000 total:83.3805
# INFO:root:[train] epoch 1348 step 10/17 ot:0.3481 nll:-6.6025 curv:0.0191 floor:0.4630 id:7862.0845
# INFO:root:Epoch 1348 | train total=78619.7128 ot:0.3449 nll:-6.6127 curv:0.0191 floor:0.4630 id:7862.5978 || val ot:80.1101 nll:-6.6079 curv:0.0191 floor:0.4630 id:1.0000 total:83.5068
# INFO:root:[train] epoch 1349 step 10/17 ot:0.3485 nll:-6.6069 curv:0.0191 floor:0.4630 id:7884.7781
# INFO:root:Epoch 1349 | train total=78846.3346 ot:0.3446 nll:-6.6130 curv:0.0191 floor:0.4630 id:7885.2599 || val ot:80.2336 nll:-6.6083 curv:0.0191 floor:0.4630 id:1.0000 total:83.6299
# INFO:root:[train] epoch 1350 step 10/17 ot:0.3516 nll:-6.6113 curv:0.0192 floor:0.4631 id:7907.3977
# INFO:root:Epoch 1350 | train total=79073.7799 ot:0.3430 nll:-6.6146 curv:0.0192 floor:0.4631 id:7908.0045 || val ot:80.3581 nll:-6.6083 curv:0.0192 floor:0.4631 id:1.0000 total:83.7544
# INFO:root:[train] epoch 1351 step 10/17 ot:0.3491 nll:-6.6094 curv:0.0192 floor:0.4631 id:7930.1120
# INFO:root:Epoch 1351 | train total=79300.9747 ot:0.3428 nll:-6.6142 curv:0.0192 floor:0.4631 id:7930.7241 || val ot:80.5312 nll:-6.6091 curv:0.0193 floor:0.4631 id:1.0000 total:83.9267
# INFO:root:[train] epoch 1352 step 10/17 ot:0.3504 nll:-6.6235 curv:0.0193 floor:0.4631 id:7952.8312
# INFO:root:Epoch 1352 | train total=79528.9550 ot:0.3415 nll:-6.6152 curv:0.0193 floor:0.4631 id:7953.5223 || val ot:80.6575 nll:-6.6102 curv:0.0193 floor:0.4631 id:1.0000 total:84.0520
# INFO:root:[train] epoch 1353 step 10/17 ot:0.3378 nll:-6.6063 curv:0.0193 floor:0.4631 id:7975.9243
# INFO:root:Epoch 1353 | train total=79757.3699 ot:0.3408 nll:-6.6160 curv:0.0193 floor:0.4631 id:7976.3641 || val ot:80.7819 nll:-6.6103 curv:0.0193 floor:0.4631 id:1.0000 total:84.1762
# INFO:root:[train] epoch 1354 step 10/17 ot:0.3355 nll:-6.6188 curv:0.0194 floor:0.4631 id:7998.9388
# INFO:root:Epoch 1354 | train total=79986.2702 ot:0.3404 nll:-6.6156 curv:0.0194 floor:0.4631 id:7999.2540 || val ot:80.9070 nll:-6.6102 curv:0.0194 floor:0.4631 id:1.0000 total:84.3014
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 567
#     565 best_val = float("inf")
#     566 for epoch in range(1, CONFIG["training"]["epochs"]+1):
# --> 567     tr = trainer.train_epoch(train_loader, epoch, phase="train")
#     568     vl = trainer.train_epoch(val_loader,   epoch, phase="val")
#     570     # Force a plot refresh at epoch end
#
# Cell In[6], line 395, in InverseScaleTrainer.train_epoch(self, loader, epoch, phase)
#     393 if train:
#     394     self.opt.zero_grad(set_to_none=True)
# --> 395     loss.backward()
#     396     torch.nn.utils.clip_grad_norm_(list(self.psi.parameters()), max_norm=self.cfg["training"]["grad_clip_norm"])
#     397     self.opt.step()
#
# File /opt/anaconda3/envs/manip311/lib/python3.11/site-packages/torch/_tensor.py:653, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     643 if has_torch_function_unary(self):
#     644     return handle_torch_function(
#     645         Tensor.backward,
#     646         (self,),
#    (...)    651         inputs=inputs,
#     652     )
# --> 653 torch.autograd.backward(
#     654     self, gradient, retain_graph, create_graph, inputs=inputs
#     655 )
#
# File /opt/anaconda3/envs/manip311/lib/python3.11/site-packages/torch/autograd/__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File /opt/anaconda3/envs/manip311/lib/python3.11/site-packages/torch/autograd/graph.py:829, in _engine_run_backward(t_outputs, *args, **kwargs)
#     827     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828 try:
# --> 829     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830         t_outputs, *args, **kwargs
#     831     )  # Calls into the C++ engine to run the backward pass
#     832 finally:
#     833     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
# ============================================================
# Inverse mapping training: ψ:(0,1)->R learned from per-face
# rating distributions (quantile transport + robust NLL)
# ============================================================

import os, logging, pickle
from pathlib import Path
from typing import Dict, Tuple, List, Optional

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# ------------------ Utilities: bootstrap & I/O ------------------

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
DTYPE  = torch.float32

def bootstrap_tensor(data: torch.Tensor) -> torch.Tensor:
    """
    Bootstraps along dim=1 (ratings), preserving NaNs, used by load_interp_data.
    Expects shape (1, N) or (B, N); returns same shape.
    """
    if data.dim() == 1:
        data = data.unsqueeze(0)
    B, N = data.shape
    mask = ~torch.isnan(data)
    out = torch.full_like(data, float('nan'))
    for b in range(B):
        valid = data[b, mask[b]]
        if valid.numel() == 0:
            out[b] = torch.full((N,), 0.5, device=data.device, dtype=data.dtype)
            continue
        idx = torch.randint(0, valid.numel(), (N,), device=data.device)
        out[b] = valid[idx]
    return out

def pad_list(l, max_len):
    return l[:max_len] + [np.nan] * (max_len - len(l[:max_len]))

def load_interp_data(base_dir = "/Users/adamsobieszek/PycharmProjects/PsychGAN/", scale=1) -> Tuple[
    Dict[str, torch.Tensor],
    Dict[str, Dict[str, torch.Tensor]]
]:
    """
    Load latent coordinates (unused here), and ratings with bootstrap per image.
    Returns: (photo_to_coords, dim_to_photo_to_ratings)
    """
    base_dir = Path(base_dir)
    p2c_path = base_dir / "newer_photo_to_coords.pt"
    d2p2r_path = base_dir / "dim_to_photo_to_ratings2.pkl"
    with open(d2p2r_path, "rb") as f:
        dim_to_photo_to_ratings = pickle.load(f)
    photo_to_coords = torch.load(p2c_path, map_location="cpu")
    photo_to_coords = {k: torch.tensor(photo_to_coords[k]).cpu().flatten()[:512] for k in photo_to_coords}
    for k in dim_to_photo_to_ratings:
        max_len = int(max(len(dim_to_photo_to_ratings[k][kk]) for kk in dim_to_photo_to_ratings[k]) * 2.5)
        dim_to_photo_to_ratings[k] = {
            kk: bootstrap_tensor(
                    (((-0.005 if scale!=1 else 0.0) + torch.tensor(pad_list(dim_to_photo_to_ratings[k][kk], max_len))).reshape(1, -1)) * scale
                ).reshape(-1)
            for kk in dim_to_photo_to_ratings[k]
        }
    return photo_to_coords, dim_to_photo_to_ratings

# ------------------ Dataset & Collate ------------------

class ItemRatingsDataset(Dataset):
    """
    One sample = one face (item).
    y_raw: raw ratings as integers [0..100] with NaNs padded (bootstrapped in loader).
    We convert to unit scale (0,1) inside collate.
    """
    def __init__(self,
                 dim_to_photo_to_ratings: Dict[str, Dict[str, torch.Tensor]],
                 target_dim: str = "age",
                 min_ratings: int = 10):
        dims = list(dim_to_photo_to_ratings.keys())
        dim = next((d for d in dims if target_dim.lower() in d.lower()), dims[0])
        self.dim_name = dim
        p2r = dim_to_photo_to_ratings[dim]
        items, ratings = [], []
        for photo, r in p2r.items():
            r = torch.as_tensor(r, dtype=torch.float32)
            n_valid = (~torch.isnan(r)).sum().item()
            if n_valid >= min_ratings:
                items.append(photo)
                ratings.append(r)
        self.items = items
        self.ratings = ratings  # list of 1D tensors with NaNs padded

    def __len__(self): return len(self.items)

    def __getitem__(self, idx):
        return {
            "item_id": idx,
            "photo": self.items[idx],
            "ratings_raw": self.ratings[idx]  # 0..100 with NaNs
        }

def to_unit(y_int: torch.Tensor) -> torch.Tensor:
    # y_int can contain NaNs; keep them
    return torch.where(
        torch.isnan(y_int),
        y_int,
        torch.clamp((y_int + 0.5)/101.0, 1e-6, 1-1e-6)
    )

def collate_items_quantiles(batch: List[dict],
                            quantiles: torch.Tensor,
                            subsample_raw: Optional[int]=None):
    """
    Build a batch:
    - Qy: per-item empirical quantiles (unit scale)
    - y_all: stacked raw unit ratings for optional likelihood (with NaNs removed; possibly subsampled)
    - n_i: counts per item
    """
    item_ids = torch.tensor([b["item_id"] for b in batch], dtype=torch.long)
    # Prepare quantiles and raw ratings (unit)
    Qy_list, y_raw_list, n_list = [], [], []
    for b in batch:
        y_int = b["ratings_raw"].clone().detach()
        y = to_unit(y_int)  # unit in (0,1)
        y_valid = y[~torch.isnan(y)]
        n = y_valid.numel()
        if n == 0:
            # fall back: uniform
            Qy = quantiles.clone()
            yv = torch.tensor([], dtype=torch.float32)
        else:
            Qy = torch.quantile(y_valid, quantiles.to(y_valid.device))
            if (subsample_raw is not None) and (n > subsample_raw):
                idx = torch.randint(0, n, (subsample_raw,), device=y_valid.device)
                yv = y_valid[idx]
            else:
                yv = y_valid
        Qy_list.append(Qy)
        y_raw_list.append(yv)
        n_list.append(n)

    # Pad y_raw_list into a ragged batch (list) – trainer will loop
    batch_data = {
        "item_ids": item_ids,
        "Qy_list": Qy_list,          # list of tensors (K,)
        "y_raw_list": y_raw_list,    # list of tensors (n_i_subsample,)
        "n_list": torch.tensor(n_list, dtype=torch.float32),
    }
    return batch_data

# ------------------ Monotone ψ model ------------------

class MonoPsiGrid(nn.Module):
    """
    Global monotone map ψ on y∈(0,1) via positive derivative on a uniform grid.
    ψ(0)=0 (reference). Strictly increasing via softplus on derivative.
    """
    def __init__(self, M:int=200, eps_floor:float=1e-4):
        super().__init__()
        self.M = M
        self.register_buffer("y_grid", torch.linspace(0., 1., M, dtype=DTYPE))
        self.rho = nn.Parameter(torch.zeros(M, dtype=DTYPE))   # unconstrained
        self.eps_floor = eps_floor
        # optional global affine (can keep fixed at identity)
        self.shift = nn.Parameter(torch.tensor(0., dtype=DTYPE))
        self.scale = nn.Parameter(torch.tensor(1., dtype=DTYPE))

    def deriv_at_grid(self) -> torch.Tensor:
        # ψ'(y_m) = eps + softplus(rho_m)
        return self.eps_floor + torch.nn.functional.softplus(self.rho)

    def psi_grid_values(self) -> torch.Tensor:
        # Integrate derivative over grid (trapezoid). ψ(0)=0 baseline.
        d = self.deriv_at_grid()
        y = self.y_grid
        # uniform grid spacing
        h = y[1]-y[0]
        # trapezoid cumulative integral
        # integral at grid k: sum over intervals [m,m+1]
        # cum_d_mid = 0.5*(d[m] + d[m+1])
        d_left = d[:-1]
        d_right = d[1:]
        inc = 0.5*h*(d_left + d_right)
        psi0 = torch.zeros(1, dtype=DTYPE, device=d.device)
        psi_vals = torch.cat([psi0, torch.cumsum(inc, dim=0)], dim=0)  # length M
        # affine gauge (learned): scale & shift
        return self.shift + self.scale * psi_vals

    def forward(self, y_query: torch.Tensor) -> torch.Tensor:
        """
        y_query: (...,) in (0,1); returns ψ(y_query).
        Linear interpolates ψ values on grid; differentiable w.r.t. params.
        """
        y = torch.clamp(y_query, 1e-6, 1-1e-6)
        psi_vals = self.psi_grid_values()
        # indices for interpolation
        # searchsorted expects ascending grid; keep in [1, M-1] to have left & right
        idx_right = torch.searchsorted(self.y_grid, y)
        idx_right = torch.clamp(idx_right, 1, self.M-1)
        idx_left = idx_right - 1
        y0 = self.y_grid[idx_left]
        y1 = self.y_grid[idx_right]
        psi0 = psi_vals[idx_left]
        psi1 = psi_vals[idx_right]
        t = (y - y0) / torch.clamp(y1 - y0, 1e-12)
        return psi0 + t*(psi1 - psi0)

    # regularizers helpers
    def curvature_penalty(self) -> torch.Tensor:
        psi = self.psi_grid_values()
        # second differences
        d2 = psi[:-2] - 2*psi[1:-1] + psi[2:]
        return torch.mean(d2**2)

    def floor_barrier(self) -> torch.Tensor:
        d = self.deriv_at_grid()
        # penalize going below a slightly larger floor than eps_floor
        target = 2.0*self.eps_floor
        return torch.mean(torch.nn.functional.softplus(target - d)**2)

class ItemEmbeddings(nn.Module):
    """
    Per-item Θ and σ (heteroscedastic). σ = σ_min + softplus(ρ).
    """
    def __init__(self, num_items:int, sigma_min:float=1e-3):
        super().__init__()
        self.theta = nn.Embedding(num_items, 1)
        self.rho   = nn.Embedding(num_items, 1)
        nn.init.zeros_(self.theta.weight)
        nn.init.zeros_(self.rho.weight)
        self.sigma_min = sigma_min

    def forward(self, item_ids: torch.Tensor):
        theta = self.theta(item_ids).squeeze(-1)
        sigma = self.sigma_min + torch.nn.functional.softplus(self.rho(item_ids).squeeze(-1))
        return theta, sigma

# ------------------ Loss functions ------------------

def normal_quantiles(tau: torch.Tensor, device=None, dtype=None) -> torch.Tensor:
    dist = torch.distributions.Normal(loc=torch.tensor(0., device=device, dtype=dtype),
                                      scale=torch.tensor(1., device=device, dtype=dtype))
    return dist.icdf(torch.clamp(tau, 1e-6, 1-1e-6))

def ot_quantile_loss(psi: MonoPsiGrid,
                     item_ids: torch.Tensor,
                     Qy_list: List[torch.Tensor],
                     embeddings: ItemEmbeddings,
                     tau: torch.Tensor,
                     weights_per_item: Optional[torch.Tensor]=None) -> torch.Tensor:
    """
    Quantile alignment: ψ(Q_y(τ)) ≈ Θ_i + σ_i Φ^{-1}(τ)
    """
    device = item_ids.device
    q_norm = normal_quantiles(tau.to(device), device=device, dtype=DTYPE)
    theta, sigma = embeddings(item_ids)  # (B,)
    losses = []
    for b, Qy in enumerate(Qy_list):
        z_hat = psi(Qy.to(device))                # shape (K,)
        target = theta[b] + sigma[b] * q_norm     # shape (K,)
        e = z_hat - target
        l = torch.mean(e**2)
        if weights_per_item is not None:
            l = l * weights_per_item[b]
        losses.append(l)
    return torch.mean(torch.stack(losses)) if losses else torch.tensor(0., device=device)
# --- EDIT: add optional item weights to student_t_nll ---
def student_t_nll(psi: MonoPsiGrid,
                  item_ids: torch.Tensor,
                  y_raw_list: List[torch.Tensor],
                  embeddings: ItemEmbeddings,
                  nu: float = 6.0,
                  weights_per_item: Optional[torch.Tensor] = None,
                  weight_gamma: float = 1.0) -> torch.Tensor:
    device = item_ids.device
    theta, sigma = embeddings(item_ids)  # (B,)
    nu_t = torch.tensor(nu, device=device, dtype=DTYPE)
    losses = []
    for b, y_unit in enumerate(y_raw_list):
        if y_unit.numel() == 0:
            continue
        z = psi(y_unit.to(device))
        r = (z - theta[b]) / torch.clamp(sigma[b], 1e-6)
        term = ((nu_t + 1.)/2.) * torch.log1p( (r**2)/nu_t )
        nll = torch.mean(term) + torch.log(torch.clamp(sigma[b], 1e-6))
        if weights_per_item is not None:
            w = torch.clamp(weights_per_item[b], 1e-6)
            nll = nll * (w ** weight_gamma)   # temper inside NLL
        losses.append(nll)
    if not losses:
        return torch.tensor(0., device=device)
    return torch.mean(torch.stack(losses))


def identification_penalty(emb: ItemEmbeddings,
                           item_count:int,
                           lambda_mean:float=1.0,
                           lambda_var:float=1.0) -> torch.Tensor:
    theta_all = emb.theta.weight.squeeze(-1)
    mean_pen = (theta_all.mean())**2
    var_pen  = (theta_all.pow(2).mean() - 1.)**2
    return lambda_mean*mean_pen + lambda_var*var_pen

# ------------------ Trainer ------------------
# ---- MODIFY: Trainer to accept a visualizer and dataset ----
class InverseScaleTrainer:

    def __init__(self, psi_model:MonoPsiGrid,
                 emb:ItemEmbeddings,
                 config:dict,
                 visualizer: LiveInverseMappingVisualizer = None,
                 item_density_weights: Optional[torch.Tensor] = None):
        self.item_density_weights = item_density_weights  # NEW
        self.psi = psi_model.to(DEVICE)
        self.emb = emb.to(DEVICE)
        params = list(self.psi.parameters()) + list(self.emb.parameters())
        try:

            sys.path.append('/Users/adamsobieszek/PycharmProjects/_manipy/deixis/pixel2style2pixel/training')
            from ranger import Ranger
       
            self.opt = Ranger(params, lr=config["training"]["learning_rate"],)
                                # weight_decay=config["training"]["weight_decay"])
        except Exception as e:
            self.opt = optim.AdamW(params, lr=config["training"]["learning_rate"],
                                weight_decay=config["training"]["weight_decay"])
        self.scheduler = optim.lr_scheduler.CosineAnnealingLR(
            self.opt,
            T_max=config["training"]["epochs"] * config["training"]["steps_per_epoch_estimate"]
        )
        self.cfg = config
        self.quantiles = torch.tensor(config["model"]["quantiles"], dtype=DTYPE)
        self.visualizer = visualizer  # <-- new
    
    def train_epoch(self, loader: DataLoader, epoch: int = 0, phase: str = "train") -> dict:
        train = (phase == "train")
        self.psi.train(train)
        self.emb.train(train)

        tot = 0.0
        logs = {"ot": 0., "nll": 0., "curv": 0., "floor": 0., "id": 0.}

        for step, batch in enumerate(loader):
            item_ids   = batch["item_ids"].to(DEVICE)
            Qy_list    = batch["Qy_list"]
            y_raw_list = batch["y_raw_list"]
            n_list     = batch["n_list"].to(DEVICE)

            # === NEW: combine empirical density weights with n_i weighting ===
            if getattr(self, "item_density_weights", None) is not None and self.cfg["reweighting"]["enabled"]:
                w_density = self.item_density_weights[item_ids]
            else:
                w_density = torch.ones_like(n_list)

            scheme = self.cfg["training"].get("item_weighting", "none")
            if scheme == "n":
                w_n = n_list
            elif scheme == "sqrt_n":
                w_n = torch.sqrt(torch.clamp(n_list, 1))
            else:
                w_n = torch.ones_like(n_list)

            pow_n = float(self.cfg["reweighting"].get("n_weight_power", 0.0))
            if pow_n != 0.0:
                n_scaled = (n_list / (n_list.mean() + 1e-8)).clamp(1e-3)
                w_n = w_n * (n_scaled ** pow_n)

            # final combined weights
            w_items = w_density * w_n
            w_items = w_items / (w_items.mean() + 1e-8)

            # === LOSS COMPONENTS ===
            ot_w     = self.cfg["loss_weights"]["ot"]
            nll_w    = self.cfg["loss_weights"]["nll"]
            curv_w   = self.cfg["loss_weights"]["curv"]
            floor_w  = self.cfg["loss_weights"]["floor"]
            id_w     = self.cfg["loss_weights"]["id"]

            # OT (quantile) loss — weighted
            loss_ot = ot_quantile_loss(
                self.psi, item_ids, Qy_list, self.emb,
                tau=self.quantiles, weights_per_item=w_items
            )

            # NLL (Student-t) — optionally weighted / tempered
            if self.cfg["reweighting"].get("apply_to_nll", True):
                nll_gamma = float(self.cfg["reweighting"].get("nll_gamma", 0.5))
                loss_nll = student_t_nll(
                    self.psi, item_ids, y_raw_list, self.emb,
                    nu=self.cfg["model"]["student_t_nu"],
                    weights_per_item=w_items, weight_gamma=nll_gamma
                )
            else:
                loss_nll = student_t_nll(
                    self.psi, item_ids, y_raw_list, self.emb,
                    nu=self.cfg["model"]["student_t_nu"]
                )

            loss_curv = self.psi.curvature_penalty()
            loss_floor = self.psi.floor_barrier()
            loss_id = identification_penalty(
                self.emb,
                item_count=self.emb.theta.num_embeddings,
                lambda_mean=1.0, lambda_var=1.0
            )

            # total weighted loss
            loss = (ot_w * loss_ot
                    + nll_w * loss_nll
                    + curv_w * loss_curv
                    + floor_w * loss_floor
                    + id_w * loss_id)

            # === Optimization ===
            if train:
                self.opt.zero_grad(set_to_none=True)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(
                    list(self.psi.parameters()) + list(self.emb.parameters()),
                    max_norm=self.cfg["training"]["grad_clip_norm"]
                )
                self.opt.step()
                self.scheduler.step()

            # accumulate metrics
            tot += loss.item()
            logs["ot"] += loss_ot.item()
            logs["nll"] += loss_nll.item()
            logs["curv"] += loss_curv.item()
            logs["floor"] += loss_floor.item()
            logs["id"] += loss_id.item()

            # === NEW: Live visualizer hook (unchanged) ===
            if self.visualizer and (phase == "train"):
                if ((step + 1) % self.cfg["logging"]["plot_every_steps"] == 0):
                    self.visualizer.update_async(self.psi, self.emb)
                self.visualizer.check_and_update_plot()

            # === Logging ===
            if (step + 1) % self.cfg["logging"]["print_every"] == 0:
                avg = {k: v / (step + 1) for k, v in logs.items()}
                logging.info(
                    f"[{phase}] epoch {epoch} step {step+1}/{len(loader)} "
                    + " ".join(f"{k}:{avg[k]:.4f}" for k in avg)
                )

        N = max(1, len(loader))
        return {k: v / N for k, v in logs.items()} | {"total": tot / N}

# ------------------ Config ------------------

CONFIG = {
    "data": {
        "dimension": "age",
        "min_ratings": 10,
        "val_split": 0.1,
        "subsample_raw_for_nll": 256,  # None or int
        "base_dir": "/Users/adamsobieszek/PycharmProjects/PsychGAN/"
    },
    "model": {
        "grid_M": 200,
        "eps_floor": 1/200/10,
        "student_t_nu": 6.0,
        # 21 quantiles from 0.025..0.975 (mid-tail emphasis)
        "quantiles": [*np.arange(0.01, 0.991, 0.01)],  #[0.025,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95,0.975],
        "sigma_min": 1e-3
    },
    "loss_weights": {
        "ot":   1.0,
        "nll":  1.0,     # start small; can ramp to 1.0
        "curv": 1e-3,
        "floor":1e-3,
        "id":   10.0
    },
    "training": {
        "epochs": 2000,
        "batch_size": 64,                # number of items (faces) per step
        "learning_rate": 8e-4,
        "weight_decay": 1e-3,
        "grad_clip_norm": 1.0,
        "item_weighting": "n",           # {"n","sqrt_n","uniform"}
        "steps_per_epoch_estimate": 200  # for cosine scheduler period
    },
    "logging": {
        "level": "INFO",
        "print_every": 10
    }
}

logging.basicConfig(level=CONFIG["logging"]["level"])
CONFIG["logging"].update({
    "plot_every_steps": 30,   # how often to kick async refresh (steps)
    "print_every": 10         # you already have this
})
# --- add to CONFIG ---
CONFIG["reweighting"] = {
    "enabled": True,          # turn density reweighting on/off
    "stat": "mean",           # "mean" or "median" for item location m_i
    "bins": 50,               # histogram bins for empirical density
    "target": "uniform",      # "uniform" (flat over [0,1]) -- simplest and robust
    "clip_min": 0.2,         # clip weights to [clip_min, clip_max]
    "clip_max": 5.0,
    "gamma": 1.,            # temper weights: w <- w^gamma
    "apply_to_nll": True,     # also weight the NLL term?
    "nll_gamma": 0.50,        # temper again inside NLL (lower variance)
    "n_weight_power": 0.0     # optional combine with n_i weighting (0 = ignore n_i)
}

# ------------------ Train / Validate split & run ------------------

if __name__ == "__main__":
    # Load data (bootstrap inside)
    photo_to_coords, dim_to_photo_to_ratings = load_interp_data(
        base_dir=CONFIG["data"]["base_dir"], scale=101
    )
    dim_to_photo_to_ratings = {k:{kk:vv for kk,vv in v.items() if torch.mean(vv) > .10} for k,v in dim_to_photo_to_ratings.items()}
    # Build dataset
    ds = ItemRatingsDataset(dim_to_photo_to_ratings,
                            target_dim=CONFIG["data"]["dimension"],
                            min_ratings=CONFIG["data"]["min_ratings"])
    N = len(ds)
    idx = np.arange(N)
    np.random.shuffle(idx)
    n_val = max(1, int(CONFIG["data"]["val_split"] * N))
    val_idx = idx[:n_val]
    train_idx = idx[n_val:]

    ds_train = torch.utils.data.Subset(ds, train_idx.tolist())
    ds_val   = torch.utils.data.Subset(ds, val_idx.tolist())

    def _collate(batch):
        return collate_items_quantiles(
            batch,
            quantiles=torch.tensor(CONFIG["model"]["quantiles"], dtype=DTYPE),
            subsample_raw=CONFIG["data"]["subsample_raw_for_nll"]
        )

    train_loader = DataLoader(ds_train, batch_size=CONFIG["training"]["batch_size"],
                              shuffle=True, num_workers=0, collate_fn=_collate)
    val_loader   = DataLoader(ds_val, batch_size=CONFIG["training"]["batch_size"],
                              shuffle=False, num_workers=0, collate_fn=_collate)

    # Models
    psi = MonoPsiGrid(M=CONFIG["model"]["grid_M"], eps_floor=CONFIG["model"]["eps_floor"])
    emb = ItemEmbeddings(num_items=N, sigma_min=CONFIG["model"]["sigma_min"])

    # Initialize Θ, σ from identity ψ (optional)
    # (Quick pass over train set to set rough scales)
    with torch.no_grad():
        all_theta = torch.zeros(N,1)
        all_sigma = torch.zeros(N,1)
        for b in train_loader:
            ids = b["item_ids"]
            # mean & std of ψ(y)=y initially (approx)
            means = []
            sds   = []
            for yv in b["y_raw_list"]:
                if yv.numel()==0:
                    means.append(torch.tensor(0.0))
                    sds.append(torch.tensor(1.0))
                else:
                    m = yv.mean()
                    s = yv.std(unbiased=False)
                    means.append(m)
                    sds.append(torch.clamp(s, 1e-3))
            all_theta[ids] = torch.stack(means).unsqueeze(1)
            all_sigma[ids] = torch.stack(sds).unsqueeze(1)
        emb.theta.weight.copy_((all_theta - all_theta.mean())/ (all_theta.std()+1e-6))
        emb.rho.weight.copy_(torch.log(torch.exp(all_sigma - CONFIG["model"]["sigma_min"]) - 1.).clamp(min=-5., max=5.))

    # Visualizer over the FULL dataset indices (embeddings are indexed by full ds)
    live_vis = LiveInverseMappingVisualizer(dataset=ds, example_item_ids=None)
    # --- NEW: compute per-item density weights over item means ---
    m_all = compute_item_locations_unit(ds, stat=CONFIG["reweighting"]["stat"])
    density_w_all = make_density_weights_from_m(
        m_all,
        bins=CONFIG["reweighting"]["bins"],
        target=CONFIG["reweighting"]["target"],
        clip_min=CONFIG["reweighting"]["clip_min"],
        clip_max=CONFIG["reweighting"]["clip_max"],
        gamma=CONFIG["reweighting"]["gamma"]
    ).to(DEVICE)

    trainer = InverseScaleTrainer(psi_model=psi, emb=emb, config=CONFIG, visualizer=live_vis)

    best_val = float("inf")
    for epoch in range(1, CONFIG["training"]["epochs"]+1):
        tr = trainer.train_epoch(train_loader, epoch, phase="train")
        
        vl = trainer.train_epoch(val_loader,   epoch, phase="val")
        # Force a plot refresh at epoch end, too:
        if live_vis:
            live_vis.update_async(trainer.psi, trainer.emb)
            live_vis.check_and_update_plot()

        val_score = vl["ot"] + CONFIG["loss_weights"]["nll"]*vl["nll"]
        logging.info(f"Epoch {epoch:03d} | "
                     f"train: total={sum(tr.values()):.4f}, "
                     + " ".join([f"{k}:{v:.4f}" for k,v in tr.items()])
                     + f" || val: " 
                     + " ".join([f"{k}:{v:.4f}" for k,v in vl.items()])
                     )
        if val_score < best_val:
            best_val = val_score
            os.makedirs("checkpoints", exist_ok=True)
            torch.save({
                "psi": trainer.psi.state_dict(),
                "emb": trainer.emb.state_dict(),
                "config": CONFIG
            }, "checkpoints/inverse_mapping_best.pt")
            logging.info(f"Saved best model (val score={best_val:.4f})")

    logging.info("Done.")
# Out:
# /var/folders/nc/zbqbbkkx08z7v1g3mlf8bdn00000gn/T/ipykernel_52639/3057931241.py:57: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
# FigureWidget({
#     'data': [{'line': {'color': 'gray', 'dash': 'dash', 'width': 2},
#               'mode': 'lines',
#               'name': 'baseline',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '904d9b74-85a5-41bf-8f72-5833476de447',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'red', 'width': 3},
#               'mode': 'lines',
#               'name': 'psi',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '1c466c87-8c9b-4ba8-b1b2-56a7909f11ea',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'marker': {'color': '#729ECE', 'opacity': 0.45},
#               'name': 'hist1',
#               'showlegend': False,
#               'type': 'bar',
#               'uid': '785d8c76-3487-47dd-acdc-574cf925d3f3',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': '#729ECE', 'width': 2},
#               'mode': 'lines',
#               'name': 'pdf1',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '56fb07b7-30db-4dff-b898-ff94309b7f69',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'marker': {'color': '#8EBA42', 'opacity': 0.45},
#               'name': 'hist2',
#               'showlegend': False,
#               'type': 'bar',
#               'uid': '29415d98-feab-4393-bfcb-d575864ec8c7',
#               'xaxis': 'x4',
#               'yaxis': 'y4'},
#              {'line': {'color': '#8EBA42', 'width': 2},
#               'mode': 'lines',
#               'name': 'pdf2',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '63b59790-de5f-4bff-8911-8fa6d7c21e9e',
#               'xaxis': 'x4',
#               'yaxis': 'y4'},
#              {'marker': {'color': '#FF9DA7', 'opacity': 0.45},
#               'name': 'hist3',
#               'showlegend': False,
#               'type': 'bar',
#               'uid': 'b8332573-715f-48b3-972d-e697404f2026',
#               'xaxis': 'x5',
#               'yaxis': 'y5'},
#              {'line': {'color': '#FF9DA7', 'width': 2},
#               'mode': 'lines',
#               'name': 'pdf3',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'bae42ad8-dcc5-46a7-986a-b18856c93c19',
#               'xaxis': 'x5',
#               'yaxis': 'y5'},
#              {'marker': {'color': '#444', 'opacity': 0.6, 'size': 6},
#               'mode': 'markers',
#               'name': 'Beta αβ',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'a88de88b-872c-42d5-bcd6-aa5cf275831a',
#               'xaxis': 'x3',
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Mapping ψ(y) (red) & Best Linear Baseline (gray)',
#                                 'x': 0.23833333333333337,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Example #430',
#                                 'x': 0.6516666666666668,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Example #778',
#                                 'x': 0.9133333333333333,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Beta(α, β) over items',
#                                 'x': 0.6516666666666668,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.6111111111111112,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Example #871',
#                                 'x': 0.6516666666666668,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.22222222222222224,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 760,
#                'margin': {'b': 40, 'l': 50, 'r': 20, 't': 60},
#                'template': '...',
#                'title': {'text': 'Live Inverse Mapping Training'},
#                'width': 1800,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 0.47666666666666674], 'title': {'text': 'y (slider in [0,1])'}},
#                'xaxis2': {'anchor': 'y2',
#                           'domain': [0.5433333333333334, 0.7600000000000001],
#                           'title': {'text': 'z = ψ(y)'}},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.8266666666666667, 1.0], 'title': {'text': 'α (Beta)'}},
#                'xaxis4': {'anchor': 'y4',
#                           'domain': [0.5433333333333334, 0.7600000000000001],
#                           'title': {'text': 'z = ψ(y)'}},
#                'xaxis5': {'anchor': 'y5',
#                           'domain': [0.5433333333333334, 0.7600000000000001],
#                           'title': {'text': 'z = ψ(y)'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'ψ(y)'}},
#                'yaxis2': {'anchor': 'x2', 'domain': [0.7777777777777778, 1.0], 'title': {'text': 'density'}},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 1.0], 'title': {'text': 'β (Beta)'}},
#                'yaxis4': {'anchor': 'x4',
#                           'domain': [0.3888888888888889, 0.6111111111111112],
#                           'title': {'text': 'density'}},
#                'yaxis5': {'anchor': 'x5', 'domain': [0.0, 0.22222222222222224], 'title': {'text': 'density'}}}
# })
# INFO:root:[train] epoch 1 step 10/19 ot:0.5622 nll:5.7189 curv:0.0000 floor:0.1645 id:0.0000
# INFO:root:Epoch 001 | train: total=12.4560, ot:0.5448 nll:5.6008 curv:0.0000 floor:0.1645 id:0.0000 total:6.1458 || val: ot:nan nll:nan curv:0.0000 floor:0.1645 id:0.0000 total:nan
# INFO:root:[train] epoch 2 step 10/19 ot:0.5176 nll:5.4598 curv:0.0000 floor:0.1645 id:0.0000
# INFO:root:Epoch 002 | train: total=12.3826, ot:0.5435 nll:5.5655 curv:0.0000 floor:0.1645 id:0.0000 total:6.1091 || val: ot:nan nll:nan curv:0.0000 floor:0.1645 id:0.0000 total:nan
# INFO:root:[train] epoch 3 step 10/19 ot:0.5637 nll:5.8193 curv:0.0000 floor:0.1645 id:0.0000
# INFO:root:Epoch 003 | train: total=12.4129, ot:0.5439 nll:5.5803 curv:0.0000 floor:0.1644 id:0.0000 total:6.1243 || val: ot:nan nll:nan curv:0.0000 floor:0.1644 id:0.0000 total:nan
# INFO:root:[train] epoch 4 step 10/19 ot:0.5238 nll:5.4682 curv:0.0000 floor:0.1644 id:0.0000
# INFO:root:Epoch 004 | train: total=12.3930, ot:0.5461 nll:5.5682 curv:0.0000 floor:0.1644 id:0.0000 total:6.1144 || val: ot:nan nll:nan curv:0.0000 floor:0.1644 id:0.0000 total:nan
# INFO:root:[train] epoch 5 step 10/19 ot:0.5477 nll:5.4629 curv:0.0000 floor:0.1643 id:0.0000
# INFO:root:Epoch 005 | train: total=12.3372, ot:0.5387 nll:5.5477 curv:0.0000 floor:0.1643 id:0.0000 total:6.0865 || val: ot:nan nll:nan curv:0.0000 floor:0.1643 id:0.0000 total:nan
# INFO:root:[train] epoch 6 step 10/19 ot:0.5101 nll:5.3808 curv:0.0000 floor:0.1643 id:0.0000
# INFO:root:Epoch 006 | train: total=12.2600, ot:0.5336 nll:5.5142 curv:0.0000 floor:0.1642 id:0.0000 total:6.0480 || val: ot:nan nll:nan curv:0.0000 floor:0.1642 id:0.0000 total:nan
# INFO:root:[train] epoch 7 step 10/19 ot:0.5156 nll:5.4464 curv:0.0000 floor:0.1642 id:0.0000
# INFO:root:Epoch 007 | train: total=12.3699, ot:0.5426 nll:5.5602 curv:0.0000 floor:0.1642 id:0.0000 total:6.1030 || val: ot:nan nll:nan curv:0.0000 floor:0.1641 id:0.0000 total:nan
# INFO:root:[train] epoch 8 step 10/19 ot:0.5330 nll:5.5548 curv:0.0000 floor:0.1641 id:0.0000
# INFO:root:Epoch 008 | train: total=12.3569, ot:0.5398 nll:5.5566 curv:0.0000 floor:0.1641 id:0.0000 total:6.0965 || val: ot:nan nll:nan curv:0.0000 floor:0.1640 id:0.0000 total:nan
# INFO:root:[train] epoch 9 step 10/19 ot:0.5296 nll:5.4181 curv:0.0000 floor:0.1640 id:0.0000
# INFO:root:Epoch 009 | train: total=12.3046, ot:0.5356 nll:5.5346 curv:0.0000 floor:0.1640 id:0.0000 total:6.0704 || val: ot:nan nll:nan curv:0.0000 floor:0.1639 id:0.0000 total:nan
# INFO:root:[train] epoch 10 step 10/19 ot:0.5299 nll:5.5218 curv:0.0000 floor:0.1639 id:0.0000
# INFO:root:Epoch 010 | train: total=12.2313, ot:0.5356 nll:5.4981 curv:0.0000 floor:0.1638 id:0.0000 total:6.0338 || val: ot:nan nll:nan curv:0.0000 floor:0.1638 id:0.0000 total:nan
# INFO:root:[train] epoch 11 step 10/19 ot:0.5496 nll:5.6398 curv:0.0000 floor:0.1637 id:0.0000
# INFO:root:Epoch 011 | train: total=12.2125, ot:0.5329 nll:5.4914 curv:0.0000 floor:0.1637 id:0.0000 total:6.0245 || val: ot:nan nll:nan curv:0.0000 floor:0.1636 id:0.0000 total:nan
# INFO:root:[train] epoch 12 step 10/19 ot:0.5288 nll:5.4153 curv:0.0000 floor:0.1636 id:0.0000
# INFO:root:Epoch 012 | train: total=12.4572, ot:0.5475 nll:5.5992 curv:0.0000 floor:0.1636 id:0.0000 total:6.1469 || val: ot:nan nll:nan curv:0.0000 floor:0.1635 id:0.0000 total:nan
# INFO:root:[train] epoch 13 step 10/19 ot:0.5616 nll:5.7493 curv:0.0000 floor:0.1635 id:0.0000
# INFO:root:Epoch 013 | train: total=12.1422, ot:0.5289 nll:5.4604 curv:0.0000 floor:0.1634 id:0.0000 total:5.9895 || val: ot:nan nll:nan curv:0.0000 floor:0.1634 id:0.0000 total:nan
# INFO:root:[train] epoch 14 step 10/19 ot:0.5395 nll:5.4679 curv:0.0000 floor:0.1633 id:0.0000
# INFO:root:Epoch 014 | train: total=12.2042, ot:0.5340 nll:5.4863 curv:0.0000 floor:0.1633 id:0.0000 total:6.0205 || val: ot:nan nll:nan curv:0.0000 floor:0.1632 id:0.0000 total:nan
# INFO:root:[train] epoch 15 step 10/19 ot:0.5190 nll:5.3876 curv:0.0000 floor:0.1632 id:0.0000
# INFO:root:Epoch 015 | train: total=12.1929, ot:0.5319 nll:5.4829 curv:0.0000 floor:0.1631 id:0.0000 total:6.0150 || val: ot:nan nll:nan curv:0.0000 floor:0.1630 id:0.0000 total:nan
# INFO:root:[train] epoch 16 step 10/19 ot:0.5497 nll:5.5577 curv:0.0000 floor:0.1630 id:0.0000
# INFO:root:Epoch 016 | train: total=12.2913, ot:0.5370 nll:5.5271 curv:0.0000 floor:0.1630 id:0.0000 total:6.0642 || val: ot:nan nll:nan curv:0.0000 floor:0.1629 id:0.0000 total:nan
# INFO:root:[train] epoch 17 step 10/19 ot:0.5119 nll:5.3121 curv:0.0000 floor:0.1629 id:0.0000
# INFO:root:Epoch 017 | train: total=12.1813, ot:0.5254 nll:5.4838 curv:0.0000 floor:0.1628 id:0.0000 total:6.0093 || val: ot:nan nll:nan curv:0.0000 floor:0.1627 id:0.0000 total:nan
# INFO:root:[train] epoch 18 step 10/19 ot:0.5206 nll:5.3731 curv:0.0000 floor:0.1627 id:0.0000
# INFO:root:Epoch 018 | train: total=12.2759, ot:0.5312 nll:5.5254 curv:0.0000 floor:0.1627 id:0.0000 total:6.0567 || val: ot:nan nll:nan curv:0.0000 floor:0.1626 id:0.0000 total:nan
# INFO:root:[train] epoch 19 step 10/19 ot:0.5306 nll:5.4682 curv:0.0000 floor:0.1625 id:0.0000
# INFO:root:Epoch 019 | train: total=12.4324, ot:0.5440 nll:5.5908 curv:0.0000 floor:0.1625 id:0.0000 total:6.1351 || val: ot:nan nll:nan curv:0.0000 floor:0.1624 id:0.0000 total:nan
# INFO:root:[train] epoch 20 step 10/19 ot:0.5558 nll:5.6413 curv:0.0000 floor:0.1623 id:0.0000
# INFO:root:Epoch 020 | train: total=12.3702, ot:0.5384 nll:5.5654 curv:0.0000 floor:0.1623 id:0.0000 total:6.1040 || val: ot:nan nll:nan curv:0.0000 floor:0.1622 id:0.0000 total:nan
# INFO:root:[train] epoch 21 step 10/19 ot:0.5342 nll:5.4976 curv:0.0000 floor:0.1622 id:0.0000
# INFO:root:Epoch 021 | train: total=12.2153, ot:0.5293 nll:5.4972 curv:0.0000 floor:0.1621 id:0.0000 total:6.0266 || val: ot:nan nll:nan curv:0.0000 floor:0.1620 id:0.0000 total:nan
# INFO:root:[train] epoch 22 step 10/19 ot:0.5086 nll:5.2865 curv:0.0000 floor:0.1620 id:0.0000
# INFO:root:Epoch 022 | train: total=12.3549, ot:0.5399 nll:5.5565 curv:0.0000 floor:0.1619 id:0.0000 total:6.0966 || val: ot:nan nll:nan curv:0.0000 floor:0.1618 id:0.0000 total:nan
# INFO:root:[train] epoch 23 step 10/19 ot:0.5617 nll:5.8326 curv:0.0000 floor:0.1618 id:0.0000
# INFO:root:Epoch 023 | train: total=12.2192, ot:0.5326 nll:5.4961 curv:0.0000 floor:0.1617 id:0.0000 total:6.0288 || val: ot:nan nll:nan curv:0.0000 floor:0.1616 id:0.0000 total:nan
# INFO:root:[train] epoch 24 step 10/19 ot:0.5103 nll:5.2982 curv:0.0000 floor:0.1616 id:0.0000
# INFO:root:Epoch 024 | train: total=12.2311, ot:0.5296 nll:5.5051 curv:0.0000 floor:0.1615 id:0.0000 total:6.0349 || val: ot:nan nll:nan curv:0.0000 floor:0.1614 id:0.0000 total:nan
# INFO:root:[train] epoch 25 step 10/19 ot:0.5155 nll:5.2527 curv:0.0000 floor:0.1613 id:0.0000
# INFO:root:Epoch 025 | train: total=12.1100, ot:0.5244 nll:5.4499 curv:0.0000 floor:0.1613 id:0.0000 total:5.9744 || val: ot:nan nll:nan curv:0.0000 floor:0.1612 id:0.0000 total:nan
# INFO:root:[train] epoch 26 step 10/19 ot:0.4975 nll:5.2279 curv:0.0000 floor:0.1611 id:0.0000
# INFO:root:Epoch 026 | train: total=12.2145, ot:0.5304 nll:5.4962 curv:0.0000 floor:0.1611 id:0.0000 total:6.0268 || val: ot:nan nll:nan curv:0.0000 floor:0.1609 id:0.0000 total:nan
# INFO:root:[train] epoch 27 step 10/19 ot:0.5088 nll:5.3361 curv:0.0000 floor:0.1609 id:0.0000
# INFO:root:Epoch 027 | train: total=12.1900, ot:0.5280 nll:5.4865 curv:0.0000 floor:0.1608 id:0.0000 total:6.0147 || val: ot:nan nll:nan curv:0.0000 floor:0.1607 id:0.0000 total:nan
# INFO:root:[train] epoch 28 step 10/19 ot:0.5328 nll:5.5133 curv:0.0000 floor:0.1607 id:0.0000
# INFO:root:Epoch 028 | train: total=11.9738, ot:0.5169 nll:5.3896 curv:0.0000 floor:0.1606 id:0.0000 total:5.9067 || val: ot:nan nll:nan curv:0.0000 floor:0.1605 id:0.0000 total:nan
# INFO:root:[train] epoch 29 step 10/19 ot:0.5033 nll:5.2605 curv:0.0000 floor:0.1604 id:0.0000
# INFO:root:Epoch 029 | train: total=12.0993, ot:0.5221 nll:5.4473 curv:0.0000 floor:0.1604 id:0.0000 total:5.9695 || val: ot:nan nll:nan curv:0.0000 floor:0.1602 id:0.0000 total:nan
# INFO:root:[train] epoch 30 step 10/19 ot:0.5793 nll:5.8279 curv:0.0000 floor:0.1602 id:0.0000
# INFO:root:Epoch 030 | train: total=12.0475, ot:0.5168 nll:5.4268 curv:0.0000 floor:0.1601 id:0.0000 total:5.9438 || val: ot:nan nll:nan curv:0.0000 floor:0.1600 id:0.0000 total:nan
# INFO:root:[train] epoch 31 step 10/19 ot:0.5706 nll:5.7568 curv:0.0000 floor:0.1600 id:0.0000
# INFO:root:Epoch 031 | train: total=12.0329, ot:0.5208 nll:5.4156 curv:0.0000 floor:0.1599 id:0.0000 total:5.9366 || val: ot:nan nll:nan curv:0.0000 floor:0.1598 id:0.0000 total:nan
# INFO:root:[train] epoch 32 step 10/19 ot:0.5101 nll:5.2376 curv:0.0000 floor:0.1597 id:0.0000
# INFO:root:Epoch 032 | train: total=12.3663, ot:0.5347 nll:5.5685 curv:0.0000 floor:0.1597 id:0.0000 total:6.1034 || val: ot:nan nll:nan curv:0.0000 floor:0.1595 id:0.0000 total:nan
# INFO:root:[train] epoch 33 step 10/19 ot:0.5358 nll:5.5797 curv:0.0000 floor:0.1595 id:0.0000
# INFO:root:Epoch 033 | train: total=11.8508, ot:0.5116 nll:5.3340 curv:0.0000 floor:0.1594 id:0.0000 total:5.8458 || val: ot:nan nll:nan curv:0.0000 floor:0.1593 id:0.0000 total:nan
# INFO:root:[train] epoch 34 step 10/19 ot:0.4761 nll:5.0325 curv:0.0000 floor:0.1592 id:0.0000
# INFO:root:Epoch 034 | train: total=12.1125, ot:0.5212 nll:5.4554 curv:0.0000 floor:0.1591 id:0.0000 total:5.9768 || val: ot:nan nll:nan curv:0.0000 floor:0.1590 id:0.0000 total:nan
# INFO:root:[train] epoch 35 step 10/19 ot:0.5060 nll:5.4099 curv:0.0000 floor:0.1589 id:0.0000
# INFO:root:Epoch 035 | train: total=12.0347, ot:0.5205 nll:5.4173 curv:0.0000 floor:0.1589 id:0.0000 total:5.9380 || val: ot:nan nll:nan curv:0.0000 floor:0.1587 id:0.0000 total:nan
# INFO:root:[train] epoch 36 step 10/19 ot:0.5075 nll:5.3156 curv:0.0000 floor:0.1587 id:0.0000
# INFO:root:Epoch 036 | train: total=12.0983, ot:0.5222 nll:5.4476 curv:0.0000 floor:0.1586 id:0.0000 total:5.9700 || val: ot:nan nll:nan curv:0.0000 floor:0.1585 id:0.0000 total:nan
# INFO:root:[train] epoch 37 step 10/19 ot:0.5281 nll:5.4664 curv:0.0000 floor:0.1584 id:0.0000
# INFO:root:Epoch 037 | train: total=11.9065, ot:0.5100 nll:5.3640 curv:0.0000 floor:0.1583 id:0.0000 total:5.8742 || val: ot:nan nll:nan curv:0.0000 floor:0.1582 id:0.0000 total:nan
# INFO:root:[train] epoch 38 step 10/19 ot:0.5335 nll:5.6081 curv:0.0000 floor:0.1581 id:0.0000
# INFO:root:Epoch 038 | train: total=11.8676, ot:0.5088 nll:5.3458 curv:0.0000 floor:0.1581 id:0.0000 total:5.8548 || val: ot:nan nll:nan curv:0.0000 floor:0.1579 id:0.0000 total:nan
# INFO:root:[train] epoch 39 step 10/19 ot:0.5034 nll:5.3639 curv:0.0000 floor:0.1579 id:0.0000
# INFO:root:Epoch 039 | train: total=12.1092, ot:0.5214 nll:5.4542 curv:0.0000 floor:0.1578 id:0.0000 total:5.9758 || val: ot:nan nll:nan curv:0.0000 floor:0.1576 id:0.0000 total:nan
# INFO:root:[train] epoch 40 step 10/19 ot:0.5300 nll:5.5939 curv:0.0000 floor:0.1576 id:0.0000
# INFO:root:Epoch 040 | train: total=12.0309, ot:0.5187 nll:5.4179 curv:0.0000 floor:0.1575 id:0.0000 total:5.9368 || val: ot:nan nll:nan curv:0.0000 floor:0.1573 id:0.0000 total:nan
# INFO:root:[train] epoch 41 step 10/19 ot:0.5333 nll:5.5858 curv:0.0000 floor:0.1573 id:0.0000
# INFO:root:Epoch 041 | train: total=11.8979, ot:0.5089 nll:5.3614 curv:0.0000 floor:0.1572 id:0.0000 total:5.8704 || val: ot:nan nll:nan curv:0.0000 floor:0.1570 id:0.0000 total:nan
# INFO:root:[train] epoch 42 step 10/19 ot:0.4996 nll:5.4170 curv:0.0000 floor:0.1570 id:0.0000
# INFO:root:Epoch 042 | train: total=12.1005, ot:0.5251 nll:5.4466 curv:0.0000 floor:0.1569 id:0.0000 total:5.9719 || val: ot:nan nll:nan curv:0.0000 floor:0.1568 id:0.0000 total:nan
# INFO:root:[train] epoch 43 step 10/19 ot:0.5177 nll:5.2950 curv:0.0000 floor:0.1567 id:0.0000
# INFO:root:Epoch 043 | train: total=11.9391, ot:0.5104 nll:5.3807 curv:0.0000 floor:0.1566 id:0.0000 total:5.8913 || val: ot:nan nll:nan curv:0.0000 floor:0.1565 id:0.0000 total:nan
# INFO:root:[train] epoch 44 step 10/19 ot:0.5130 nll:5.3749 curv:0.0000 floor:0.1564 id:0.0000
# INFO:root:Epoch 044 | train: total=12.0012, ot:0.5087 nll:5.4137 curv:0.0000 floor:0.1563 id:0.0000 total:5.9225 || val: ot:nan nll:nan curv:0.0000 floor:0.1561 id:0.0000 total:nan
# INFO:root:[train] epoch 45 step 10/19 ot:0.5184 nll:5.4166 curv:0.0000 floor:0.1561 id:0.0000
# INFO:root:Epoch 045 | train: total=11.8179, ot:0.5052 nll:5.3257 curv:0.0000 floor:0.1560 id:0.0000 total:5.8310 || val: ot:nan nll:nan curv:0.0000 floor:0.1558 id:0.0000 total:nan
# INFO:root:[train] epoch 46 step 10/19 ot:0.5113 nll:5.3170 curv:0.0000 floor:0.1558 id:0.0000
# INFO:root:Epoch 046 | train: total=11.8069, ot:0.5072 nll:5.3183 curv:0.0000 floor:0.1557 id:0.0000 total:5.8257 || val: ot:nan nll:nan curv:0.0000 floor:0.1555 id:0.0000 total:nan
# INFO:root:[train] epoch 47 step 10/19 ot:0.5200 nll:5.3525 curv:0.0000 floor:0.1554 id:0.0000
# INFO:root:Epoch 047 | train: total=12.0582, ot:0.5129 nll:5.4384 curv:0.0000 floor:0.1554 id:0.0000 total:5.9515 || val: ot:nan nll:nan curv:0.0000 floor:0.1552 id:0.0000 total:nan
# INFO:root:[train] epoch 48 step 10/19 ot:0.4995 nll:5.2336 curv:0.0000 floor:0.1551 id:0.0000
# INFO:root:Epoch 048 | train: total=11.9591, ot:0.5136 nll:5.3884 curv:0.0000 floor:0.1550 id:0.0000 total:5.9021 || val: ot:nan nll:nan curv:0.0000 floor:0.1549 id:0.0000 total:nan
# INFO:root:[train] epoch 49 step 10/19 ot:0.5200 nll:5.4985 curv:0.0000 floor:0.1548 id:0.0000
# INFO:root:Epoch 049 | train: total=11.8437, ot:0.5082 nll:5.3362 curv:0.0000 floor:0.1547 id:0.0000 total:5.8446 || val: ot:nan nll:nan curv:0.0000 floor:0.1546 id:0.0000 total:nan
# INFO:root:[train] epoch 50 step 10/19 ot:0.5147 nll:5.4359 curv:0.0000 floor:0.1545 id:0.0000
# INFO:root:Epoch 050 | train: total=12.1142, ot:0.5182 nll:5.4616 curv:0.0000 floor:0.1544 id:0.0000 total:5.9800 || val: ot:nan nll:nan curv:0.0000 floor:0.1542 id:0.0000 total:nan
# INFO:root:[train] epoch 51 step 10/19 ot:0.5440 nll:5.7170 curv:0.0000 floor:0.1541 id:0.0000
# INFO:root:Epoch 051 | train: total=11.9574, ot:0.5128 nll:5.3888 curv:0.0000 floor:0.1541 id:0.0000 total:5.9018 || val: ot:nan nll:nan curv:0.0000 floor:0.1539 id:0.0000 total:nan
# INFO:root:[train] epoch 52 step 10/19 ot:0.5231 nll:5.4846 curv:0.0000 floor:0.1538 id:0.0000
# INFO:root:Epoch 052 | train: total=11.8896, ot:0.5054 nll:5.3624 curv:0.0000 floor:0.1537 id:0.0000 total:5.8680 || val: ot:nan nll:nan curv:0.0000 floor:0.1535 id:0.0000 total:nan
# INFO:root:[train] epoch 53 step 10/19 ot:0.5012 nll:5.5402 curv:0.0000 floor:0.1534 id:0.0000
# INFO:root:Epoch 053 | train: total=11.8189, ot:0.5061 nll:5.3266 curv:0.0000 floor:0.1533 id:0.0000 total:5.8328 || val: ot:nan nll:nan curv:0.0000 floor:0.1531 id:0.0000 total:nan
# INFO:root:[train] epoch 54 step 10/19 ot:0.5012 nll:5.2055 curv:0.0000 floor:0.1531 id:0.0000
# INFO:root:Epoch 054 | train: total=11.8443, ot:0.5001 nll:5.3455 curv:0.0000 floor:0.1530 id:0.0000 total:5.8457 || val: ot:nan nll:nan curv:0.0000 floor:0.1528 id:0.0000 total:nan
# INFO:root:[train] epoch 55 step 10/19 ot:0.4957 nll:5.2875 curv:0.0000 floor:0.1527 id:0.0000
# INFO:root:Epoch 055 | train: total=11.8629, ot:0.4994 nll:5.3556 curv:0.0000 floor:0.1526 id:0.0000 total:5.8552 || val: ot:nan nll:nan curv:0.0000 floor:0.1525 id:0.0000 total:nan
# INFO:root:[train] epoch 56 step 10/19 ot:0.5327 nll:5.6423 curv:0.0000 floor:0.1524 id:0.0000
# INFO:root:Epoch 056 | train: total=11.7359, ot:0.4993 nll:5.2925 curv:0.0000 floor:0.1523 id:0.0000 total:5.7919 || val: ot:nan nll:nan curv:0.0000 floor:0.1521 id:0.0000 total:nan
# INFO:root:[train] epoch 57 step 10/19 ot:0.5164 nll:5.4265 curv:0.0000 floor:0.1520 id:0.0000
# INFO:root:Epoch 057 | train: total=11.7558, ot:0.4969 nll:5.3050 curv:0.0000 floor:0.1519 id:0.0000 total:5.8020 || val: ot:nan nll:nan curv:0.0000 floor:0.1517 id:0.0000 total:nan
# INFO:root:[train] epoch 58 step 10/19 ot:0.4942 nll:5.3047 curv:0.0000 floor:0.1516 id:0.0000
# INFO:root:Epoch 058 | train: total=12.0011, ot:0.5082 nll:5.4165 curv:0.0000 floor:0.1516 id:0.0000 total:5.9248 || val: ot:nan nll:nan curv:0.0000 floor:0.1513 id:0.0000 total:nan
# INFO:root:[train] epoch 59 step 10/19 ot:0.4679 nll:4.9841 curv:0.0000 floor:0.1513 id:0.0000
# INFO:root:Epoch 059 | train: total=11.7823, ot:0.4990 nll:5.3165 curv:0.0000 floor:0.1512 id:0.0000 total:5.8156 || val: ot:nan nll:nan curv:0.0000 floor:0.1509 id:0.0000 total:nan
# INFO:root:[train] epoch 60 step 10/19 ot:0.5057 nll:5.3071 curv:0.0000 floor:0.1509 id:0.0000
# INFO:root:Epoch 060 | train: total=11.6928, ot:0.4911 nll:5.2798 curv:0.0000 floor:0.1508 id:0.0000 total:5.7711 || val: ot:nan nll:nan curv:0.0000 floor:0.1507 id:0.0000 total:nan
# INFO:root:[train] epoch 61 step 10/19 ot:0.5050 nll:5.4436 curv:0.0000 floor:0.1505 id:0.0000
# INFO:root:Epoch 061 | train: total=11.7109, ot:0.4926 nll:5.2875 curv:0.0000 floor:0.1504 id:0.0000 total:5.7803 || val: ot:nan nll:nan curv:0.0000 floor:0.1503 id:0.0000 total:nan
# INFO:root:[train] epoch 62 step 10/19 ot:0.4813 nll:5.2430 curv:0.0000 floor:0.1501 id:0.0000
# INFO:root:Epoch 062 | train: total=11.8012, ot:0.4929 nll:5.3326 curv:0.0000 floor:0.1501 id:0.0000 total:5.8257 || val: ot:nan nll:nan curv:0.0000 floor:0.1499 id:0.0000 total:nan
# INFO:root:[train] epoch 63 step 10/19 ot:0.4862 nll:5.1850 curv:0.0000 floor:0.1498 id:0.0000
# INFO:root:Epoch 063 | train: total=11.6087, ot:0.4874 nll:5.2420 curv:0.0000 floor:0.1497 id:0.0000 total:5.7296 || val: ot:nan nll:nan curv:0.0000 floor:0.1495 id:0.0000 total:nan
# INFO:root:[train] epoch 64 step 10/19 ot:0.4820 nll:5.2147 curv:0.0000 floor:0.1494 id:0.0000
# INFO:root:Epoch 064 | train: total=11.8485, ot:0.4953 nll:5.3542 curv:0.0000 floor:0.1493 id:0.0000 total:5.8497 || val: ot:nan nll:nan curv:0.0000 floor:0.1491 id:0.0000 total:nan
# INFO:root:[train] epoch 65 step 10/19 ot:0.5116 nll:5.5346 curv:0.0000 floor:0.1491 id:0.0000
# INFO:root:Epoch 065 | train: total=11.8874, ot:0.4988 nll:5.3704 curv:0.0000 floor:0.1490 id:0.0000 total:5.8693 || val: ot:nan nll:nan curv:0.0000 floor:0.1487 id:0.0000 total:nan
# INFO:root:[train] epoch 66 step 10/19 ot:0.4709 nll:5.0887 curv:0.0000 floor:0.1487 id:0.0000
# INFO:root:Epoch 066 | train: total=11.6384, ot:0.4837 nll:5.2611 curv:0.0000 floor:0.1486 id:0.0000 total:5.7450 || val: ot:nan nll:nan curv:0.0000 floor:0.1484 id:0.0000 total:nan
# INFO:root:[train] epoch 67 step 10/19 ot:0.4951 nll:5.2529 curv:0.0000 floor:0.1483 id:0.0000
# INFO:root:Epoch 067 | train: total=11.6875, ot:0.4867 nll:5.2829 curv:0.0000 floor:0.1482 id:0.0000 total:5.7697 || val: ot:nan nll:nan curv:0.0000 floor:0.1480 id:0.0000 total:nan
# INFO:root:[train] epoch 68 step 10/19 ot:0.5102 nll:5.4440 curv:0.0000 floor:0.1479 id:0.0000
# INFO:root:Epoch 068 | train: total=11.7206, ot:0.4906 nll:5.2957 curv:0.0000 floor:0.1478 id:0.0000 total:5.7865 || val: ot:nan nll:nan curv:0.0000 floor:0.1476 id:0.0000 total:nan
# INFO:root:[train] epoch 69 step 10/19 ot:0.4781 nll:5.0847 curv:0.0000 floor:0.1475 id:0.0000
# INFO:root:Epoch 069 | train: total=11.7034, ot:0.4866 nll:5.2913 curv:0.0000 floor:0.1475 id:0.0000 total:5.7781 || val: ot:nan nll:nan curv:0.0000 floor:0.1472 id:0.0000 total:nan
# INFO:root:[train] epoch 70 step 10/19 ot:0.4413 nll:4.8982 curv:0.0000 floor:0.1472 id:0.0000
# INFO:root:Epoch 070 | train: total=11.7206, ot:0.4890 nll:5.2977 curv:0.0000 floor:0.1471 id:0.0000 total:5.7868 || val: ot:nan nll:nan curv:0.0000 floor:0.1468 id:0.0000 total:nan
# INFO:root:[train] epoch 71 step 10/19 ot:0.4815 nll:5.3128 curv:0.0000 floor:0.1468 id:0.0000
# INFO:root:Epoch 071 | train: total=11.5721, ot:0.4830 nll:5.2296 curv:0.0000 floor:0.1467 id:0.0000 total:5.7128 || val: ot:nan nll:nan curv:0.0000 floor:0.1464 id:0.0000 total:nan
# INFO:root:[train] epoch 72 step 10/19 ot:0.4849 nll:5.3248 curv:0.0000 floor:0.1464 id:0.0000
# INFO:root:Epoch 072 | train: total=11.6694, ot:0.4851 nll:5.2764 curv:0.0000 floor:0.1463 id:0.0000 total:5.7616 || val: ot:nan nll:nan curv:0.0000 floor:0.1462 id:0.0000 total:nan
# INFO:root:[train] epoch 73 step 10/19 ot:0.4868 nll:5.3213 curv:0.0000 floor:0.1460 id:0.0000
# INFO:root:Epoch 073 | train: total=11.5419, ot:0.4758 nll:5.2222 curv:0.0000 floor:0.1459 id:0.0000 total:5.6981 || val: ot:nan nll:nan curv:0.0000 floor:0.1457 id:0.0000 total:nan
# INFO:root:[train] epoch 74 step 10/19 ot:0.4694 nll:5.2912 curv:0.0000 floor:0.1456 id:0.0000
# INFO:root:Epoch 074 | train: total=11.6405, ot:0.4821 nll:5.2653 curv:0.0000 floor:0.1455 id:0.0000 total:5.7476 || val: ot:nan nll:nan curv:0.0000 floor:0.1453 id:0.0000 total:nan
# INFO:root:[train] epoch 75 step 10/19 ot:0.4722 nll:5.2123 curv:0.0000 floor:0.1452 id:0.0000
# INFO:root:Epoch 075 | train: total=11.4014, ot:0.4729 nll:5.1551 curv:0.0000 floor:0.1451 id:0.0000 total:5.6282 || val: ot:nan nll:nan curv:0.0000 floor:0.1449 id:0.0000 total:nan
# INFO:root:[train] epoch 76 step 10/19 ot:0.4927 nll:5.3898 curv:0.0000 floor:0.1448 id:0.0000
# INFO:root:Epoch 076 | train: total=11.4694, ot:0.4744 nll:5.1879 curv:0.0000 floor:0.1447 id:0.0000 total:5.6624 || val: ot:nan nll:nan curv:0.0000 floor:0.1445 id:0.0000 total:nan
# INFO:root:[train] epoch 77 step 10/19 ot:0.4921 nll:5.3718 curv:0.0000 floor:0.1444 id:0.0000
# INFO:root:Epoch 077 | train: total=11.5677, ot:0.4776 nll:5.2340 curv:0.0000 floor:0.1443 id:0.0000 total:5.7118 || val: ot:nan nll:nan curv:0.0000 floor:0.1440 id:0.0000 total:nan
# INFO:root:[train] epoch 78 step 10/19 ot:0.4523 nll:4.9501 curv:0.0000 floor:0.1440 id:0.0000
# INFO:root:Epoch 078 | train: total=11.6025, ot:0.4771 nll:5.2522 curv:0.0000 floor:0.1439 id:0.0000 total:5.7294 || val: ot:nan nll:nan curv:0.0000 floor:0.1438 id:0.0000 total:nan
# INFO:root:[train] epoch 79 step 10/19 ot:0.4607 nll:5.0716 curv:0.0000 floor:0.1436 id:0.0000
# INFO:root:Epoch 079 | train: total=11.3010, ot:0.4681 nll:5.1105 curv:0.0000 floor:0.1435 id:0.0000 total:5.5788 || val: ot:nan nll:nan curv:0.0000 floor:0.1433 id:0.0000 total:nan
# INFO:root:[train] epoch 80 step 10/19 ot:0.4819 nll:5.1577 curv:0.0000 floor:0.1432 id:0.0000
# INFO:root:Epoch 080 | train: total=11.4988, ot:0.4699 nll:5.2078 curv:0.0000 floor:0.1431 id:0.0000 total:5.6779 || val: ot:nan nll:nan curv:0.0000 floor:0.1429 id:0.0000 total:nan
# INFO:root:[train] epoch 81 step 10/19 ot:0.4740 nll:5.2894 curv:0.0000 floor:0.1428 id:0.0000
# INFO:root:Epoch 081 | train: total=11.3222, ot:0.4656 nll:5.1241 curv:0.0000 floor:0.1427 id:0.0000 total:5.5899 || val: ot:nan nll:nan curv:0.0000 floor:0.1424 id:0.0000 total:nan
# INFO:root:[train] epoch 82 step 10/19 ot:0.4930 nll:5.3151 curv:0.0000 floor:0.1423 id:0.0000
# INFO:root:Epoch 082 | train: total=11.2741, ot:0.4604 nll:5.1055 curv:0.0000 floor:0.1422 id:0.0000 total:5.5660 || val: ot:nan nll:nan curv:0.0000 floor:0.1420 id:0.0000 total:nan
# INFO:root:[train] epoch 83 step 10/19 ot:0.4685 nll:5.2359 curv:0.0000 floor:0.1419 id:0.0000
# INFO:root:Epoch 083 | train: total=11.4348, ot:0.4653 nll:5.1811 curv:0.0000 floor:0.1418 id:0.0000 total:5.6466 || val: ot:nan nll:nan curv:0.0000 floor:0.1415 id:0.0000 total:nan
# INFO:root:[train] epoch 84 step 10/19 ot:0.4728 nll:5.1788 curv:0.0000 floor:0.1415 id:0.0000
# INFO:root:Epoch 084 | train: total=11.3321, ot:0.4629 nll:5.1324 curv:0.0000 floor:0.1413 id:0.0000 total:5.5955 || val: ot:nan nll:nan curv:0.0000 floor:0.1412 id:0.0000 total:nan
# INFO:root:[train] epoch 85 step 10/19 ot:0.4609 nll:5.1598 curv:0.0000 floor:0.1410 id:0.0000
# INFO:root:Epoch 085 | train: total=11.2988, ot:0.4598 nll:5.1190 curv:0.0000 floor:0.1410 id:0.0000 total:5.5790 || val: ot:nan nll:nan curv:0.0000 floor:0.1408 id:0.0000 total:nan
# INFO:root:[train] epoch 86 step 10/19 ot:0.4415 nll:4.9906 curv:0.0000 floor:0.1406 id:0.0000
# INFO:root:Epoch 086 | train: total=11.3018, ot:0.4588 nll:5.1217 curv:0.0000 floor:0.1405 id:0.0000 total:5.5807 || val: ot:nan nll:nan curv:0.0000 floor:0.1403 id:0.0000 total:nan
# INFO:root:[train] epoch 87 step 10/19 ot:0.4904 nll:5.3348 curv:0.0000 floor:0.1402 id:0.0000
# INFO:root:Epoch 087 | train: total=11.0700, ot:0.4470 nll:5.0179 curv:0.0000 floor:0.1401 id:0.0000 total:5.4650 || val: ot:nan nll:nan curv:0.0000 floor:0.1399 id:0.0000 total:nan
# INFO:root:[train] epoch 88 step 10/19 ot:0.4437 nll:5.0617 curv:0.0000 floor:0.1398 id:0.0000
# INFO:root:Epoch 088 | train: total=11.3301, ot:0.4588 nll:5.1364 curv:0.0000 floor:0.1397 id:0.0000 total:5.5953 || val: ot:nan nll:nan curv:0.0000 floor:0.1395 id:0.0000 total:nan
# INFO:root:[train] epoch 89 step 10/19 ot:0.4518 nll:4.9399 curv:0.0000 floor:0.1394 id:0.0000
# INFO:root:Epoch 089 | train: total=11.2083, ot:0.4525 nll:5.0820 curv:0.0000 floor:0.1393 id:0.0000 total:5.5345 || val: ot:nan nll:nan curv:0.0000 floor:0.1390 id:0.0000 total:nan
# INFO:root:[train] epoch 90 step 10/19 ot:0.4509 nll:5.0557 curv:0.0000 floor:0.1390 id:0.0000
# INFO:root:Epoch 090 | train: total=11.1838, ot:0.4510 nll:5.0714 curv:0.0000 floor:0.1389 id:0.0000 total:5.5225 || val: ot:nan nll:nan curv:0.0000 floor:0.1387 id:0.0000 total:nan
# INFO:root:[train] epoch 91 step 10/19 ot:0.4733 nll:5.3727 curv:0.0000 floor:0.1386 id:0.0000
# INFO:root:Epoch 091 | train: total=11.2069, ot:0.4529 nll:5.0813 curv:0.0000 floor:0.1385 id:0.0000 total:5.5343 || val: ot:nan nll:nan curv:0.0000 floor:0.1383 id:0.0000 total:nan
# INFO:root:[train] epoch 92 step 10/19 ot:0.4681 nll:5.2293 curv:0.0000 floor:0.1382 id:0.0000
# INFO:root:Epoch 092 | train: total=11.2061, ot:0.4508 nll:5.0832 curv:0.0000 floor:0.1380 id:0.0000 total:5.5341 || val: ot:nan nll:nan curv:0.0000 floor:0.1378 id:0.0000 total:nan
# INFO:root:[train] epoch 93 step 10/19 ot:0.4663 nll:5.2195 curv:0.0000 floor:0.1377 id:0.0000
# INFO:root:Epoch 093 | train: total=11.1885, ot:0.4497 nll:5.0757 curv:0.0000 floor:0.1376 id:0.0000 total:5.5255 || val: ot:nan nll:nan curv:0.0000 floor:0.1374 id:0.0000 total:nan
# INFO:root:[train] epoch 94 step 10/19 ot:0.4366 nll:4.9830 curv:0.0000 floor:0.1373 id:0.0000
# INFO:root:Epoch 094 | train: total=11.0673, ot:0.4470 nll:5.0179 curv:0.0000 floor:0.1372 id:0.0000 total:5.4651 || val: ot:nan nll:nan curv:0.0000 floor:0.1370 id:0.0000 total:nan
# INFO:root:[train] epoch 95 step 10/19 ot:0.4156 nll:4.7941 curv:0.0000 floor:0.1369 id:0.0000
# INFO:root:Epoch 095 | train: total=11.1374, ot:0.4438 nll:5.0565 curv:0.0000 floor:0.1368 id:0.0000 total:5.5004 || val: ot:nan nll:nan curv:0.0000 floor:0.1365 id:0.0000 total:nan
# INFO:root:[train] epoch 96 step 10/19 ot:0.4570 nll:5.1277 curv:0.0000 floor:0.1365 id:0.0000
# INFO:root:Epoch 096 | train: total=10.9864, ot:0.4366 nll:4.9884 curv:0.0000 floor:0.1364 id:0.0000 total:5.4251 || val: ot:nan nll:nan curv:0.0000 floor:0.1362 id:0.0000 total:nan
# INFO:root:[train] epoch 97 step 10/19 ot:0.4104 nll:4.8079 curv:0.0000 floor:0.1361 id:0.0000
# INFO:root:Epoch 097 | train: total=11.1059, ot:0.4457 nll:5.0392 curv:0.0000 floor:0.1360 id:0.0000 total:5.4850 || val: ot:nan nll:nan curv:0.0000 floor:0.1358 id:0.0000 total:nan
# INFO:root:[train] epoch 98 step 10/19 ot:0.4354 nll:4.9335 curv:0.0000 floor:0.1356 id:0.0000
# INFO:root:Epoch 098 | train: total=11.0757, ot:0.4409 nll:5.0291 curv:0.0000 floor:0.1355 id:0.0000 total:5.4702 || val: ot:nan nll:nan curv:0.0000 floor:0.1353 id:0.0000 total:nan
# INFO:root:[train] epoch 99 step 10/19 ot:0.4323 nll:4.9630 curv:0.0000 floor:0.1352 id:0.0000
# INFO:root:Epoch 099 | train: total=11.0254, ot:0.4364 nll:5.0087 curv:0.0000 floor:0.1351 id:0.0000 total:5.4452 || val: ot:nan nll:nan curv:0.0000 floor:0.1348 id:0.0000 total:nan
# INFO:root:[train] epoch 100 step 10/19 ot:0.4200 nll:4.8726 curv:0.0000 floor:0.1347 id:0.0000
# INFO:root:Epoch 100 | train: total=10.9418, ot:0.4339 nll:4.9696 curv:0.0000 floor:0.1346 id:0.0000 total:5.4036 || val: ot:nan nll:nan curv:0.0000 floor:0.1344 id:0.0000 total:nan
# INFO:root:[train] epoch 101 step 10/19 ot:0.4214 nll:4.8166 curv:0.0000 floor:0.1343 id:0.0000
# INFO:root:Epoch 101 | train: total=10.9398, ot:0.4333 nll:4.9695 curv:0.0000 floor:0.1342 id:0.0000 total:5.4029 || val: ot:nan nll:nan curv:0.0000 floor:0.1339 id:0.0000 total:nan
# INFO:root:[train] epoch 102 step 10/19 ot:0.4483 nll:5.0953 curv:0.0000 floor:0.1339 id:0.0000
# INFO:root:Epoch 102 | train: total=11.0241, ot:0.4357 nll:5.0093 curv:0.0000 floor:0.1338 id:0.0000 total:5.4452 || val: ot:nan nll:nan curv:0.0000 floor:0.1336 id:0.0000 total:nan
# INFO:root:[train] epoch 103 step 10/19 ot:0.4387 nll:4.8783 curv:0.0000 floor:0.1335 id:0.0000
# INFO:root:Epoch 103 | train: total=10.9472, ot:0.4291 nll:4.9778 curv:0.0000 floor:0.1334 id:0.0000 total:5.4070 || val: ot:nan nll:nan curv:0.0000 floor:0.1332 id:0.0000 total:nan
# INFO:root:[train] epoch 104 step 10/19 ot:0.4535 nll:5.2527 curv:0.0000 floor:0.1330 id:0.0000
# INFO:root:Epoch 104 | train: total=10.8105, ot:0.4234 nll:4.9153 curv:0.0000 floor:0.1329 id:0.0000 total:5.3389 || val: ot:nan nll:nan curv:0.0000 floor:0.1327 id:0.0000 total:nan
# INFO:root:[train] epoch 105 step 10/19 ot:0.4307 nll:5.0011 curv:0.0000 floor:0.1326 id:0.0000
# INFO:root:Epoch 105 | train: total=10.9087, ot:0.4293 nll:4.9588 curv:0.0000 floor:0.1325 id:0.0000 total:5.3882 || val: ot:nan nll:nan curv:0.0000 floor:0.1322 id:0.0000 total:nan
# INFO:root:[train] epoch 106 step 10/19 ot:0.4388 nll:4.9908 curv:0.0000 floor:0.1321 id:0.0000
# INFO:root:Epoch 106 | train: total=10.8651, ot:0.4275 nll:4.9390 curv:0.0000 floor:0.1320 id:0.0000 total:5.3666 || val: ot:nan nll:nan curv:0.0000 floor:0.1317 id:0.0000 total:nan
# INFO:root:[train] epoch 107 step 10/19 ot:0.4025 nll:4.8014 curv:0.0000 floor:0.1317 id:0.0000
# INFO:root:Epoch 107 | train: total=10.9061, ot:0.4292 nll:4.9580 curv:0.0000 floor:0.1316 id:0.0000 total:5.3873 || val: ot:nan nll:nan curv:0.0000 floor:0.1313 id:0.0000 total:nan
# INFO:root:[train] epoch 108 step 10/19 ot:0.4131 nll:4.8203 curv:0.0000 floor:0.1312 id:0.0000
# INFO:root:Epoch 108 | train: total=10.8136, ot:0.4233 nll:4.9179 curv:0.0000 floor:0.1311 id:0.0000 total:5.3413 || val: ot:nan nll:nan curv:0.0000 floor:0.1309 id:0.0000 total:nan
# INFO:root:[train] epoch 109 step 10/19 ot:0.4211 nll:4.9438 curv:0.0000 floor:0.1308 id:0.0000
# INFO:root:Epoch 109 | train: total=10.9459, ot:0.4276 nll:4.9799 curv:0.0000 floor:0.1307 id:0.0000 total:5.4077 || val: ot:nan nll:nan curv:0.0000 floor:0.1305 id:0.0000 total:nan
# INFO:root:[train] epoch 110 step 10/19 ot:0.4126 nll:4.7879 curv:0.0000 floor:0.1303 id:0.0000
# INFO:root:Epoch 110 | train: total=10.7176, ot:0.4170 nll:4.8767 curv:0.0000 floor:0.1302 id:0.0000 total:5.2938 || val: ot:nan nll:nan curv:0.0000 floor:0.1300 id:0.0000 total:nan
# INFO:root:[train] epoch 111 step 10/19 ot:0.4227 nll:4.9433 curv:0.0000 floor:0.1299 id:0.0000
# INFO:root:Epoch 111 | train: total=10.6730, ot:0.4123 nll:4.8592 curv:0.0000 floor:0.1298 id:0.0000 total:5.2717 || val: ot:nan nll:nan curv:0.0000 floor:0.1295 id:0.0000 total:nan
# INFO:root:[train] epoch 112 step 10/19 ot:0.4455 nll:5.0573 curv:0.0000 floor:0.1294 id:0.0000
# INFO:root:Epoch 112 | train: total=10.5884, ot:0.4079 nll:4.8216 curv:0.0000 floor:0.1293 id:0.0000 total:5.2296 || val: ot:nan nll:nan curv:0.0000 floor:0.1290 id:0.0000 total:nan
# INFO:root:[train] epoch 113 step 10/19 ot:0.3873 nll:4.5842 curv:0.0000 floor:0.1290 id:0.0000
# INFO:root:Epoch 113 | train: total=10.6878, ot:0.4123 nll:4.8671 curv:0.0000 floor:0.1289 id:0.0000 total:5.2796 || val: ot:nan nll:nan curv:0.0000 floor:0.1286 id:0.0000 total:nan
# INFO:root:[train] epoch 114 step 10/19 ot:0.3850 nll:4.7246 curv:0.0000 floor:0.1285 id:0.0000
# INFO:root:Epoch 114 | train: total=10.5154, ot:0.4063 nll:4.7871 curv:0.0000 floor:0.1284 id:0.0000 total:5.1936 || val: ot:nan nll:nan curv:0.0000 floor:0.1282 id:0.0000 total:nan
# INFO:root:[train] epoch 115 step 10/19 ot:0.4319 nll:5.1336 curv:0.0000 floor:0.1281 id:0.0000
# INFO:root:Epoch 115 | train: total=10.4208, ot:0.3976 nll:4.7487 curv:0.0000 floor:0.1280 id:0.0000 total:5.1465 || val: ot:nan nll:nan curv:0.0000 floor:0.1278 id:0.0000 total:nan
# INFO:root:[train] epoch 116 step 10/19 ot:0.4126 nll:4.8824 curv:0.0000 floor:0.1276 id:0.0000
# INFO:root:Epoch 116 | train: total=10.5377, ot:0.4028 nll:4.8023 curv:0.0000 floor:0.1275 id:0.0000 total:5.2052 || val: ot:nan nll:nan curv:0.0000 floor:0.1273 id:0.0000 total:nan
# INFO:root:[train] epoch 117 step 10/19 ot:0.4065 nll:4.8817 curv:0.0000 floor:0.1272 id:0.0000
# INFO:root:Epoch 117 | train: total=10.5693, ot:0.4049 nll:4.8161 curv:0.0000 floor:0.1271 id:0.0000 total:5.2212 || val: ot:nan nll:nan curv:0.0000 floor:0.1268 id:0.0000 total:nan
# INFO:root:[train] epoch 118 step 10/19 ot:0.4002 nll:4.8346 curv:0.0000 floor:0.1267 id:0.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[86], line 589
#     587 best_val = float("inf")
#     588 for epoch in range(1, CONFIG["training"]["epochs"]+1):
# --> 589     tr = trainer.train_epoch(train_loader, epoch, phase="train")
#     591     vl = trainer.train_epoch(val_loader,   epoch, phase="val")
#     592     # Force a plot refresh at epoch end, too:
#
# Cell In[86], line 418, in InverseScaleTrainer.train_epoch(self, loader, epoch, phase)
#     416 if train:
#     417     self.opt.zero_grad(set_to_none=True)
# --> 418     loss.backward()
#     419     torch.nn.utils.clip_grad_norm_(
#     420         list(self.psi.parameters()) + list(self.emb.parameters()),
#     421         max_norm=self.cfg["training"]["grad_clip_norm"]
#     422     )
#     423     self.opt.step()
#
# File /opt/anaconda3/envs/manip311/lib/python3.11/site-packages/torch/_tensor.py:653, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     643 if has_torch_function_unary(self):
#     644     return handle_torch_function(
#     645         Tensor.backward,
#     646         (self,),
#    (...)    651         inputs=inputs,
#     652     )
# --> 653 torch.autograd.backward(
#     654     self, gradient, retain_graph, create_graph, inputs=inputs
#     655 )
#
# File /opt/anaconda3/envs/manip311/lib/python3.11/site-packages/torch/autograd/__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File /opt/anaconda3/envs/manip311/lib/python3.11/site-packages/torch/autograd/graph.py:829, in _engine_run_backward(t_outputs, *args, **kwargs)
#     827     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828 try:
# --> 829     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830         t_outputs, *args, **kwargs
#     831     )  # Calls into the C++ engine to run the backward pass
#     832 finally:
#     833     if attach_logging_hooks:
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/envs/manip311/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File /opt/anaconda3/envs/manip311/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
#     649 # released and notifications are fired.
# --> 650 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     651     for name in sync_data:
#     652         if name in self.keys:
#
# File /opt/anaconda3/envs/manip311/lib/python3.11/contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File /opt/anaconda3/envs/manip311/lib/python3.11/site-packages/traitlets/traitlets.py:1510, in HasTraits.hold_trait_notifications(self)
#    1508 for changes in cache.values():
#    1509     for change in changes:
# -> 1510         self.notify_change(change)
#
# File /opt/anaconda3/envs/manip311/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File /opt/anaconda3/envs/manip311/lib/python3.11/site-packages/traitlets/traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File /opt/anaconda3/envs/manip311/lib/python3.11/site-packages/traitlets/traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# File /opt/anaconda3/envs/manip311/lib/python3.11/site-packages/plotly/basewidget.py:458, in BaseFigureWidget._handler_js2py_traceDeltas(self, change)
#     451 delta_transform = BaseFigureWidget._transform_data(
#     452     uid_trace._prop_defaults, delta
#     453 )
#     455 # #### Remove overlapping properties ####
#     456 # If a property is present in both _props and _prop_defaults
#     457 # then we remove the copy from _props
# --> 458 remove_props = self._remove_overlapping_props(
#     459     uid_trace._props, uid_trace._prop_defaults
#     460 )
#     462 # #### Notify frontend model of property removal ####
#     463 if remove_props:
#
# File /opt/anaconda3/envs/manip311/lib/python3.11/site-packages/plotly/basewidget.py:849, in BaseFigureWidget._remove_overlapping_props(input_data, delta_data, prop_path)
#     845 removed.extend(recur_removed)
#     847 # Check whether the last property in input_val
#     848 # has been removed. If so, remove it entirely
# --> 849 if not input_val:
#     850     input_data.pop(p)
#     851     removed.append(recur_prop_path)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
